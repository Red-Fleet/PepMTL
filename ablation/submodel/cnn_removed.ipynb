# %%
# --------------------------------------------------
# 1. Imports (add these to the existing ones)
# --------------------------------------------------
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader, random_split
from sklearn.preprocessing import MultiLabelBinarizer
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt
import itertools
from torchvision.transforms import Resize
from ast import literal_eval
from sklearn.metrics import matthews_corrcoef
from torchvision import models
from transformers import AutoTokenizer, AutoModelForMaskedLM
import math
import json
from collections import defaultdict
import seaborn as sns
from matplotlib.colors import LogNorm
import random
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
# --------------------------------------------------
# Out:
# Skipping import of cpp extensions due to incompatible torch version 2.8.0+cu128 for torchao version 0.15.0             Please see https://github.com/pytorch/ao/issues/2919 for more info

# %%
DEVICE    = 'cuda:1' if torch.cuda.is_available() else 'cpu'

# %% [markdown]
# this is for all_endpoint + non_functional

# %%
with open('../../cleaned_clustered_dataset.json') as f:
    clustered_dataset = json.load(f)

# %%
class_count = defaultdict(int)
for cluster in clustered_dataset:
    for s in cluster:
        for c in s['classes']:
            class_count[c] += 1

class_count
# Out:
# defaultdict(int,
#             {'other-functional': 7040,
#              'metabolic': 11589,
#              'inhibitor': 2046,
#              'toxic': 22440,
#              'anti-cancer': 12390,
#              'drug-delivery': 2202,
#              'anti-bacterial': 29969,
#              'anti-fungal': 12747,
#              'anti-parasitic': 6586,
#              'anti-viral': 6894,
#              'signal-peptide': 22226,
#              'immunological': 4413,
#              'cell-cell-communication': 3249,
#              'non-functional': 163115})

# %%
# cleaning clusters , removing clustures with empty sequences or empty classes
removes_seqs = 0
for i, cluster in enumerate(clustered_dataset):
    new_cluster = []
    for entry in cluster:
        if entry['sequence'] == '' or len(entry['classes']) == 0:
            removes_seqs += 1
        else:
            new_cluster.append(entry)

    clustered_dataset[i] = new_cluster

unfiltured_clusters_size = len(clustered_dataset)
clustered_dataset = [cluster for cluster in clustered_dataset if len(cluster) > 0]
print(f"Removed {unfiltured_clusters_size - len(clustered_dataset)} clusters")
print(f"Removed {removes_seqs} sequences")
# Out:
# Removed 0 clusters
# Removed 0 sequences

# %% [markdown]
# # dividing into train and test

# %%
train_val_test_ratio = [0.7, 0.1, 0.2]
random_state = 42

if len(train_val_test_ratio) != 3:
    raise ValueError("train_val_test_ratio must contain [train, val, test].")

ratio_sum = sum(train_val_test_ratio)
if ratio_sum <= 0:
    raise ValueError("Sum of train_val_test_ratio must be > 0.")

train_ratio, val_ratio, test_ratio = [r / ratio_sum for r in train_val_test_ratio]

all_seqs_count = sum(len(cluster) for cluster in clustered_dataset)
print('all_seqs_count', all_seqs_count)

train_size = int(all_seqs_count * train_ratio)
val_size = int(all_seqs_count * val_ratio)
test_size = all_seqs_count - train_size - val_size

train_seqs = []
val_seqs = []
test_seqs = []

train_cluster_count = 0
val_cluster_count = 0
test_cluster_count = 0

all_cluster_ids = [i for i in range(len(clustered_dataset))]
rng = random.Random(random_state)
rng.shuffle(all_cluster_ids)

for cluster_id in all_cluster_ids:
    cluster = clustered_dataset[cluster_id]
    if len(train_seqs) < train_size:
        train_seqs.extend(cluster)
        train_cluster_count += 1
    elif len(val_seqs) < val_size:
        val_seqs.extend(cluster)
        val_cluster_count += 1
    else:
        test_seqs.extend(cluster)
        test_cluster_count += 1

print('train_seqs', len(train_seqs))
print('val_seqs', len(val_seqs))
print('test_seqs', len(test_seqs))

print('train_cluster_count', train_cluster_count)
print('val_cluster_count', val_cluster_count)
print('test_cluster_count', test_cluster_count)
# Out:
# all_seqs_count 257812
# train_seqs 180471
# val_seqs 25781
# test_seqs 51560
# train_cluster_count 87893
# val_cluster_count 12557
# test_cluster_count 25276

# %% [markdown]
# # creating dataset

# %%
# other-functional is present with known functionl class then remove other-functional
for item in train_seqs:
    if 'other-functional' in item['classes'] and len(item['classes']) > 1:
        item['classes'].remove('other-functional')
        if len(item['classes']) == 0: raise Exception("no class left")

for item in test_seqs:
    if 'other-functional' in item['classes'] and len(item['classes']) > 1:
        item['classes'].remove('other-functional')
        if len(item['classes']) == 0: raise Exception("no class left")

for item in val_seqs:
    if 'other-functional' in item['classes'] and len(item['classes']) > 1:
        item['classes'].remove('other-functional')
        if len(item['classes']) == 0: raise Exception("no class left")

# %%
all_endpoints = set([c for e in train_seqs+test_seqs+val_seqs for c in e['classes']]) 

sorted(list(all_endpoints))
# Out:
# ['anti-bacterial',
#  'anti-cancer',
#  'anti-fungal',
#  'anti-parasitic',
#  'anti-viral',
#  'cell-cell-communication',
#  'drug-delivery',
#  'immunological',
#  'inhibitor',
#  'metabolic',
#  'non-functional',
#  'other-functional',
#  'signal-peptide',
#  'toxic']

# %%
# endpoints = [
#  'anti-cancer',
#  'anti-fungal',
#  'anti-parasitic',
#  'anti-viral',
#  'non-functional'
#  ]

endpoints = ['anti-bacterial',
 'anti-cancer',
 'anti-fungal',
 'anti-parasitic',
 'anti-viral',
 'cell-cell-communication',
 'drug-delivery',
 'immunological',
 'inhibitor',
 'metabolic',
 'non-functional',
 'other-functional',
 'signal-peptide',
 'toxic']

 
endpoints_set = set(endpoints)
endpoint_index = {endpoint: i for i, endpoint in enumerate(endpoints)}
index_endpoint = {i: endpoint for i, endpoint in enumerate(endpoints)}

# %%
endpoints_set
# Out:
# {'anti-bacterial',
#  'anti-cancer',
#  'anti-fungal',
#  'anti-parasitic',
#  'anti-viral',
#  'cell-cell-communication',
#  'drug-delivery',
#  'immunological',
#  'inhibitor',
#  'metabolic',
#  'non-functional',
#  'other-functional',
#  'signal-peptide',
#  'toxic'}

# %%
train_df_rows = []
for entry in train_seqs:
    row = [False]*len(endpoints)
    if len(set(entry['classes']).intersection(endpoints_set)) > 0: 
        
        for c in entry['classes']:
            if c in endpoints:
                row[endpoint_index[c]] = True

    
        row = [entry['sequence']] + row
        train_df_rows.append(row)
    
val_df_rows = []
for entry in val_seqs:
    row = [False]*len(endpoints)
    if len(set(entry['classes']).intersection(endpoints_set)) > 0: 

        for c in entry['classes']:
            if c in endpoints:
                row[endpoint_index[c]] = True

        row = [entry['sequence']] + row
        val_df_rows.append(row)

test_df_rows = []
for entry in test_seqs:
    row = [False]*len(endpoints)
    if len(set(entry['classes']).intersection(endpoints_set)) > 0: 

        for c in entry['classes']:
            if c in endpoints:
                row[endpoint_index[c]] = True

        row = [entry['sequence']] + row
        test_df_rows.append(row)

train_df = pd.DataFrame(train_df_rows, columns=['sequence'] + endpoints)
val_df = pd.DataFrame(val_df_rows, columns=['sequence'] + endpoints)
test_df = pd.DataFrame(test_df_rows, columns=['sequence'] + endpoints)

# %%
# # saving train, val, test dataset for classification
# train_df.to_csv('train_classification.csv')
# val_df.to_csv('validation_classification.csv')
# test_df.to_csv('test_classification.csv')

# %%
summary = train_df[endpoints].apply(pd.Series.value_counts)

# 2. Calculate True Percentage and add it as a new row
# We multiply by 100 to get a readable percentage (e.g., 75.0 instead of 0.75)
summary.loc['True %'] = train_df[endpoints].mean() * 100

# Print the final summary
print(summary)
# Out:
#         anti-bacterial    anti-cancer   anti-fungal  anti-parasitic  \
# False    159502.000000  171656.000000  171554.00000   175865.000000
# True      20969.000000    8815.000000    8917.00000     4606.000000
# True %       11.619041       4.884441       4.94096        2.552211
#
#            anti-viral  cell-cell-communication  drug-delivery  immunological  \
# False   175475.000000            178081.000000  178847.000000  177435.000000
# True      4996.000000              2390.000000    1624.000000    3036.000000
# True %       2.768312                 1.324312       0.899868       1.682265
#
#             inhibitor      metabolic  non-functional  other-functional  \
# False   178988.000000  172233.000000    66678.000000     178237.000000
# True      1483.000000    8238.000000   113793.000000       2234.000000
# True %       0.821739       4.564722       63.053344          1.237872
#
#         signal-peptide          toxic
# False    164871.000000  164737.000000
# True      15600.000000   15734.000000
# True %        8.644048       8.718298

# %%
summary = test_df[endpoints].apply(pd.Series.value_counts)

# 2. Calculate True Percentage and add it as a new row
# We multiply by 100 to get a readable percentage (e.g., 75.0 instead of 0.75)
summary.loc['True %'] = test_df[endpoints].mean() * 100

# Print the final summary
print(summary)
# Out:
#         anti-bacterial   anti-cancer  anti-fungal  anti-parasitic  \
# False     45293.000000  49132.000000  49041.00000    50244.000000
# True       6267.000000   2428.000000   2519.00000     1316.000000
# True %       12.154771      4.709077      4.88557        2.552366
#
#           anti-viral  cell-cell-communication  drug-delivery  immunological  \
# False   50281.000000              51014.00000   51168.000000   50648.000000
# True     1279.000000                546.00000     392.000000     912.000000
# True %      2.480605                  1.05896       0.760279       1.768813
#
#            inhibitor    metabolic  non-functional  other-functional  \
# False   51191.000000  49450.00000    18796.000000      50873.000000
# True      369.000000   2110.00000    32764.000000        687.000000
# True %      0.715671      4.09232       63.545384          1.332428
#
#         signal-peptide         toxic
# False     47144.000000  47045.000000
# True       4416.000000   4515.000000
# True %        8.564779      8.756788

# %%
random.random()
# Out:
# 0.32142313728066974

# %%
esm_tokenizer = AutoTokenizer.from_pretrained("facebook/esm2_t6_8M_UR50D")

# %%
class PeptideDataset(Dataset):

    def __init__(
        self,
        dataframe,
        tokenizer,
        label_columns,
        max_length: int = 128
    ):
        """
        Args:
            dataframe (pd.DataFrame): DataFrame containing the data.
                                      Must have a 'sequence' column.
            tokenizer (AutoTokenizer): A Hugging Face tokenizer (e.g., for ESM-2).
            label_columns (List[str]): A list of column names that represent the labels.
            max_length (int): Maximum sequence length for padding/truncation.
        """
        self.df = dataframe
        self.tokenizer = tokenizer
        self.sequences = self.df['sequence'].values
        self.labels = self.df[label_columns].values
        self.label_columns = label_columns
        self.max_length = max_length

        functional_idxs = []
        non_functional_idxs = []
        for i, label in enumerate(self.labels):
            if label[endpoint_index['non-functional']] == True:
                non_functional_idxs.append(i)
            else:
                functional_idxs.append(i)
        
        non_functional_idxs = [non_functional_idxs[i: i+1] for i in range(0, len(non_functional_idxs), 1)]
        non_functional_idxs = [i for i in non_functional_idxs]

        functional_idxs = [functional_idxs[i: i+1] for i in range(0, len(functional_idxs), 1)]
        self.all_idxs = non_functional_idxs + functional_idxs

        # Pre-tokenize ALL sequences once
        sequences = dataframe['sequence'].tolist()
        encodings = tokenizer(
            sequences,
            add_special_tokens=True,
            max_length=max_length,
            padding='max_length',
            truncation=True,
            return_attention_mask=True,
            return_tensors='pt'
        )
        self.input_ids = encodings['input_ids']
        self.attention_masks = encodings['attention_mask']


    def __len__(self) -> int:
        """Returns the total number of samples in the dataset."""
        return len(self.all_idxs)

    def __getitem__(self, index: int):
        """
        Retrieves a single sample from the dataset.

        Args:
            index (int): The index of the sample to retrieve.

        Returns:
            A dictionary containing:
            - 'input_ids': Token IDs of the sequence.
            - 'attention_mask': Mask to avoid performing attention on padding tokens.
            - 'labels': A multi-hot encoded tensor of labels.
            - 'img_input': A dummy tensor to match the MultiModelNetwork's forward signature.
        """
        idx = random.choice(self.all_idxs[index])

        return {
            'input_ids': self.input_ids[idx],
            'attention_mask': self.attention_masks[idx],
            'labels': torch.FloatTensor(self.labels[idx])
        }

# %%
LABEL_COLUMNS = endpoints

MAX_LEN = 100
train_dataset = PeptideDataset(train_df, esm_tokenizer, LABEL_COLUMNS, MAX_LEN)
val_dataset = PeptideDataset(val_df, esm_tokenizer, LABEL_COLUMNS, MAX_LEN)
test_dataset = PeptideDataset(test_df, esm_tokenizer, LABEL_COLUMNS, MAX_LEN)

# %%
len(train_dataset),  len(val_dataset), len(test_dataset)
# Out:
# (180471, 25781, 51560)

# %%
train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=64, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=True)

# %%
# Calculate weights
NON_FUNC_IDX = endpoint_index['non-functional']
FUNC_INDICES = [i for k, i in endpoint_index.items() if k != 'non-functional']

# %%
# =====================================================================
# Model v19 (Lite): Sequence-Level Cross-Attention + Task Query Decoder
# Parameter Count: ~19.6 Million
# =====================================================================

class ESM2_Encoder(nn.Module):
    def __init__(self, model_name, trainable=True, unfreeze_last_n=0):
        super().__init__()
        self.esm_mlm = AutoModelForMaskedLM.from_pretrained(model_name)
        self.hidden_size = self.esm_mlm.config.hidden_size
        if not trainable:
            for param in self.esm_mlm.parameters():
                param.requires_grad = False
            if unfreeze_last_n > 0:
                for layer in self.esm_mlm.esm.encoder.layer[-unfreeze_last_n:]:
                    for param in layer.parameters():
                        param.requires_grad = True

    def forward(self, input_ids, attention_mask):
        return self.esm_mlm.esm(input_ids=input_ids, attention_mask=attention_mask).last_hidden_state



class MultiHeadAttentionPool(nn.Module):
    def __init__(self, dim, num_heads=4):
        super().__init__()
        self.num_heads = num_heads
        self.attn = nn.Sequential(
            nn.Linear(dim, 128), 
            nn.Tanh(), 
            nn.Linear(128, num_heads)
        )
        self._last_weights = None

    def forward(self, x, mask):
        scores = self.attn(x)
        scores = scores.masked_fill(mask.unsqueeze(-1) == 0, -1e4)
        weights = torch.softmax(scores, dim=1)
        self._last_weights = weights
        pooled = (x.unsqueeze(2) * weights.unsqueeze(-1)).sum(dim=1)
        return pooled.view(x.size(0), -1)


    def orthogonality_loss(self):
        """Penalize overlap between head attention distributions."""
        if self._last_weights is None:
            return 0.0
            
        # weights: [B, L, num_heads] -> transpose to [B, num_heads, L]
        w = self._last_weights.transpose(1, 2)  
        
        # Gram matrix of head attention distributions: shape [B, num_heads, num_heads]
        gram = torch.bmm(w, w.transpose(1, 2))  
        
        # Create a boolean mask for the off-diagonal elements (~torch.eye inverts the identity matrix)
        mask = ~torch.eye(self.num_heads, dtype=torch.bool, device=gram.device)
        
        # Penalize only the off-diagonal overlap to encourage heads to focus on different tokens.
        # We want these dot products to be pushed towards 0.
        loss = (gram[:, mask] ** 2).mean()
        
        return loss
    
class GatedFusion(nn.Module):
    def __init__(self, input_dim):
        super().__init__()
        self.gate = nn.Sequential(nn.Linear(input_dim, input_dim), nn.Sigmoid())
    def forward(self, x):
        return x * self.gate(x)

class PeptideNetwork(nn.Module):
    def __init__(self, num_classes=21, mask_token_id=32):
        super().__init__()
        self.mask_token_id = mask_token_id
        self.num_classes = num_classes

        # BOTH encoders are now the 8M parameter t6 model
        self.esm_t6_a = ESM2_Encoder("facebook/esm2_t6_8M_UR50D", trainable=True)        
        self.esm_t6_b = ESM2_Encoder("facebook/esm2_t6_8M_UR50D", trainable=False, unfreeze_last_n=2)                                  

        # REDUCED cross_dim to 128 to save parameters
        cross_dim = 128
        self.proj_t6_a = nn.Linear(320, cross_dim)
        self.proj_t6_b = nn.Linear(320, cross_dim) # Updated to 320 for t6

        self.cross_t6_a = nn.MultiheadAttention(cross_dim, num_heads=4, batch_first=True, dropout=0.1)
        self.ln_ca_t6_a = nn.LayerNorm(cross_dim)
        
        self.cross_t6_b = nn.MultiheadAttention(cross_dim, num_heads=4, batch_first=True, dropout=0.1)
        self.ln_ca_t6_b = nn.LayerNorm(cross_dim)
        
        self.pool_t6_a = MultiHeadAttentionPool(cross_dim, num_heads=4)
        self.pool_t6_b = MultiHeadAttentionPool(cross_dim, num_heads=4)

        # Bottleneck reduction layer before fusion
        # Concat size: 128*4*3 (pools) + 768 (CNN) = 1536 + 768 = 2304
        concat_size = cross_dim * 4 * 2 
        
        self.dim_reduce = nn.Sequential(
            nn.Linear(concat_size, 512),
            nn.GELU()
        )
        
        # Fusion now operates efficiently on 512 dimensions
        self.fusion = GatedFusion(512)
        self.ln = nn.LayerNorm(512)

        # binary head
        binary_features_dim = 64
        self.binary_features = nn.Sequential(
            nn.Linear(512, binary_features_dim),
            nn.GELU(),
            nn.Dropout(0.2)
        )
        self.binary_classifier = nn.Linear(64, 1) # Final logit

        # Task Query Decoder
        self.task_dim = 128
        self.n_memory_tokens = 16
        self.memory_proj = nn.Sequential(
            nn.Linear(512 + binary_features_dim, self.task_dim * self.n_memory_tokens),
            nn.GELU(),
        )
        self.task_queries = nn.Embedding(num_classes, self.task_dim)
        decoder_layer = nn.TransformerDecoderLayer(
            d_model=self.task_dim, nhead=4, dim_feedforward=256,
            batch_first=True, dropout=0.1
        )
        self.task_decoder = nn.TransformerDecoder(decoder_layer, num_layers=2)
        self.task_classifiers = nn.ModuleList([
            nn.Linear(self.task_dim, 1) for _ in range(num_classes)
        ])

    def _mask_tokens(self, input_ids, attention_mask, mask_prob=0.15):
        masked_ids = input_ids.clone()
        prob_matrix = torch.full_like(input_ids, mask_prob, dtype=torch.float)
        prob_matrix[attention_mask == 0] = 0
        prob_matrix[:, 0] = 0
        seq_lens = attention_mask.sum(dim=1)
        for i in range(len(seq_lens)):
            if seq_lens[i] > 1:
                prob_matrix[i, seq_lens[i] - 1] = 0
        mask = torch.bernoulli(prob_matrix).bool()
        masked_ids[mask] = self.mask_token_id
        return masked_ids

    def _extract_features(self, seq_input, seq_mask):
        esm6_a_seq = self.esm_t6_a(seq_input, seq_mask)       
        esm6_b_seq = self.esm_t6_b(seq_input, seq_mask)     

        t6_a = self.proj_t6_a(esm6_a_seq)       
        t6_b = self.proj_t6_b(esm6_b_seq)    


        kv_pad = seq_mask == 0  

        ca_t6_a, _ = self.cross_t6_a(t6_a, t6_b, t6_b, key_padding_mask=kv_pad)
        ca_t6_a = self.ln_ca_t6_a(t6_a + ca_t6_a)

        ca_t6_b, _ = self.cross_t6_b(t6_b, t6_a, t6_a, key_padding_mask=kv_pad)
        ca_t6_b = self.ln_ca_t6_b(t6_b + ca_t6_b)

        pooled_t6_a = self.pool_t6_a(ca_t6_a, seq_mask)
        pooled_t6_b = self.pool_t6_b(ca_t6_b, seq_mask)

        # Concat -> Reduce -> Fuse
        combined = torch.cat([pooled_t6_a, pooled_t6_b], dim=1)  
        reduced = self.dim_reduce(combined)
        fusion = self.ln(reduced + self.fusion(reduced))

        binary_features = self.binary_features(fusion)
        
        return binary_features, torch.cat([fusion, binary_features], dim=1)
    
    def _binary_classify(self, binary_features):
        
        binary_logits = self.binary_classifier(binary_features)

        return binary_logits

    def _classify(self, final_fusion):
        B = final_fusion.size(0)
        memory = self.memory_proj(final_fusion).view(B, self.n_memory_tokens, self.task_dim)
        tgt = self.task_queries.weight.unsqueeze(0).expand(B, -1, -1)
        decoded = self.task_decoder(tgt, memory)
        logits = torch.cat([self.task_classifiers[i](decoded[:, i, :])
                           for i in range(self.num_classes)], dim=1)
        return logits

    def forward(self, seq_input, seq_mask, mask_tokens=False):
        if mask_tokens and self.training:
            seq_input = self._mask_tokens(seq_input, seq_mask)
        
        binary_features, combined_features = self._extract_features(seq_input, seq_mask)
        

        return self._binary_classify(binary_features), self._classify(combined_features)


    def ortho_loss(self):
        return (self.pool_t6_a.orthogonality_loss() +
                self.pool_t6_b.orthogonality_loss() 
                ) / 2
    
    def get_features(self, seq_input, seq_mask, mask_tokens=False):
        if mask_tokens and self.training:
            seq_input = self._mask_tokens(seq_input, seq_mask)
        return self._extract_features(seq_input, seq_mask)

    def multi_classify(self, combined):
        return self._classify(combined)
    
    def binary_classify(self, binary_features):
        return self._binary_classify(binary_features)

# %% [markdown]
# # training: function and non-functionl(whole sequence)

# %%
import copy
class EMA:
    def __init__(self, model, decay=0.999):
        self.decay = decay
        self.shadow = copy.deepcopy(model)
        self.shadow.eval()
        for p in self.shadow.parameters():
            p.requires_grad_(False)

    @torch.no_grad()
    def update(self, model):
        # Update parameters (weights & biases)
        for s_param, m_param in zip(self.shadow.parameters(), model.parameters()):
            s_param.data.mul_(self.decay).add_(m_param.data, alpha=1 - self.decay)
        
        # FIX: Update only floating point buffers (skip int buffers like num_batches_tracked)
        for s_buf, m_buf in zip(self.shadow.buffers(), model.buffers()):
            if s_buf.dtype.is_floating_point:
                s_buf.data.mul_(self.decay).add_(m_buf.data, alpha=1 - self.decay)
            else:
                # For integer buffers, just copy directly (no EMA smoothing needed)
                s_buf.data.copy_(m_buf.data)

    def forward(self, *args, **kwargs):
        return self.shadow(*args, **kwargs)

# %%
torch.cuda.empty_cache()

model = PeptideNetwork(num_classes=len(endpoints)-1, mask_token_id=32).to(DEVICE)
ema = EMA(model, decay=0.999)

# --- ASL: Asymmetric Loss for Multi-Label Classification ---
class AsymmetricLoss(nn.Module):
    def __init__(self, gamma_neg=4, gamma_pos=1, clip=0.05):
        super().__init__()
        self.gamma_neg = gamma_neg
        self.gamma_pos = gamma_pos
        self.clip = clip

    def forward(self, logits, targets):
        p = torch.sigmoid(logits)
        pos_part = targets * torch.log(p.clamp(min=1e-8))
        neg_p = (1 - p).clamp(min=1e-8)
        if self.clip > 0:
            neg_p = (neg_p + self.clip).clamp(max=1)
        neg_part = (1 - targets) * torch.log(neg_p)
        pos_weight = (1 - p) ** self.gamma_pos
        neg_weight = p ** self.gamma_neg
        loss = -(pos_weight * pos_part + neg_weight * neg_part)
        return loss.mean()

criterion = AsymmetricLoss(gamma_neg=4, gamma_pos=1, clip=0.05)
binary_criterion = nn.BCEWithLogitsLoss()

# Optimizer — 3 LR groups (Lowered LRs to prevent early overfitting)
esm_t6_ids = set(id(p) for p in model.esm_t6_a.esm_mlm.parameters())
esm_t6_b_ids = set(id(p) for p in model.esm_t6_b.esm_mlm.parameters())

esm_t6_params = [p for p in model.parameters() if id(p) in esm_t6_ids and p.requires_grad]
esm_t6_b_params = [p for p in model.parameters() if id(p) in esm_t6_b_ids and p.requires_grad]
other_params = [p for p in model.parameters() if id(p) not in esm_t6_ids and id(p) not in esm_t6_b_ids and p.requires_grad]

optimizer = optim.AdamW([
    {'params': esm_t6_params, 'lr': 1e-5},     # Reduced from 1e-5
    {'params': esm_t6_b_params, 'lr': 2e-6},   # Reduced from 2e-6
    {'params': other_params, 'lr': 1e-4},      # Reduced from 1e-4
], weight_decay=0.05)                          # Kept the stronger L2 regularization

total_params = sum(p.numel() for p in model.parameters())
trainable_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
print(f"Total: {total_params/1e6:.1f}M | Trainable: {trainable_params/1e6:.1f}M")
print(f"Loss: ASL(γ-=4, γ+=1, clip=0.05) | v19: Triple CrossAttn + Task Query Decoder")
# Out:
# Total: 17.7M | Trainable: 12.6M
# Loss: ASL(γ-=4, γ+=1, clip=0.05) | v19: Triple CrossAttn + Task Query Decoder

# %%
NON_FUNC_IDX = endpoint_index['non-functional']
FUNC_INDICES = [i for k, i in endpoint_index.items() if k != 'non-functional']

# %%
epochs = 80

# %%
# Warmup + Cosine Annealing
steps_per_epoch = len(train_loader)
warmup_epochs = 3
total_steps = epochs * steps_per_epoch

def lr_lambda(step):
    if step < warmup_epochs * steps_per_epoch:
        return step / (warmup_epochs * steps_per_epoch)
    progress = (step - warmup_epochs * steps_per_epoch) / (total_steps - warmup_epochs * steps_per_epoch)
    return 0.5 * (1 + math.cos(math.pi * progress))

scheduler = optim.lr_scheduler.LambdaLR(optimizer, lr_lambda)
print(f"Warmup ({warmup_epochs} ep) + CosineAnnealing, total {epochs} epochs, {total_steps} steps")
# Out:
# Warmup (3 ep) + CosineAnnealing, total 80 epochs, 225600 steps

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score

# %%
from sklearn.metrics import matthews_corrcoef, accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, confusion_matrix
import json

# %%
# --- HELPER FUNCTIONS ---
def calculate_complete_metrics(y_true, y_pred_probs, thresholds, class_names):
    results = {}
    for i in range(y_true.shape[1]):
        y_pred_cls = (y_pred_probs[:, i] >= thresholds[i]).astype(int)
        mcc = matthews_corrcoef(y_true[:, i], y_pred_cls)
        acc = accuracy_score(y_true[:, i], y_pred_cls)
        prec = precision_score(y_true[:, i], y_pred_cls, zero_division=0)
        rec = recall_score(y_true[:, i], y_pred_cls, zero_division=0)
        f1 = f1_score(y_true[:, i], y_pred_cls, zero_division=0)
        try:
            auc_val = roc_auc_score(y_true[:, i], y_pred_probs[:, i])
        except ValueError:
            auc_val = 0.5
        tn, fp, fn, tp = confusion_matrix(y_true[:, i], y_pred_cls, labels=[0, 1]).ravel()
        results[class_names[i]] = {
            "mcc": float(mcc),
            "threshold": float(thresholds[i]),
            "accuracy": float(acc),
            "precision": float(prec),
            "recall": float(rec),
            "f1_score": float(f1),
            "roc_auc": float(auc_val),
            "tp": int(tp),
            "tn": int(tn),
            "fp": int(fp),
            "fn": int(fn),
        }
    return results

def find_optimal_thresholds(y_true, y_pred_probs):
    optimal_thresholds = []
    for i in range(y_true.shape[1]):
        best_mcc = -1
        best_threshold = 0.5
        for threshold in np.arange(0.1, 0.95, 0.05):
            y_pred_class = (y_pred_probs[:, i] >= threshold).astype(int)
            mcc = matthews_corrcoef(y_true[:, i], y_pred_class)
            if mcc > best_mcc:
                best_mcc = mcc
                best_threshold = threshold
        optimal_thresholds.append(best_threshold)
    return optimal_thresholds

def calculate_mcc(tp, tn, fp, fn):
    num = (tp * tn) - (fp * fn)
    den_sq = (tp + fp) * (tp + fn) * (tn + fp) * (tn + fn)
    return num / math.sqrt(den_sq) if den_sq > 0 else 0.0

def aggregate_mcc(*metric_groups):
    tp, tn, fp, fn = 0, 0, 0, 0
    for metrics in metric_groups:
        for values in metrics.values():
            tp += values['tp']
            tn += values['tn']
            fp += values['fp']
            fn += values['fn']
    return calculate_mcc(tp, tn, fp, fn)

def feature_mixup(features, labels, alpha=0.4):
    batch_size = features.size(0)
    lam = np.random.beta(alpha, alpha) if alpha > 0 else 1.0
    index = torch.randperm(batch_size, device=features.device)
    mixed_features = lam * features + (1 - lam) * features[index]
    mixed_labels = lam * labels + (1 - lam) * labels[index]
    return mixed_features, mixed_labels

def rdrop_kl_loss(logits1, logits2):
    kl1 = F.binary_cross_entropy_with_logits(logits1, torch.sigmoid(logits2).detach(), reduction='mean')
    kl2 = F.binary_cross_entropy_with_logits(logits2, torch.sigmoid(logits1).detach(), reduction='mean')
    return (kl1 + kl2) / 2

def enable_dropout(model):
    """
    Specifically tailored for PeptideNetwork to activate all sources of dropout
    during Test-Time Augmentation (TTA), including functional dropouts hidden 
    inside complex PyTorch modules.
    """
    for module in model.modules():
        class_name = module.__class__.__name__
        
        # 1. Standard explicit dropout layers (Dropout, Dropout1d, Dropout2d)
        if class_name.startswith('Dropout'):
            module.train()
            
        # 2. Cross-Attention functional dropout
        elif class_name == 'MultiheadAttention':
            module.train()
            
        # 3. Task Query Decoder functional dropout
        elif class_name in ['TransformerDecoder', 'TransformerDecoderLayer']:
            module.train()
            
        # 4. GRU functional dropout (applied between internal layers)
        elif class_name == 'GRU':
            module.train()


# --- SWA ---
swa_start_epoch = 30
swa_model = None
swa_n = 0

def update_swa(model_state, swa_state, n):
    if swa_state is None:
        return {k: v.clone() for k, v in model_state.items()}, 1
    for k in swa_state:
        swa_state[k] = (swa_state[k] * n + model_state[k]) / (n + 1)
    return swa_state, n + 1

# --- MAIN TRAINING LOOP ---
history_log = []
history_log_path = "cnn_removed.json"
best_model_path = "cnn_removed.pt"
best_val_mcc = -1.0
scaler = torch.amp.GradScaler('cuda')
patience_counter = 0
early_stop_patience = 20
mixup_alpha = 0.4
rdrop_alpha = 1.0
tta_passes = 5

func_names = [index_endpoint[i] for i in FUNC_INDICES]
bin_names = ["NON-FUNCTIONAL"]
bin_thresh = [0.5]
spec_thresh = [0.5] * len(func_names)

print("Training v19: Triple CrossAttn + Task Query Decoder + ASL")
print(f"  ASL(γ-=4, γ+=1, clip=0.05)")
print(f"  R-Drop α={rdrop_alpha} | Mixup α={mixup_alpha} | SWA from ep {swa_start_epoch}")
print(f"  Validation eval: TTA={tta_passes} | Test eval: simple (no TTA)")
print("=" * 70)
for epoch in range(1, epochs + 1):
    model.train()
    total_train_loss = 0.0

    for data in train_loader:
        input_ids = data['input_ids'].to(DEVICE)
        attention_mask = data['attention_mask'].to(DEVICE)
        labels = data['labels'].to(DEVICE)

        optimizer.zero_grad()

        # Binary label: 1 if NON-FUNCTIONAL, 0 if FUNCTIONAL
        target_bin = labels[:, NON_FUNC_IDX].unsqueeze(1).float()
        target_spec = labels[:, FUNC_INDICES]

        with torch.amp.autocast('cuda'):
            # Two augmented passes for R-Drop
            bin_features1, features1 = model.get_features(input_ids, attention_mask, mask_tokens=True)
            bin_features2, features2 = model.get_features(input_ids, attention_mask, mask_tokens=True)

            # 1. Clean predictions
            logits1_clean = model.multi_classify(features1)
            logits2_clean = model.multi_classify(features2)

            # 2. Binary classification (Always on the whole batch)
            binary_logits = model.binary_classify(bin_features2)
            binary_loss = binary_criterion(binary_logits, target_bin)
            ortho = model.ortho_loss()

            # --- THE FIX: Boolean Masking ---
            is_functional_mask = (target_bin == 0).view(-1).bool()
            
            if is_functional_mask.sum() > 0:
                # Slice out ONLY the functional peptides
                func_f1 = features1[is_functional_mask]
                func_targets = target_spec[is_functional_mask]
                func_logits1 = logits1_clean[is_functional_mask]
                func_logits2 = logits2_clean[is_functional_mask]

                # R-Drop only on functional
                rdrop_loss = rdrop_kl_loss(func_logits1, func_logits2)
                
                # Mixup only on functional
                mixed_f, mixed_y = feature_mixup(func_f1, func_targets, alpha=mixup_alpha)
                logits_mix = model.multi_classify(mixed_f)
                
                # ASL evaluates ONLY the functional slice
                asl_loss_mix = criterion(logits_mix, mixed_y)
                asl_loss_clean = criterion(func_logits2, func_targets)
                
                spec_loss = (asl_loss_mix + asl_loss_clean) / 2 + (rdrop_alpha * rdrop_loss) + (0.1 * ortho)
                loss = 0.3 * binary_loss + 0.7 * spec_loss
            else:
                # If batch is 100% non-functional
                loss = binary_loss + (0.1 * ortho)

        scaler.scale(loss).backward()
        scaler.unscale_(optimizer)
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
        scaler.step(optimizer)
        scaler.update()
        scheduler.step()
        ema.update(model)

        total_train_loss += loss.item() * input_ids.size(0)

    # --- SWA Update ---
    if epoch >= swa_start_epoch:
        swa_model, swa_n = update_swa(ema.shadow.state_dict(), swa_model, swa_n)

    if swa_model is not None and epoch >= swa_start_epoch:
        eval_model = copy.deepcopy(ema.shadow)
        eval_model.load_state_dict(swa_model)
        eval_model.eval()
    else:
        eval_model = ema.shadow
        eval_model.eval()

    # --- VALIDATION (TTA) ---
    total_val_loss = 0.0
    val_bin_y = []
    val_spec_y = []
    val_tta_bin_preds = [[] for _ in range(tta_passes)]
    val_tta_spec_preds = [[] for _ in range(tta_passes)]

    with torch.no_grad():
        for data in val_loader:
            input_ids = data['input_ids'].to(DEVICE)
            attention_mask = data['attention_mask'].to(DEVICE)
            labels = data['labels'].to(DEVICE)

            target_bin = labels[:, NON_FUNC_IDX].unsqueeze(1).float()
            target_spec = labels[:, FUNC_INDICES]

            with torch.amp.autocast('cuda'):
                pred_bin, pred_spec = eval_model(input_ids, attention_mask)
                loss_bin = binary_criterion(pred_bin, target_bin)

                is_functional_mask = (target_bin == 0).view(-1).bool()
                if is_functional_mask.sum() > 0:
                    loss_spec = criterion(pred_spec[is_functional_mask], target_spec[is_functional_mask])
                    loss_val = 0.3 * loss_bin + 0.7 * loss_spec
                else:
                    loss_val = loss_bin  # fallback if batch has no functional peptides

            total_val_loss += loss_val.item() * input_ids.size(0)
            
            # Append entire batch for both binary and specific targets
            val_bin_y.append(target_bin.cpu().numpy())
            val_spec_y.append(target_spec.cpu().numpy()) 
            
            val_tta_bin_preds[0].append(torch.sigmoid(pred_bin).detach().cpu().numpy())
            val_tta_spec_preds[0].append(torch.sigmoid(pred_spec).detach().cpu().numpy())

            if tta_passes > 1:
                enable_dropout(eval_model)
                for t in range(1, tta_passes):
                    with torch.amp.autocast('cuda'):
                        pred_bin_t, pred_spec_t = eval_model(input_ids, attention_mask)
                    val_tta_bin_preds[t].append(torch.sigmoid(pred_bin_t).detach().cpu().numpy())
                    val_tta_spec_preds[t].append(torch.sigmoid(pred_spec_t).detach().cpu().numpy())
                eval_model.eval()

    y_true_bin_val = np.concatenate(val_bin_y)
    y_pred_bin_val = np.mean([np.concatenate(pred_list) for pred_list in val_tta_bin_preds], axis=0)
    
    y_true_spec_val = np.concatenate(val_spec_y)
    raw_pred_spec_val = np.mean([np.concatenate(pred_list) for pred_list in val_tta_spec_preds], axis=0)

    # SOFT GATING: Scale specific predictions by functionality probability
    # y_pred_bin_val is probability of NON-FUNCTIONAL, so 1 - y_pred_bin_val is prob of FUNCTIONAL
    y_pred_spec_val = raw_pred_spec_val * (1 - y_pred_bin_val)

    # Compute optimal thresholds on Validation set
    opt_bin_thresh = find_optimal_thresholds(y_true_bin_val.reshape(-1, 1), y_pred_bin_val.reshape(-1, 1))
    opt_spec_thresh = find_optimal_thresholds(y_true_spec_val, raw_pred_spec_val)


    val_bin_metrics = calculate_complete_metrics(y_true_bin_val, y_pred_bin_val, opt_bin_thresh, bin_names)
    val_spec_metrics = calculate_complete_metrics(y_true_spec_val, y_pred_spec_val, opt_spec_thresh, func_names)
    val_total_mcc = aggregate_mcc(val_bin_metrics, val_spec_metrics)
    
    val_func_mccs = [metrics['mcc'] for metrics in val_spec_metrics.values() if not np.isnan(metrics['mcc'])]
    val_avg_func_mcc = sum(val_func_mccs) / len(val_func_mccs) if val_func_mccs else 0.0


    # --- TEST (TTA) ---
    total_test_loss = 0.0
    test_bin_y = []
    test_spec_y = []
    test_tta_bin_preds = [[] for _ in range(tta_passes)]
    test_tta_spec_preds = [[] for _ in range(tta_passes)]

    with torch.no_grad():
        for data in test_loader:
            input_ids = data['input_ids'].to(DEVICE)
            attention_mask = data['attention_mask'].to(DEVICE)
            labels = data['labels'].to(DEVICE)

            target_bin = labels[:, NON_FUNC_IDX].unsqueeze(1).float()
            target_spec = labels[:, FUNC_INDICES]

            with torch.amp.autocast('cuda'):
                pred_bin, pred_spec = eval_model(input_ids, attention_mask)
                loss_bin = binary_criterion(pred_bin, target_bin)
                
                is_functional_mask = (target_bin == 0).view(-1).bool()
                if is_functional_mask.sum() > 0:
                    loss_spec = criterion(pred_spec[is_functional_mask], target_spec[is_functional_mask])
                    loss_test = 0.3 * loss_bin + 0.7 * loss_spec
                else:
                    loss_test = loss_bin

            total_test_loss += loss_test.item() * input_ids.size(0)
            
            test_bin_y.append(target_bin.cpu().numpy())
            test_spec_y.append(target_spec.cpu().numpy())
            
            # First pass predictions
            test_tta_bin_preds[0].append(torch.sigmoid(pred_bin).detach().cpu().numpy())
            test_tta_spec_preds[0].append(torch.sigmoid(pred_spec).detach().cpu().numpy())

            # Additional TTA passes
            if tta_passes > 1:
                enable_dropout(eval_model)
                for t in range(1, tta_passes):
                    with torch.amp.autocast('cuda'):
                        pred_bin_t, pred_spec_t = eval_model(input_ids, attention_mask)
                    test_tta_bin_preds[t].append(torch.sigmoid(pred_bin_t).detach().cpu().numpy())
                    test_tta_spec_preds[t].append(torch.sigmoid(pred_spec_t).detach().cpu().numpy())
                eval_model.eval()

    y_true_bin_test = np.concatenate(test_bin_y)
    y_pred_bin_test = np.mean([np.concatenate(pred_list) for pred_list in test_tta_bin_preds], axis=0)
    
    y_true_spec_test = np.concatenate(test_spec_y)
    raw_pred_spec_test = np.mean([np.concatenate(pred_list) for pred_list in test_tta_spec_preds], axis=0)

    # SOFT GATING for Test
    y_pred_spec_test = raw_pred_spec_test * (1 - y_pred_bin_test)

    test_bin_metrics = calculate_complete_metrics(y_true_bin_test, y_pred_bin_test, opt_bin_thresh, bin_names)
    test_spec_metrics = calculate_complete_metrics(y_true_spec_test, y_pred_spec_test, opt_spec_thresh, func_names)
    test_total_mcc = aggregate_mcc(test_bin_metrics, test_spec_metrics)

    test_func_mccs = [metrics['mcc'] for metrics in test_spec_metrics.values() if not np.isnan(metrics['mcc'])]
    test_avg_func_mcc = sum(test_func_mccs) / len(test_func_mccs) if test_func_mccs else 0.0

    avg_train_loss = total_train_loss / len(train_loader.dataset)
    avg_val_loss = total_val_loss / len(val_loader.dataset)
    avg_test_loss = total_test_loss / len(test_loader.dataset)

    if val_avg_func_mcc > best_val_mcc:
        best_val_mcc = val_avg_func_mcc
        patience_counter = 0
        torch.save(eval_model.state_dict(), best_model_path)
        marker = " >>> BEST <<<"
    else:
        patience_counter += 1
        marker = ""

    lr_now = optimizer.param_groups[0]['lr']
    swa_tag = f" [SWA n={swa_n}]" if epoch >= swa_start_epoch else ""
    print(f"Ep {epoch:02d}/{epochs} | LR: {lr_now:.1e} | Train: {avg_train_loss:.4f} | Val: {avg_val_loss:.4f} | Test: {avg_test_loss:.4f}{swa_tag}")
    print(f"  MCC -> Func Avg (Val): {val_avg_func_mcc:.4f} | Func Avg (Test): {test_avg_func_mcc:.4f} | Pat: {patience_counter}/{early_stop_patience}{marker}")
    print(f"  Overall Total MCC -> Val: {val_total_mcc:.4f} | Test: {test_total_mcc:.4f}")
    print(f"  NON-FUNCTIONAL MCC -> Val: {val_bin_metrics['NON-FUNCTIONAL']['mcc']:.4f} | Test: {test_bin_metrics['NON-FUNCTIONAL']['mcc']:.4f}")
    
    for name in func_names:
        val_mcc = val_spec_metrics[name]['mcc'] if name in val_spec_metrics else float('nan')
        test_mcc = test_spec_metrics[name]['mcc'] if name in test_spec_metrics else float('nan')
        print(f"  {name:16s}: Val MCC={val_mcc:.4f} | Test MCC={test_mcc:.4f}")
    print("-" * 70)

    epoch_data = {
        "epoch": epoch,
        "train_loss": avg_train_loss,
        "val_loss": avg_val_loss,
        "test_loss": avg_test_loss,
        "val_total_mcc": float(val_total_mcc),
        "test_total_mcc": float(test_total_mcc),
        "thresholds": {
            "binary": opt_bin_thresh,
            "functional": opt_spec_thresh,
        },
        "val_metrics": {**val_bin_metrics, **val_spec_metrics},
        "test_metrics": {**test_bin_metrics, **test_spec_metrics},
    }
    history_log.append(epoch_data)
    with open(history_log_path, "w") as f:
        json.dump(history_log, f, indent=2)

    if patience_counter >= early_stop_patience:
        print(f"\nEarly stopping at epoch {epoch}!")
        break

    if swa_model is not None and epoch >= swa_start_epoch:
        del eval_model

print(f"\nTraining Complete! Best Val MCC: {best_val_mcc:.4f}")
# Out:
# Training v19: Triple CrossAttn + Task Query Decoder + ASL
#   ASL(γ-=4, γ+=1, clip=0.05)
#   R-Drop α=1.0 | Mixup α=0.4 | SWA from ep 30
#   Validation eval: TTA=5 | Test eval: simple (no TTA)
# ======================================================================
# Ep 01/80 | LR: 3.3e-06 | Train: 0.5695 | Val: 0.0712 | Test: 0.0709
#   MCC -> Func Avg (Val): 0.2448 | Func Avg (Test): 0.2377 | Pat: 0/20 >>> BEST <<<
#   Overall Total MCC -> Val: 0.7417 | Test: 0.7310
#   NON-FUNCTIONAL MCC -> Val: 0.9180 | Test: 0.9155
#   anti-bacterial  : Val MCC=0.6366 | Test MCC=0.6549
#   anti-cancer     : Val MCC=0.2963 | Test MCC=0.2972
#   anti-fungal     : Val MCC=0.1927 | Test MCC=0.1842
#   anti-parasitic  : Val MCC=0.1311 | Test MCC=0.1576
#   anti-viral      : Val MCC=0.2215 | Test MCC=0.2635
#   cell-cell-communication: Val MCC=0.0000 | Test MCC=0.0000
#   drug-delivery   : Val MCC=0.1353 | Test MCC=0.0779
#   immunological   : Val MCC=0.2703 | Test MCC=0.2485
#   inhibitor       : Val MCC=0.0768 | Test MCC=0.0817
#   metabolic       : Val MCC=0.0675 | Test MCC=0.0502
#   other-functional: Val MCC=-0.0021 | Test MCC=0.0076
#   signal-peptide  : Val MCC=0.6248 | Test MCC=0.6046
#   toxic           : Val MCC=0.5320 | Test MCC=0.4616
# ----------------------------------------------------------------------
# Ep 02/80 | LR: 6.7e-06 | Train: 0.5217 | Val: 0.0610 | Test: 0.0595
#   MCC -> Func Avg (Val): 0.3676 | Func Avg (Test): 0.3716 | Pat: 0/20 >>> BEST <<<
#   Overall Total MCC -> Val: 0.7529 | Test: 0.7453
#   NON-FUNCTIONAL MCC -> Val: 0.9291 | Test: 0.9286
#   anti-bacterial  : Val MCC=0.6856 | Test MCC=0.7124
#   anti-cancer     : Val MCC=0.3420 | Test MCC=0.3624
#   anti-fungal     : Val MCC=0.3805 | Test MCC=0.4267
#   anti-parasitic  : Val MCC=0.2162 | Test MCC=0.2316
#   anti-viral      : Val MCC=0.3358 | Test MCC=0.3685
#   cell-cell-communication: Val MCC=0.0840 | Test MCC=0.2410
#   drug-delivery   : Val MCC=0.2494 | Test MCC=0.1448
#   immunological   : Val MCC=0.3951 | Test MCC=0.3569
#   inhibitor       : Val MCC=0.2429 | Test MCC=0.2479
#   metabolic       : Val MCC=0.3565 | Test MCC=0.2412
#   other-functional: Val MCC=0.1446 | Test MCC=0.2140
#   signal-peptide  : Val MCC=0.7518 | Test MCC=0.7363
#   toxic           : Val MCC=0.5941 | Test MCC=0.5470
# ----------------------------------------------------------------------
# Ep 03/80 | LR: 1.0e-05 | Train: 0.5106 | Val: 0.0564 | Test: 0.0540
#   MCC -> Func Avg (Val): 0.4185 | Func Avg (Test): 0.4284 | Pat: 0/20 >>> BEST <<<
#   Overall Total MCC -> Val: 0.7519 | Test: 0.7440
#   NON-FUNCTIONAL MCC -> Val: 0.9335 | Test: 0.9343
#   anti-bacterial  : Val MCC=0.6799 | Test MCC=0.6970
#   anti-cancer     : Val MCC=0.3788 | Test MCC=0.3898
#   anti-fungal     : Val MCC=0.4279 | Test MCC=0.4412
#   anti-parasitic  : Val MCC=0.2426 | Test MCC=0.3063
#   anti-viral      : Val MCC=0.3309 | Test MCC=0.4073
#   cell-cell-communication: Val MCC=0.2893 | Test MCC=0.4179
#   drug-delivery   : Val MCC=0.2865 | Test MCC=0.2220
#   immunological   : Val MCC=0.4286 | Test MCC=0.4121
#   inhibitor       : Val MCC=0.3181 | Test MCC=0.2806
#   metabolic       : Val MCC=0.4565 | Test MCC=0.3558
#   other-functional: Val MCC=0.1815 | Test MCC=0.2731
#   signal-peptide  : Val MCC=0.7862 | Test MCC=0.7692
#   toxic           : Val MCC=0.6338 | Test MCC=0.5974
# ----------------------------------------------------------------------
# Ep 04/80 | LR: 1.0e-05 | Train: 0.5029 | Val: 0.0537 | Test: 0.0509
#   MCC -> Func Avg (Val): 0.4660 | Func Avg (Test): 0.4772 | Pat: 0/20 >>> BEST <<<
#   Overall Total MCC -> Val: 0.7661 | Test: 0.7624
#   NON-FUNCTIONAL MCC -> Val: 0.9367 | Test: 0.9386
#   anti-bacterial  : Val MCC=0.6927 | Test MCC=0.7137
#   anti-cancer     : Val MCC=0.4036 | Test MCC=0.4331
#   anti-fungal     : Val MCC=0.4499 | Test MCC=0.4653
#   anti-parasitic  : Val MCC=0.3729 | Test MCC=0.4299
#   anti-viral      : Val MCC=0.3465 | Test MCC=0.4451
#   cell-cell-communication: Val MCC=0.4478 | Test MCC=0.5204
#   drug-delivery   : Val MCC=0.3541 | Test MCC=0.2403
#   immunological   : Val MCC=0.4740 | Test MCC=0.4735
#   inhibitor       : Val MCC=0.3444 | Test MCC=0.2978
#   metabolic       : Val MCC=0.5021 | Test MCC=0.4368
#   other-functional: Val MCC=0.1887 | Test MCC=0.3147
#   signal-peptide  : Val MCC=0.8179 | Test MCC=0.7995
#   toxic           : Val MCC=0.6633 | Test MCC=0.6332
# ----------------------------------------------------------------------
# Ep 05/80 | LR: 1.0e-05 | Train: 0.4968 | Val: 0.0523 | Test: 0.0493
#   MCC -> Func Avg (Val): 0.4831 | Func Avg (Test): 0.4952 | Pat: 0/20 >>> BEST <<<
#   Overall Total MCC -> Val: 0.7797 | Test: 0.7765
#   NON-FUNCTIONAL MCC -> Val: 0.9393 | Test: 0.9398
#   anti-bacterial  : Val MCC=0.6930 | Test MCC=0.7229
#   anti-cancer     : Val MCC=0.4133 | Test MCC=0.4462
#   anti-fungal     : Val MCC=0.4713 | Test MCC=0.4770
#   anti-parasitic  : Val MCC=0.3881 | Test MCC=0.4630
#   anti-viral      : Val MCC=0.4167 | Test MCC=0.4569
#   cell-cell-communication: Val MCC=0.4719 | Test MCC=0.5140
#   drug-delivery   : Val MCC=0.3556 | Test MCC=0.2659
#   immunological   : Val MCC=0.4765 | Test MCC=0.5037
#   inhibitor       : Val MCC=0.3563 | Test MCC=0.3106
#   metabolic       : Val MCC=0.5044 | Test MCC=0.4503
#   other-functional: Val MCC=0.2203 | Test MCC=0.3630
#   signal-peptide  : Val MCC=0.8301 | Test MCC=0.8115
#   toxic           : Val MCC=0.6827 | Test MCC=0.6524
# ----------------------------------------------------------------------
# Ep 06/80 | LR: 1.0e-05 | Train: 0.4923 | Val: 0.0514 | Test: 0.0482
#   MCC -> Func Avg (Val): 0.4887 | Func Avg (Test): 0.5062 | Pat: 0/20 >>> BEST <<<
#   Overall Total MCC -> Val: 0.7841 | Test: 0.7821
#   NON-FUNCTIONAL MCC -> Val: 0.9409 | Test: 0.9406
#   anti-bacterial  : Val MCC=0.7059 | Test MCC=0.7365
#   anti-cancer     : Val MCC=0.4346 | Test MCC=0.4612
#   anti-fungal     : Val MCC=0.4760 | Test MCC=0.4854
#   anti-parasitic  : Val MCC=0.3991 | Test MCC=0.4800
#   anti-viral      : Val MCC=0.4181 | Test MCC=0.4618
#   cell-cell-communication: Val MCC=0.4431 | Test MCC=0.4909
#   drug-delivery   : Val MCC=0.3592 | Test MCC=0.2659
#   immunological   : Val MCC=0.4829 | Test MCC=0.5252
#   inhibitor       : Val MCC=0.3689 | Test MCC=0.3074
#   metabolic       : Val MCC=0.5169 | Test MCC=0.4971
#   other-functional: Val MCC=0.2207 | Test MCC=0.3895
#   signal-peptide  : Val MCC=0.8324 | Test MCC=0.8183
#   toxic           : Val MCC=0.6957 | Test MCC=0.6609
# ----------------------------------------------------------------------
# Ep 07/80 | LR: 9.9e-06 | Train: 0.4887 | Val: 0.0509 | Test: 0.0474
#   MCC -> Func Avg (Val): 0.4933 | Func Avg (Test): 0.5138 | Pat: 0/20 >>> BEST <<<
#   Overall Total MCC -> Val: 0.7891 | Test: 0.7878
#   NON-FUNCTIONAL MCC -> Val: 0.9415 | Test: 0.9438
#   anti-bacterial  : Val MCC=0.7158 | Test MCC=0.7489
#   anti-cancer     : Val MCC=0.4428 | Test MCC=0.4642
#   anti-fungal     : Val MCC=0.4851 | Test MCC=0.4899
#   anti-parasitic  : Val MCC=0.3614 | Test MCC=0.4736
#   anti-viral      : Val MCC=0.4097 | Test MCC=0.4601
#   cell-cell-communication: Val MCC=0.4598 | Test MCC=0.4932
#   drug-delivery   : Val MCC=0.3615 | Test MCC=0.2770
#   immunological   : Val MCC=0.4962 | Test MCC=0.5404
#   inhibitor       : Val MCC=0.3799 | Test MCC=0.3243
#   metabolic       : Val MCC=0.5520 | Test MCC=0.5330
#   other-functional: Val MCC=0.2234 | Test MCC=0.3974
#   signal-peptide  : Val MCC=0.8202 | Test MCC=0.8091
#   toxic           : Val MCC=0.7054 | Test MCC=0.6678
# ----------------------------------------------------------------------
# Ep 08/80 | LR: 9.9e-06 | Train: 0.4852 | Val: 0.0510 | Test: 0.0472
#   MCC -> Func Avg (Val): 0.5071 | Func Avg (Test): 0.5268 | Pat: 0/20 >>> BEST <<<
#   Overall Total MCC -> Val: 0.8010 | Test: 0.8005
#   NON-FUNCTIONAL MCC -> Val: 0.9424 | Test: 0.9438
#   anti-bacterial  : Val MCC=0.7206 | Test MCC=0.7540
#   anti-cancer     : Val MCC=0.4570 | Test MCC=0.4741
#   anti-fungal     : Val MCC=0.4914 | Test MCC=0.5156
#   anti-parasitic  : Val MCC=0.4015 | Test MCC=0.5027
#   anti-viral      : Val MCC=0.4116 | Test MCC=0.4683
#   cell-cell-communication: Val MCC=0.5127 | Test MCC=0.5181
#   drug-delivery   : Val MCC=0.3679 | Test MCC=0.2970
#   immunological   : Val MCC=0.5287 | Test MCC=0.5477
#   inhibitor       : Val MCC=0.3848 | Test MCC=0.3287
#   metabolic       : Val MCC=0.5440 | Test MCC=0.5340
#   other-functional: Val MCC=0.2311 | Test MCC=0.4148
#   signal-peptide  : Val MCC=0.8238 | Test MCC=0.8141
#   toxic           : Val MCC=0.7167 | Test MCC=0.6795
# ----------------------------------------------------------------------
# Ep 09/80 | LR: 9.9e-06 | Train: 0.4825 | Val: 0.0504 | Test: 0.0471
#   MCC -> Func Avg (Val): 0.5212 | Func Avg (Test): 0.5350 | Pat: 0/20 >>> BEST <<<
#   Overall Total MCC -> Val: 0.8042 | Test: 0.8024
#   NON-FUNCTIONAL MCC -> Val: 0.9433 | Test: 0.9439
#   anti-bacterial  : Val MCC=0.7278 | Test MCC=0.7660
#   anti-cancer     : Val MCC=0.4656 | Test MCC=0.4766
#   anti-fungal     : Val MCC=0.4984 | Test MCC=0.5168
#   anti-parasitic  : Val MCC=0.4747 | Test MCC=0.5006
#   anti-viral      : Val MCC=0.4342 | Test MCC=0.4837
#   cell-cell-communication: Val MCC=0.5424 | Test MCC=0.5310
#   drug-delivery   : Val MCC=0.3801 | Test MCC=0.3184
#   immunological   : Val MCC=0.5271 | Test MCC=0.5546
#   inhibitor       : Val MCC=0.3504 | Test MCC=0.3160
#   metabolic       : Val MCC=0.5660 | Test MCC=0.5519
#   other-functional: Val MCC=0.2516 | Test MCC=0.4276
#   signal-peptide  : Val MCC=0.8393 | Test MCC=0.8325
#   toxic           : Val MCC=0.7174 | Test MCC=0.6792
# ----------------------------------------------------------------------
# Ep 10/80 | LR: 9.8e-06 | Train: 0.4794 | Val: 0.0506 | Test: 0.0468
#   MCC -> Func Avg (Val): 0.5284 | Func Avg (Test): 0.5442 | Pat: 0/20 >>> BEST <<<
#   Overall Total MCC -> Val: 0.8099 | Test: 0.8106
#   NON-FUNCTIONAL MCC -> Val: 0.9429 | Test: 0.9441
#   anti-bacterial  : Val MCC=0.7282 | Test MCC=0.7662
#   anti-cancer     : Val MCC=0.4730 | Test MCC=0.4889
#   anti-fungal     : Val MCC=0.5150 | Test MCC=0.5313
#   anti-parasitic  : Val MCC=0.4853 | Test MCC=0.5380
#   anti-viral      : Val MCC=0.4361 | Test MCC=0.4892
#   cell-cell-communication: Val MCC=0.5601 | Test MCC=0.5478
#   drug-delivery   : Val MCC=0.3813 | Test MCC=0.3190
#   immunological   : Val MCC=0.5330 | Test MCC=0.5515
#   inhibitor       : Val MCC=0.3574 | Test MCC=0.3220
#   metabolic       : Val MCC=0.5646 | Test MCC=0.5569
#   other-functional: Val MCC=0.2721 | Test MCC=0.4361
#   signal-peptide  : Val MCC=0.8463 | Test MCC=0.8387
#   toxic           : Val MCC=0.7173 | Test MCC=0.6885
# ----------------------------------------------------------------------
# Ep 11/80 | LR: 9.7e-06 | Train: 0.4773 | Val: 0.0500 | Test: 0.0470
#   MCC -> Func Avg (Val): 0.5371 | Func Avg (Test): 0.5506 | Pat: 0/20 >>> BEST <<<
#   Overall Total MCC -> Val: 0.8129 | Test: 0.8127
#   NON-FUNCTIONAL MCC -> Val: 0.9439 | Test: 0.9447
#   anti-bacterial  : Val MCC=0.7341 | Test MCC=0.7724
#   anti-cancer     : Val MCC=0.4799 | Test MCC=0.4907
#   anti-fungal     : Val MCC=0.5022 | Test MCC=0.5306
#   anti-parasitic  : Val MCC=0.5073 | Test MCC=0.5422
#   anti-viral      : Val MCC=0.4781 | Test MCC=0.4988
#   cell-cell-communication: Val MCC=0.5858 | Test MCC=0.5641
#   drug-delivery   : Val MCC=0.3924 | Test MCC=0.3415
#   immunological   : Val MCC=0.5392 | Test MCC=0.5539
#   inhibitor       : Val MCC=0.3591 | Test MCC=0.3312
#   metabolic       : Val MCC=0.5597 | Test MCC=0.5605
#   other-functional: Val MCC=0.2761 | Test MCC=0.4421
#   signal-peptide  : Val MCC=0.8465 | Test MCC=0.8401
#   toxic           : Val MCC=0.7223 | Test MCC=0.6902
# ----------------------------------------------------------------------
# Ep 12/80 | LR: 9.7e-06 | Train: 0.4750 | Val: 0.0507 | Test: 0.0476
#   MCC -> Func Avg (Val): 0.5424 | Func Avg (Test): 0.5476 | Pat: 0/20 >>> BEST <<<
#   Overall Total MCC -> Val: 0.8100 | Test: 0.8096
#   NON-FUNCTIONAL MCC -> Val: 0.9443 | Test: 0.9441
#   anti-bacterial  : Val MCC=0.7399 | Test MCC=0.7754
#   anti-cancer     : Val MCC=0.4845 | Test MCC=0.4956
#   anti-fungal     : Val MCC=0.5098 | Test MCC=0.5372
#   anti-parasitic  : Val MCC=0.5150 | Test MCC=0.5471
#   anti-viral      : Val MCC=0.4415 | Test MCC=0.4978
#   cell-cell-communication: Val MCC=0.5956 | Test MCC=0.5576
#   drug-delivery   : Val MCC=0.3954 | Test MCC=0.3107
#   immunological   : Val MCC=0.5469 | Test MCC=0.5549
#   inhibitor       : Val MCC=0.4180 | Test MCC=0.3377
#   metabolic       : Val MCC=0.5495 | Test MCC=0.5497
#   other-functional: Val MCC=0.2968 | Test MCC=0.4330
#   signal-peptide  : Val MCC=0.8336 | Test MCC=0.8268
#   toxic           : Val MCC=0.7252 | Test MCC=0.6956
# ----------------------------------------------------------------------
# Ep 13/80 | LR: 9.6e-06 | Train: 0.4731 | Val: 0.0510 | Test: 0.0476
#   MCC -> Func Avg (Val): 0.5442 | Func Avg (Test): 0.5545 | Pat: 0/20 >>> BEST <<<
#   Overall Total MCC -> Val: 0.8151 | Test: 0.8164
#   NON-FUNCTIONAL MCC -> Val: 0.9441 | Test: 0.9455
#   anti-bacterial  : Val MCC=0.7466 | Test MCC=0.7796
#   anti-cancer     : Val MCC=0.4854 | Test MCC=0.5039
#   anti-fungal     : Val MCC=0.5103 | Test MCC=0.5420
#   anti-parasitic  : Val MCC=0.5077 | Test MCC=0.5345
#   anti-viral      : Val MCC=0.4974 | Test MCC=0.5286
#   cell-cell-communication: Val MCC=0.5581 | Test MCC=0.5276
#   drug-delivery   : Val MCC=0.3903 | Test MCC=0.3686
#   immunological   : Val MCC=0.5427 | Test MCC=0.5649
#   inhibitor       : Val MCC=0.4231 | Test MCC=0.3470
#   metabolic       : Val MCC=0.5529 | Test MCC=0.5609
#   other-functional: Val MCC=0.2977 | Test MCC=0.4271
#   signal-peptide  : Val MCC=0.8362 | Test MCC=0.8289
#   toxic           : Val MCC=0.7263 | Test MCC=0.6950
# ----------------------------------------------------------------------
# Ep 14/80 | LR: 9.5e-06 | Train: 0.4707 | Val: 0.0519 | Test: 0.0483
#   MCC -> Func Avg (Val): 0.5532 | Func Avg (Test): 0.5584 | Pat: 0/20 >>> BEST <<<
#   Overall Total MCC -> Val: 0.8165 | Test: 0.8173
#   NON-FUNCTIONAL MCC -> Val: 0.9423 | Test: 0.9449
#   anti-bacterial  : Val MCC=0.7499 | Test MCC=0.7878
#   anti-cancer     : Val MCC=0.4875 | Test MCC=0.5062
#   anti-fungal     : Val MCC=0.5129 | Test MCC=0.5403
#   anti-parasitic  : Val MCC=0.5212 | Test MCC=0.5362
#   anti-viral      : Val MCC=0.4962 | Test MCC=0.5183
#   cell-cell-communication: Val MCC=0.5697 | Test MCC=0.5433
#   drug-delivery   : Val MCC=0.4125 | Test MCC=0.3524
#   immunological   : Val MCC=0.5491 | Test MCC=0.5721
#   inhibitor       : Val MCC=0.4288 | Test MCC=0.3450
#   metabolic       : Val MCC=0.5904 | Test MCC=0.5786
#   other-functional: Val MCC=0.2995 | Test MCC=0.4386
#   signal-peptide  : Val MCC=0.8507 | Test MCC=0.8440
#   toxic           : Val MCC=0.7237 | Test MCC=0.6963
# ----------------------------------------------------------------------
# Ep 15/80 | LR: 9.4e-06 | Train: 0.4689 | Val: 0.0523 | Test: 0.0490
#   MCC -> Func Avg (Val): 0.5562 | Func Avg (Test): 0.5684 | Pat: 0/20 >>> BEST <<<
#   Overall Total MCC -> Val: 0.8233 | Test: 0.8245
#   NON-FUNCTIONAL MCC -> Val: 0.9428 | Test: 0.9451
#   anti-bacterial  : Val MCC=0.7589 | Test MCC=0.7919
#   anti-cancer     : Val MCC=0.4946 | Test MCC=0.5085
#   anti-fungal     : Val MCC=0.5028 | Test MCC=0.5448
#   anti-parasitic  : Val MCC=0.5298 | Test MCC=0.5507
#   anti-viral      : Val MCC=0.5095 | Test MCC=0.5244
#   cell-cell-communication: Val MCC=0.5601 | Test MCC=0.5422
#   drug-delivery   : Val MCC=0.4209 | Test MCC=0.3873
#   immunological   : Val MCC=0.5350 | Test MCC=0.5790
#   inhibitor       : Val MCC=0.4384 | Test MCC=0.3529
#   metabolic       : Val MCC=0.6106 | Test MCC=0.5876
#   other-functional: Val MCC=0.2873 | Test MCC=0.4748
#   signal-peptide  : Val MCC=0.8511 | Test MCC=0.8474
#   toxic           : Val MCC=0.7317 | Test MCC=0.6972
# ----------------------------------------------------------------------
# Ep 16/80 | LR: 9.3e-06 | Train: 0.4671 | Val: 0.0524 | Test: 0.0492
#   MCC -> Func Avg (Val): 0.5629 | Func Avg (Test): 0.5700 | Pat: 0/20 >>> BEST <<<
#   Overall Total MCC -> Val: 0.8195 | Test: 0.8192
#   NON-FUNCTIONAL MCC -> Val: 0.9442 | Test: 0.9443
#   anti-bacterial  : Val MCC=0.7591 | Test MCC=0.7942
#   anti-cancer     : Val MCC=0.4996 | Test MCC=0.5111
#   anti-fungal     : Val MCC=0.5224 | Test MCC=0.5405
#   anti-parasitic  : Val MCC=0.5388 | Test MCC=0.5583
#   anti-viral      : Val MCC=0.4878 | Test MCC=0.5250
#   cell-cell-communication: Val MCC=0.5790 | Test MCC=0.5549
#   drug-delivery   : Val MCC=0.4335 | Test MCC=0.3988
#   immunological   : Val MCC=0.5534 | Test MCC=0.5726
#   inhibitor       : Val MCC=0.4567 | Test MCC=0.3800
#   metabolic       : Val MCC=0.6106 | Test MCC=0.5905
#   other-functional: Val MCC=0.3050 | Test MCC=0.4474
#   signal-peptide  : Val MCC=0.8391 | Test MCC=0.8360
#   toxic           : Val MCC=0.7325 | Test MCC=0.7011
# ----------------------------------------------------------------------
# Ep 17/80 | LR: 9.2e-06 | Train: 0.4656 | Val: 0.0528 | Test: 0.0491
#   MCC -> Func Avg (Val): 0.5621 | Func Avg (Test): 0.5701 | Pat: 1/20
#   Overall Total MCC -> Val: 0.8201 | Test: 0.8199
#   NON-FUNCTIONAL MCC -> Val: 0.9443 | Test: 0.9441
#   anti-bacterial  : Val MCC=0.7156 | Test MCC=0.7492
#   anti-cancer     : Val MCC=0.5090 | Test MCC=0.5150
#   anti-fungal     : Val MCC=0.5123 | Test MCC=0.5565
#   anti-parasitic  : Val MCC=0.5426 | Test MCC=0.5583
#   anti-viral      : Val MCC=0.4877 | Test MCC=0.5382
#   cell-cell-communication: Val MCC=0.5807 | Test MCC=0.5557
#   drug-delivery   : Val MCC=0.4415 | Test MCC=0.4128
#   immunological   : Val MCC=0.5562 | Test MCC=0.5797
#   inhibitor       : Val MCC=0.4340 | Test MCC=0.3683
#   metabolic       : Val MCC=0.6181 | Test MCC=0.5935
#   other-functional: Val MCC=0.3324 | Test MCC=0.4475
#   signal-peptide  : Val MCC=0.8452 | Test MCC=0.8384
#   toxic           : Val MCC=0.7314 | Test MCC=0.6984
# ----------------------------------------------------------------------
# Ep 18/80 | LR: 9.1e-06 | Train: 0.4634 | Val: 0.0541 | Test: 0.0502
#   MCC -> Func Avg (Val): 0.5645 | Func Avg (Test): 0.5746 | Pat: 0/20 >>> BEST <<<
#   Overall Total MCC -> Val: 0.8248 | Test: 0.8257
#   NON-FUNCTIONAL MCC -> Val: 0.9435 | Test: 0.9438
#   anti-bacterial  : Val MCC=0.7649 | Test MCC=0.8007
#   anti-cancer     : Val MCC=0.5043 | Test MCC=0.5162
#   anti-fungal     : Val MCC=0.5100 | Test MCC=0.5569
#   anti-parasitic  : Val MCC=0.5398 | Test MCC=0.5548
#   anti-viral      : Val MCC=0.4779 | Test MCC=0.5221
#   cell-cell-communication: Val MCC=0.6147 | Test MCC=0.5968
#   drug-delivery   : Val MCC=0.4335 | Test MCC=0.4230
#   immunological   : Val MCC=0.5392 | Test MCC=0.5623
#   inhibitor       : Val MCC=0.4442 | Test MCC=0.3512
#   metabolic       : Val MCC=0.6226 | Test MCC=0.6017
#   other-functional: Val MCC=0.3087 | Test MCC=0.4448
#   signal-peptide  : Val MCC=0.8435 | Test MCC=0.8391
#   toxic           : Val MCC=0.7354 | Test MCC=0.7000
# ----------------------------------------------------------------------
# Ep 19/80 | LR: 9.0e-06 | Train: 0.4625 | Val: 0.0540 | Test: 0.0506
#   MCC -> Func Avg (Val): 0.5644 | Func Avg (Test): 0.5778 | Pat: 1/20
#   Overall Total MCC -> Val: 0.8262 | Test: 0.8273
#   NON-FUNCTIONAL MCC -> Val: 0.9437 | Test: 0.9443
#   anti-bacterial  : Val MCC=0.7644 | Test MCC=0.8015
#   anti-cancer     : Val MCC=0.5042 | Test MCC=0.5121
#   anti-fungal     : Val MCC=0.5188 | Test MCC=0.5583
#   anti-parasitic  : Val MCC=0.5453 | Test MCC=0.5597
#   anti-viral      : Val MCC=0.4716 | Test MCC=0.5206
#   cell-cell-communication: Val MCC=0.5759 | Test MCC=0.5646
#   drug-delivery   : Val MCC=0.4543 | Test MCC=0.4386
#   immunological   : Val MCC=0.5288 | Test MCC=0.5669
#   inhibitor       : Val MCC=0.4319 | Test MCC=0.3694
#   metabolic       : Val MCC=0.6265 | Test MCC=0.5981
#   other-functional: Val MCC=0.3215 | Test MCC=0.4616
#   signal-peptide  : Val MCC=0.8567 | Test MCC=0.8539
#   toxic           : Val MCC=0.7372 | Test MCC=0.7066
# ----------------------------------------------------------------------
# Ep 20/80 | LR: 8.8e-06 | Train: 0.4606 | Val: 0.0560 | Test: 0.0513
#   MCC -> Func Avg (Val): 0.5643 | Func Avg (Test): 0.5773 | Pat: 2/20
#   Overall Total MCC -> Val: 0.8260 | Test: 0.8270
#   NON-FUNCTIONAL MCC -> Val: 0.9423 | Test: 0.9452
#   anti-bacterial  : Val MCC=0.7649 | Test MCC=0.8030
#   anti-cancer     : Val MCC=0.5094 | Test MCC=0.5202
#   anti-fungal     : Val MCC=0.5251 | Test MCC=0.5516
#   anti-parasitic  : Val MCC=0.5385 | Test MCC=0.5620
#   anti-viral      : Val MCC=0.4322 | Test MCC=0.5024
#   cell-cell-communication: Val MCC=0.5978 | Test MCC=0.5765
#   drug-delivery   : Val MCC=0.4551 | Test MCC=0.4448
#   immunological   : Val MCC=0.5432 | Test MCC=0.5514
#   inhibitor       : Val MCC=0.4647 | Test MCC=0.3635
#   metabolic       : Val MCC=0.6217 | Test MCC=0.5990
#   other-functional: Val MCC=0.3080 | Test MCC=0.4862
#   signal-peptide  : Val MCC=0.8583 | Test MCC=0.8555
#   toxic           : Val MCC=0.7175 | Test MCC=0.6884
# ----------------------------------------------------------------------
# Ep 21/80 | LR: 8.7e-06 | Train: 0.4592 | Val: 0.0566 | Test: 0.0522
#   MCC -> Func Avg (Val): 0.5608 | Func Avg (Test): 0.5747 | Pat: 3/20
#   Overall Total MCC -> Val: 0.8231 | Test: 0.8241
#   NON-FUNCTIONAL MCC -> Val: 0.9423 | Test: 0.9439
#   anti-bacterial  : Val MCC=0.7673 | Test MCC=0.8026
#   anti-cancer     : Val MCC=0.5112 | Test MCC=0.5187
#   anti-fungal     : Val MCC=0.5236 | Test MCC=0.5495
#   anti-parasitic  : Val MCC=0.5500 | Test MCC=0.5564
#   anti-viral      : Val MCC=0.4631 | Test MCC=0.5259
#   cell-cell-communication: Val MCC=0.5960 | Test MCC=0.5630
#   drug-delivery   : Val MCC=0.4639 | Test MCC=0.4572
#   immunological   : Val MCC=0.5402 | Test MCC=0.5660
#   inhibitor       : Val MCC=0.4274 | Test MCC=0.3753
#   metabolic       : Val MCC=0.5620 | Test MCC=0.5674
#   other-functional: Val MCC=0.3164 | Test MCC=0.4572
#   signal-peptide  : Val MCC=0.8477 | Test MCC=0.8432
#   toxic           : Val MCC=0.7215 | Test MCC=0.6892
# ----------------------------------------------------------------------
# Ep 22/80 | LR: 8.6e-06 | Train: 0.4577 | Val: 0.0573 | Test: 0.0533
#   MCC -> Func Avg (Val): 0.5679 | Func Avg (Test): 0.5768 | Pat: 0/20 >>> BEST <<<
#   Overall Total MCC -> Val: 0.8247 | Test: 0.8249
#   NON-FUNCTIONAL MCC -> Val: 0.9427 | Test: 0.9451
#   anti-bacterial  : Val MCC=0.7391 | Test MCC=0.7660
#   anti-cancer     : Val MCC=0.5156 | Test MCC=0.5241
#   anti-fungal     : Val MCC=0.4962 | Test MCC=0.5397
#   anti-parasitic  : Val MCC=0.5473 | Test MCC=0.5607
#   anti-viral      : Val MCC=0.5062 | Test MCC=0.5376
#   cell-cell-communication: Val MCC=0.5607 | Test MCC=0.5368
#   drug-delivery   : Val MCC=0.4529 | Test MCC=0.4628
#   immunological   : Val MCC=0.5533 | Test MCC=0.5814
#   inhibitor       : Val MCC=0.4575 | Test MCC=0.3695
#   metabolic       : Val MCC=0.6196 | Test MCC=0.6029
#   other-functional: Val MCC=0.3417 | Test MCC=0.4624
#   signal-peptide  : Val MCC=0.8505 | Test MCC=0.8447
#   toxic           : Val MCC=0.7424 | Test MCC=0.7096
# ----------------------------------------------------------------------
# Ep 23/80 | LR: 8.4e-06 | Train: 0.4561 | Val: 0.0579 | Test: 0.0537
#   MCC -> Func Avg (Val): 0.5687 | Func Avg (Test): 0.5828 | Pat: 0/20 >>> BEST <<<
#   Overall Total MCC -> Val: 0.8240 | Test: 0.8240
#   NON-FUNCTIONAL MCC -> Val: 0.9427 | Test: 0.9449
#   anti-bacterial  : Val MCC=0.7667 | Test MCC=0.8082
#   anti-cancer     : Val MCC=0.5160 | Test MCC=0.5297
#   anti-fungal     : Val MCC=0.5244 | Test MCC=0.5362
#   anti-parasitic  : Val MCC=0.5388 | Test MCC=0.5643
#   anti-viral      : Val MCC=0.4396 | Test MCC=0.4939
#   cell-cell-communication: Val MCC=0.6083 | Test MCC=0.5858
#   drug-delivery   : Val MCC=0.4895 | Test MCC=0.4665
#   immunological   : Val MCC=0.5319 | Test MCC=0.5450
#   inhibitor       : Val MCC=0.4330 | Test MCC=0.3779
#   metabolic       : Val MCC=0.6297 | Test MCC=0.6067
#   other-functional: Val MCC=0.3271 | Test MCC=0.5016
#   signal-peptide  : Val MCC=0.8443 | Test MCC=0.8447
#   toxic           : Val MCC=0.7438 | Test MCC=0.7158
# ----------------------------------------------------------------------
# Ep 24/80 | LR: 8.3e-06 | Train: 0.4553 | Val: 0.0580 | Test: 0.0540
#   MCC -> Func Avg (Val): 0.5703 | Func Avg (Test): 0.5807 | Pat: 0/20 >>> BEST <<<
#   Overall Total MCC -> Val: 0.8252 | Test: 0.8252
#   NON-FUNCTIONAL MCC -> Val: 0.9441 | Test: 0.9445
#   anti-bacterial  : Val MCC=0.7349 | Test MCC=0.7705
#   anti-cancer     : Val MCC=0.5127 | Test MCC=0.5289
#   anti-fungal     : Val MCC=0.5367 | Test MCC=0.5511
#   anti-parasitic  : Val MCC=0.5513 | Test MCC=0.5590
#   anti-viral      : Val MCC=0.4819 | Test MCC=0.5356
#   cell-cell-communication: Val MCC=0.6005 | Test MCC=0.5738
#   drug-delivery   : Val MCC=0.4740 | Test MCC=0.4633
#   immunological   : Val MCC=0.5462 | Test MCC=0.5789
#   inhibitor       : Val MCC=0.4394 | Test MCC=0.3545
#   metabolic       : Val MCC=0.6082 | Test MCC=0.6003
#   other-functional: Val MCC=0.3507 | Test MCC=0.4900
#   signal-peptide  : Val MCC=0.8497 | Test MCC=0.8457
#   toxic           : Val MCC=0.7276 | Test MCC=0.6973
# ----------------------------------------------------------------------
# Ep 25/80 | LR: 8.1e-06 | Train: 0.4536 | Val: 0.0600 | Test: 0.0550
#   MCC -> Func Avg (Val): 0.5773 | Func Avg (Test): 0.5855 | Pat: 0/20 >>> BEST <<<
#   Overall Total MCC -> Val: 0.8236 | Test: 0.8227
#   NON-FUNCTIONAL MCC -> Val: 0.9424 | Test: 0.9441
#   anti-bacterial  : Val MCC=0.7387 | Test MCC=0.7720
#   anti-cancer     : Val MCC=0.5151 | Test MCC=0.5300
#   anti-fungal     : Val MCC=0.5341 | Test MCC=0.5566
#   anti-parasitic  : Val MCC=0.5473 | Test MCC=0.5554
#   anti-viral      : Val MCC=0.5056 | Test MCC=0.5341
#   cell-cell-communication: Val MCC=0.6161 | Test MCC=0.5894
#   drug-delivery   : Val MCC=0.4752 | Test MCC=0.4646
#   immunological   : Val MCC=0.5630 | Test MCC=0.5853
#   inhibitor       : Val MCC=0.4305 | Test MCC=0.3850
#   metabolic       : Val MCC=0.6363 | Test MCC=0.6092
#   other-functional: Val MCC=0.3466 | Test MCC=0.4702
#   signal-peptide  : Val MCC=0.8527 | Test MCC=0.8470
#   toxic           : Val MCC=0.7444 | Test MCC=0.7123
# ----------------------------------------------------------------------
# Ep 26/80 | LR: 8.0e-06 | Train: 0.4523 | Val: 0.0606 | Test: 0.0560
#   MCC -> Func Avg (Val): 0.5785 | Func Avg (Test): 0.5917 | Pat: 0/20 >>> BEST <<<
#   Overall Total MCC -> Val: 0.8278 | Test: 0.8295
#   NON-FUNCTIONAL MCC -> Val: 0.9426 | Test: 0.9458
#   anti-bacterial  : Val MCC=0.7702 | Test MCC=0.8067
#   anti-cancer     : Val MCC=0.5186 | Test MCC=0.5228
#   anti-fungal     : Val MCC=0.5318 | Test MCC=0.5487
#   anti-parasitic  : Val MCC=0.5359 | Test MCC=0.5485
#   anti-viral      : Val MCC=0.4981 | Test MCC=0.5496
#   cell-cell-communication: Val MCC=0.5956 | Test MCC=0.5878
#   drug-delivery   : Val MCC=0.5055 | Test MCC=0.4818
#   immunological   : Val MCC=0.5547 | Test MCC=0.5808
#   inhibitor       : Val MCC=0.4396 | Test MCC=0.3928
#   metabolic       : Val MCC=0.6220 | Test MCC=0.6122
#   other-functional: Val MCC=0.3602 | Test MCC=0.4923
#   signal-peptide  : Val MCC=0.8478 | Test MCC=0.8488
#   toxic           : Val MCC=0.7404 | Test MCC=0.7195
# ----------------------------------------------------------------------
# Ep 27/80 | LR: 7.8e-06 | Train: 0.4509 | Val: 0.0617 | Test: 0.0566
#   MCC -> Func Avg (Val): 0.5726 | Func Avg (Test): 0.5866 | Pat: 1/20
#   Overall Total MCC -> Val: 0.8262 | Test: 0.8268
#   NON-FUNCTIONAL MCC -> Val: 0.9423 | Test: 0.9447
#   anti-bacterial  : Val MCC=0.7717 | Test MCC=0.8099
#   anti-cancer     : Val MCC=0.5135 | Test MCC=0.5216
#   anti-fungal     : Val MCC=0.5216 | Test MCC=0.5575
#   anti-parasitic  : Val MCC=0.5337 | Test MCC=0.5519
#   anti-viral      : Val MCC=0.4608 | Test MCC=0.5175
#   cell-cell-communication: Val MCC=0.6164 | Test MCC=0.5835
#   drug-delivery   : Val MCC=0.4763 | Test MCC=0.4720
#   immunological   : Val MCC=0.5464 | Test MCC=0.5785
#   inhibitor       : Val MCC=0.4281 | Test MCC=0.3953
#   metabolic       : Val MCC=0.6324 | Test MCC=0.6123
#   other-functional: Val MCC=0.3447 | Test MCC=0.4682
#   signal-peptide  : Val MCC=0.8506 | Test MCC=0.8480
#   toxic           : Val MCC=0.7472 | Test MCC=0.7097
# ----------------------------------------------------------------------
# Ep 28/80 | LR: 7.6e-06 | Train: 0.4498 | Val: 0.0618 | Test: 0.0570
#   MCC -> Func Avg (Val): 0.5772 | Func Avg (Test): 0.5936 | Pat: 2/20
#   Overall Total MCC -> Val: 0.8294 | Test: 0.8329
#   NON-FUNCTIONAL MCC -> Val: 0.9432 | Test: 0.9453
#   anti-bacterial  : Val MCC=0.7729 | Test MCC=0.8112
#   anti-cancer     : Val MCC=0.5132 | Test MCC=0.5309
#   anti-fungal     : Val MCC=0.5337 | Test MCC=0.5629
#   anti-parasitic  : Val MCC=0.5418 | Test MCC=0.5607
#   anti-viral      : Val MCC=0.5172 | Test MCC=0.5676
#   cell-cell-communication: Val MCC=0.5712 | Test MCC=0.5716
#   drug-delivery   : Val MCC=0.5035 | Test MCC=0.4815
#   immunological   : Val MCC=0.5539 | Test MCC=0.5875
#   inhibitor       : Val MCC=0.4265 | Test MCC=0.3975
#   metabolic       : Val MCC=0.6336 | Test MCC=0.6081
#   other-functional: Val MCC=0.3540 | Test MCC=0.4849
#   signal-peptide  : Val MCC=0.8537 | Test MCC=0.8522
#   toxic           : Val MCC=0.7281 | Test MCC=0.7007
# ----------------------------------------------------------------------
# Ep 32/80 | LR: 6.9e-06 | Train: 0.4452 | Val: 0.0628 | Test: 0.0580 [SWA n=3]
#   MCC -> Func Avg (Val): 0.5835 | Func Avg (Test): 0.5962 | Pat: 3/20
#   Overall Total MCC -> Val: 0.8270 | Test: 0.8283
#   NON-FUNCTIONAL MCC -> Val: 0.9436 | Test: 0.9452
#   anti-bacterial  : Val MCC=0.7512 | Test MCC=0.7822
#   anti-cancer     : Val MCC=0.5192 | Test MCC=0.5245
#   anti-fungal     : Val MCC=0.5307 | Test MCC=0.5726
#   anti-parasitic  : Val MCC=0.5328 | Test MCC=0.5483
#   anti-viral      : Val MCC=0.5114 | Test MCC=0.5695
#   cell-cell-communication: Val MCC=0.6143 | Test MCC=0.6047
#   drug-delivery   : Val MCC=0.5213 | Test MCC=0.4753
#   immunological   : Val MCC=0.5615 | Test MCC=0.5722
#   inhibitor       : Val MCC=0.4271 | Test MCC=0.3811
#   metabolic       : Val MCC=0.6352 | Test MCC=0.6235
#   other-functional: Val MCC=0.3778 | Test MCC=0.5156
#   signal-peptide  : Val MCC=0.8531 | Test MCC=0.8572
#   toxic           : Val MCC=0.7502 | Test MCC=0.7244
# ----------------------------------------------------------------------
# Ep 33/80 | LR: 6.7e-06 | Train: 0.4438 | Val: 0.0631 | Test: 0.0583 [SWA n=4]
#   MCC -> Func Avg (Val): 0.5878 | Func Avg (Test): 0.6002 | Pat: 0/20 >>> BEST <<<
#   Overall Total MCC -> Val: 0.8271 | Test: 0.8281
#   NON-FUNCTIONAL MCC -> Val: 0.9430 | Test: 0.9451
#   anti-bacterial  : Val MCC=0.7514 | Test MCC=0.7824
#   anti-cancer     : Val MCC=0.5182 | Test MCC=0.5254
#   anti-fungal     : Val MCC=0.5335 | Test MCC=0.5742
#   anti-parasitic  : Val MCC=0.5334 | Test MCC=0.5468
#   anti-viral      : Val MCC=0.5296 | Test MCC=0.5692
#   cell-cell-communication: Val MCC=0.6406 | Test MCC=0.6228
#   drug-delivery   : Val MCC=0.5181 | Test MCC=0.4793
#   immunological   : Val MCC=0.5635 | Test MCC=0.5978
#   inhibitor       : Val MCC=0.4328 | Test MCC=0.3935
#   metabolic       : Val MCC=0.6392 | Test MCC=0.6231
#   other-functional: Val MCC=0.3763 | Test MCC=0.5104
#   signal-peptide  : Val MCC=0.8526 | Test MCC=0.8563
#   toxic           : Val MCC=0.7516 | Test MCC=0.7217
# ----------------------------------------------------------------------
# Ep 34/80 | LR: 6.5e-06 | Train: 0.4432 | Val: 0.0635 | Test: 0.0586 [SWA n=5]
#   MCC -> Func Avg (Val): 0.5904 | Func Avg (Test): 0.6017 | Pat: 0/20 >>> BEST <<<
#   Overall Total MCC -> Val: 0.8286 | Test: 0.8303
#   NON-FUNCTIONAL MCC -> Val: 0.9429 | Test: 0.9440
#   anti-bacterial  : Val MCC=0.7828 | Test MCC=0.8157
#   anti-cancer     : Val MCC=0.5166 | Test MCC=0.5283
#   anti-fungal     : Val MCC=0.5290 | Test MCC=0.5732
#   anti-parasitic  : Val MCC=0.5305 | Test MCC=0.5453
#   anti-viral      : Val MCC=0.5225 | Test MCC=0.5699
#   cell-cell-communication: Val MCC=0.6397 | Test MCC=0.6315
#   drug-delivery   : Val MCC=0.5187 | Test MCC=0.4753
#   immunological   : Val MCC=0.5625 | Test MCC=0.5908
#   inhibitor       : Val MCC=0.4356 | Test MCC=0.3858
#   metabolic       : Val MCC=0.6377 | Test MCC=0.6245
#   other-functional: Val MCC=0.3905 | Test MCC=0.5033
#   signal-peptide  : Val MCC=0.8553 | Test MCC=0.8559
#   toxic           : Val MCC=0.7540 | Test MCC=0.7233
# ----------------------------------------------------------------------
# Ep 35/80 | LR: 6.3e-06 | Train: 0.4417 | Val: 0.0638 | Test: 0.0589 [SWA n=6]
#   MCC -> Func Avg (Val): 0.5919 | Func Avg (Test): 0.6052 | Pat: 0/20 >>> BEST <<<
#   Overall Total MCC -> Val: 0.8310 | Test: 0.8328
#   NON-FUNCTIONAL MCC -> Val: 0.9429 | Test: 0.9447
#   anti-bacterial  : Val MCC=0.7807 | Test MCC=0.8140
#   anti-cancer     : Val MCC=0.5184 | Test MCC=0.5272
#   anti-fungal     : Val MCC=0.5313 | Test MCC=0.5757
#   anti-parasitic  : Val MCC=0.5289 | Test MCC=0.5484
#   anti-viral      : Val MCC=0.5239 | Test MCC=0.5695
#   cell-cell-communication: Val MCC=0.6367 | Test MCC=0.6335
#   drug-delivery   : Val MCC=0.5202 | Test MCC=0.4820
#   immunological   : Val MCC=0.5649 | Test MCC=0.5972
#   inhibitor       : Val MCC=0.4393 | Test MCC=0.3937
#   metabolic       : Val MCC=0.6411 | Test MCC=0.6249
#   other-functional: Val MCC=0.3891 | Test MCC=0.5110
#   signal-peptide  : Val MCC=0.8661 | Test MCC=0.8668
#   toxic           : Val MCC=0.7538 | Test MCC=0.7239
# ----------------------------------------------------------------------
# Ep 36/80 | LR: 6.1e-06 | Train: 0.4406 | Val: 0.0642 | Test: 0.0593 [SWA n=7]
#   MCC -> Func Avg (Val): 0.5880 | Func Avg (Test): 0.6038 | Pat: 1/20
#   Overall Total MCC -> Val: 0.8296 | Test: 0.8326
#   NON-FUNCTIONAL MCC -> Val: 0.9432 | Test: 0.9455
#   anti-bacterial  : Val MCC=0.7805 | Test MCC=0.8161
#   anti-cancer     : Val MCC=0.5120 | Test MCC=0.5276
#   anti-fungal     : Val MCC=0.5320 | Test MCC=0.5802
#   anti-parasitic  : Val MCC=0.5251 | Test MCC=0.5473
#   anti-viral      : Val MCC=0.5239 | Test MCC=0.5730
#   cell-cell-communication: Val MCC=0.6219 | Test MCC=0.6109
#   drug-delivery   : Val MCC=0.5166 | Test MCC=0.4813
#   immunological   : Val MCC=0.5615 | Test MCC=0.5985
#   inhibitor       : Val MCC=0.4366 | Test MCC=0.3981
#   metabolic       : Val MCC=0.6415 | Test MCC=0.6235
#   other-functional: Val MCC=0.3848 | Test MCC=0.5135
#   signal-peptide  : Val MCC=0.8549 | Test MCC=0.8557
#   toxic           : Val MCC=0.7522 | Test MCC=0.7242
# ----------------------------------------------------------------------
# Ep 37/80 | LR: 5.9e-06 | Train: 0.4400 | Val: 0.0648 | Test: 0.0596 [SWA n=8]
#   MCC -> Func Avg (Val): 0.5848 | Func Avg (Test): 0.6024 | Pat: 2/20
#   Overall Total MCC -> Val: 0.8309 | Test: 0.8345
#   NON-FUNCTIONAL MCC -> Val: 0.9431 | Test: 0.9453
#   anti-bacterial  : Val MCC=0.7815 | Test MCC=0.8170
#   anti-cancer     : Val MCC=0.5092 | Test MCC=0.5273
#   anti-fungal     : Val MCC=0.5315 | Test MCC=0.5784
#   anti-parasitic  : Val MCC=0.5231 | Test MCC=0.5591
#   anti-viral      : Val MCC=0.5185 | Test MCC=0.5780
#   cell-cell-communication: Val MCC=0.5922 | Test MCC=0.5682
#   drug-delivery   : Val MCC=0.5130 | Test MCC=0.4846
#   immunological   : Val MCC=0.5610 | Test MCC=0.5983
#   inhibitor       : Val MCC=0.4274 | Test MCC=0.4089
#   metabolic       : Val MCC=0.6467 | Test MCC=0.6226
#   other-functional: Val MCC=0.3870 | Test MCC=0.5082
#   signal-peptide  : Val MCC=0.8554 | Test MCC=0.8572
#   toxic           : Val MCC=0.7555 | Test MCC=0.7238
# ----------------------------------------------------------------------
# Ep 38/80 | LR: 5.7e-06 | Train: 0.4391 | Val: 0.0652 | Test: 0.0599 [SWA n=9]
#   MCC -> Func Avg (Val): 0.5877 | Func Avg (Test): 0.6024 | Pat: 3/20
#   Overall Total MCC -> Val: 0.8309 | Test: 0.8336
#   NON-FUNCTIONAL MCC -> Val: 0.9434 | Test: 0.9451
#   anti-bacterial  : Val MCC=0.7815 | Test MCC=0.8173
#   anti-cancer     : Val MCC=0.5113 | Test MCC=0.5309
#   anti-fungal     : Val MCC=0.5309 | Test MCC=0.5765
#   anti-parasitic  : Val MCC=0.5242 | Test MCC=0.5485
#   anti-viral      : Val MCC=0.5235 | Test MCC=0.5729
#   cell-cell-communication: Val MCC=0.6001 | Test MCC=0.5698
#   drug-delivery   : Val MCC=0.5140 | Test MCC=0.4891
#   immunological   : Val MCC=0.5644 | Test MCC=0.6002
#   inhibitor       : Val MCC=0.4329 | Test MCC=0.4048
#   metabolic       : Val MCC=0.6495 | Test MCC=0.6269
#   other-functional: Val MCC=0.3905 | Test MCC=0.5048
#   signal-peptide  : Val MCC=0.8649 | Test MCC=0.8665
#   toxic           : Val MCC=0.7524 | Test MCC=0.7229
# ----------------------------------------------------------------------
# Ep 39/80 | LR: 5.5e-06 | Train: 0.4382 | Val: 0.0656 | Test: 0.0601 [SWA n=10]
#   MCC -> Func Avg (Val): 0.5860 | Func Avg (Test): 0.6025 | Pat: 4/20
#   Overall Total MCC -> Val: 0.8301 | Test: 0.8329
#   NON-FUNCTIONAL MCC -> Val: 0.9434 | Test: 0.9454
#   anti-bacterial  : Val MCC=0.7826 | Test MCC=0.8176
#   anti-cancer     : Val MCC=0.5086 | Test MCC=0.5319
#   anti-fungal     : Val MCC=0.5300 | Test MCC=0.5768
#   anti-parasitic  : Val MCC=0.5285 | Test MCC=0.5489
#   anti-viral      : Val MCC=0.5344 | Test MCC=0.5731
#   cell-cell-communication: Val MCC=0.5978 | Test MCC=0.5777
#   drug-delivery   : Val MCC=0.5171 | Test MCC=0.4819
#   immunological   : Val MCC=0.5619 | Test MCC=0.6011
#   inhibitor       : Val MCC=0.4111 | Test MCC=0.4081
#   metabolic       : Val MCC=0.6459 | Test MCC=0.6222
#   other-functional: Val MCC=0.3898 | Test MCC=0.5151
#   signal-peptide  : Val MCC=0.8560 | Test MCC=0.8562
#   toxic           : Val MCC=0.7544 | Test MCC=0.7223
# ----------------------------------------------------------------------
# Ep 40/80 | LR: 5.3e-06 | Train: 0.4370 | Val: 0.0658 | Test: 0.0604 [SWA n=11]
#   MCC -> Func Avg (Val): 0.5870 | Func Avg (Test): 0.6035 | Pat: 5/20
#   Overall Total MCC -> Val: 0.8361 | Test: 0.8396
#   NON-FUNCTIONAL MCC -> Val: 0.9432 | Test: 0.9451
#   anti-bacterial  : Val MCC=0.7818 | Test MCC=0.8174
#   anti-cancer     : Val MCC=0.5158 | Test MCC=0.5419
#   anti-fungal     : Val MCC=0.5235 | Test MCC=0.5778
#   anti-parasitic  : Val MCC=0.5251 | Test MCC=0.5448
#   anti-viral      : Val MCC=0.5189 | Test MCC=0.5661
#   cell-cell-communication: Val MCC=0.5952 | Test MCC=0.5777
#   drug-delivery   : Val MCC=0.5258 | Test MCC=0.4845
#   immunological   : Val MCC=0.5609 | Test MCC=0.6039
#   inhibitor       : Val MCC=0.4218 | Test MCC=0.4029
#   metabolic       : Val MCC=0.6449 | Test MCC=0.6240
#   other-functional: Val MCC=0.3962 | Test MCC=0.5130
#   signal-peptide  : Val MCC=0.8671 | Test MCC=0.8678
#   toxic           : Val MCC=0.7539 | Test MCC=0.7235
# ----------------------------------------------------------------------
# Ep 41/80 | LR: 5.1e-06 | Train: 0.4361 | Val: 0.0663 | Test: 0.0606 [SWA n=12]
#   MCC -> Func Avg (Val): 0.5892 | Func Avg (Test): 0.6118 | Pat: 6/20
#   Overall Total MCC -> Val: 0.8309 | Test: 0.8342
#   NON-FUNCTIONAL MCC -> Val: 0.9435 | Test: 0.9453
#   anti-bacterial  : Val MCC=0.7822 | Test MCC=0.8172
#   anti-cancer     : Val MCC=0.5150 | Test MCC=0.5312
#   anti-fungal     : Val MCC=0.5358 | Test MCC=0.5799
#   anti-parasitic  : Val MCC=0.5250 | Test MCC=0.5489
#   anti-viral      : Val MCC=0.5284 | Test MCC=0.5744
#   cell-cell-communication: Val MCC=0.6330 | Test MCC=0.6586
#   drug-delivery   : Val MCC=0.5136 | Test MCC=0.4871
#   immunological   : Val MCC=0.5537 | Test MCC=0.6073
#   inhibitor       : Val MCC=0.4301 | Test MCC=0.4265
#   metabolic       : Val MCC=0.6432 | Test MCC=0.6271
#   other-functional: Val MCC=0.3891 | Test MCC=0.5141
#   signal-peptide  : Val MCC=0.8552 | Test MCC=0.8597
#   toxic           : Val MCC=0.7560 | Test MCC=0.7213
# ----------------------------------------------------------------------
# Ep 42/80 | LR: 4.9e-06 | Train: 0.4352 | Val: 0.0665 | Test: 0.0608 [SWA n=13]
#   MCC -> Func Avg (Val): 0.5890 | Func Avg (Test): 0.6104 | Pat: 7/20
#   Overall Total MCC -> Val: 0.8295 | Test: 0.8333
#   NON-FUNCTIONAL MCC -> Val: 0.9432 | Test: 0.9453
#   anti-bacterial  : Val MCC=0.7826 | Test MCC=0.8188
#   anti-cancer     : Val MCC=0.5109 | Test MCC=0.5332
#   anti-fungal     : Val MCC=0.5341 | Test MCC=0.5799
#   anti-parasitic  : Val MCC=0.5253 | Test MCC=0.5497
#   anti-viral      : Val MCC=0.5260 | Test MCC=0.5751
#   cell-cell-communication: Val MCC=0.6374 | Test MCC=0.6229
#   drug-delivery   : Val MCC=0.5161 | Test MCC=0.4911
#   immunological   : Val MCC=0.5647 | Test MCC=0.6055
#   inhibitor       : Val MCC=0.4229 | Test MCC=0.4386
#   metabolic       : Val MCC=0.6454 | Test MCC=0.6243
#   other-functional: Val MCC=0.3820 | Test MCC=0.5124
#   signal-peptide  : Val MCC=0.8560 | Test MCC=0.8604
#   toxic           : Val MCC=0.7533 | Test MCC=0.7232
# ----------------------------------------------------------------------
# Ep 43/80 | LR: 4.7e-06 | Train: 0.4342 | Val: 0.0667 | Test: 0.0611 [SWA n=14]
#   MCC -> Func Avg (Val): 0.5872 | Func Avg (Test): 0.6063 | Pat: 8/20
#   Overall Total MCC -> Val: 0.8297 | Test: 0.8328
#   NON-FUNCTIONAL MCC -> Val: 0.9434 | Test: 0.9456
#   anti-bacterial  : Val MCC=0.7836 | Test MCC=0.8190
#   anti-cancer     : Val MCC=0.5098 | Test MCC=0.5301
#   anti-fungal     : Val MCC=0.5342 | Test MCC=0.5820
#   anti-parasitic  : Val MCC=0.5284 | Test MCC=0.5491
#   anti-viral      : Val MCC=0.5331 | Test MCC=0.5808
#   cell-cell-communication: Val MCC=0.6031 | Test MCC=0.5840
#   drug-delivery   : Val MCC=0.5082 | Test MCC=0.4638
#   immunological   : Val MCC=0.5585 | Test MCC=0.6060
#   inhibitor       : Val MCC=0.4262 | Test MCC=0.4350
#   metabolic       : Val MCC=0.6438 | Test MCC=0.6261
#   other-functional: Val MCC=0.3905 | Test MCC=0.5216
#   signal-peptide  : Val MCC=0.8572 | Test MCC=0.8612
#   toxic           : Val MCC=0.7568 | Test MCC=0.7233
# ----------------------------------------------------------------------
# Ep 44/80 | LR: 4.5e-06 | Train: 0.4331 | Val: 0.0670 | Test: 0.0613 [SWA n=15]
#   MCC -> Func Avg (Val): 0.5903 | Func Avg (Test): 0.6111 | Pat: 9/20
#   Overall Total MCC -> Val: 0.8314 | Test: 0.8346
#   NON-FUNCTIONAL MCC -> Val: 0.9432 | Test: 0.9455
#   anti-bacterial  : Val MCC=0.7838 | Test MCC=0.8203
#   anti-cancer     : Val MCC=0.5113 | Test MCC=0.5329
#   anti-fungal     : Val MCC=0.5343 | Test MCC=0.5809
#   anti-parasitic  : Val MCC=0.5284 | Test MCC=0.5504
#   anti-viral      : Val MCC=0.5267 | Test MCC=0.5758
#   cell-cell-communication: Val MCC=0.6395 | Test MCC=0.6220
#   drug-delivery   : Val MCC=0.5151 | Test MCC=0.4937
#   immunological   : Val MCC=0.5623 | Test MCC=0.6026
#   inhibitor       : Val MCC=0.4236 | Test MCC=0.4375
#   metabolic       : Val MCC=0.6437 | Test MCC=0.6240
#   other-functional: Val MCC=0.3798 | Test MCC=0.5114
#   signal-peptide  : Val MCC=0.8686 | Test MCC=0.8693
#   toxic           : Val MCC=0.7567 | Test MCC=0.7236
# ----------------------------------------------------------------------
# Ep 45/80 | LR: 4.3e-06 | Train: 0.4324 | Val: 0.0674 | Test: 0.0616 [SWA n=16]
#   MCC -> Func Avg (Val): 0.5890 | Func Avg (Test): 0.6115 | Pat: 10/20
#   Overall Total MCC -> Val: 0.8302 | Test: 0.8342
#   NON-FUNCTIONAL MCC -> Val: 0.9429 | Test: 0.9454
#   anti-bacterial  : Val MCC=0.7817 | Test MCC=0.8200
#   anti-cancer     : Val MCC=0.5146 | Test MCC=0.5330
#   anti-fungal     : Val MCC=0.5326 | Test MCC=0.5807
#   anti-parasitic  : Val MCC=0.5246 | Test MCC=0.5479
#   anti-viral      : Val MCC=0.5303 | Test MCC=0.5720
#   cell-cell-communication: Val MCC=0.6328 | Test MCC=0.6320
#   drug-delivery   : Val MCC=0.5136 | Test MCC=0.4998
#   immunological   : Val MCC=0.5580 | Test MCC=0.6000
#   inhibitor       : Val MCC=0.4268 | Test MCC=0.4366
#   metabolic       : Val MCC=0.6385 | Test MCC=0.6227
#   other-functional: Val MCC=0.3926 | Test MCC=0.5204
#   signal-peptide  : Val MCC=0.8577 | Test MCC=0.8618
#   toxic           : Val MCC=0.7537 | Test MCC=0.7229
# ----------------------------------------------------------------------
# Ep 46/80 | LR: 4.1e-06 | Train: 0.4309 | Val: 0.0678 | Test: 0.0618 [SWA n=17]
#   MCC -> Func Avg (Val): 0.5892 | Func Avg (Test): 0.6131 | Pat: 11/20
#   Overall Total MCC -> Val: 0.8309 | Test: 0.8349
#   NON-FUNCTIONAL MCC -> Val: 0.9430 | Test: 0.9454
#   anti-bacterial  : Val MCC=0.7827 | Test MCC=0.8213
#   anti-cancer     : Val MCC=0.5137 | Test MCC=0.5345
#   anti-fungal     : Val MCC=0.5321 | Test MCC=0.5801
#   anti-parasitic  : Val MCC=0.5294 | Test MCC=0.5503
#   anti-viral      : Val MCC=0.5260 | Test MCC=0.5774
#   cell-cell-communication: Val MCC=0.6378 | Test MCC=0.6307
#   drug-delivery   : Val MCC=0.5057 | Test MCC=0.5046
#   immunological   : Val MCC=0.5629 | Test MCC=0.6022
#   inhibitor       : Val MCC=0.4234 | Test MCC=0.4378
#   metabolic       : Val MCC=0.6445 | Test MCC=0.6277
#   other-functional: Val MCC=0.3891 | Test MCC=0.5182
#   signal-peptide  : Val MCC=0.8577 | Test MCC=0.8615
#   toxic           : Val MCC=0.7545 | Test MCC=0.7235
# ----------------------------------------------------------------------
# Ep 47/80 | LR: 3.9e-06 | Train: 0.4307 | Val: 0.0681 | Test: 0.0620 [SWA n=18]
#   MCC -> Func Avg (Val): 0.5918 | Func Avg (Test): 0.6127 | Pat: 12/20
#   Overall Total MCC -> Val: 0.8315 | Test: 0.8352
#   NON-FUNCTIONAL MCC -> Val: 0.9430 | Test: 0.9454
#   anti-bacterial  : Val MCC=0.7832 | Test MCC=0.8205
#   anti-cancer     : Val MCC=0.5142 | Test MCC=0.5341
#   anti-fungal     : Val MCC=0.5374 | Test MCC=0.5811
#   anti-parasitic  : Val MCC=0.5246 | Test MCC=0.5485
#   anti-viral      : Val MCC=0.5308 | Test MCC=0.5823
#   cell-cell-communication: Val MCC=0.6391 | Test MCC=0.6297
#   drug-delivery   : Val MCC=0.5156 | Test MCC=0.4989
#   immunological   : Val MCC=0.5590 | Test MCC=0.6025
#   inhibitor       : Val MCC=0.4417 | Test MCC=0.4401
#   metabolic       : Val MCC=0.6401 | Test MCC=0.6222
#   other-functional: Val MCC=0.3971 | Test MCC=0.5183
#   signal-peptide  : Val MCC=0.8581 | Test MCC=0.8624
#   toxic           : Val MCC=0.7526 | Test MCC=0.7240
# ----------------------------------------------------------------------
# Ep 48/80 | LR: 3.7e-06 | Train: 0.4298 | Val: 0.0685 | Test: 0.0623 [SWA n=19]
#   MCC -> Func Avg (Val): 0.5922 | Func Avg (Test): 0.6146 | Pat: 0/20 >>> BEST <<<
#   Overall Total MCC -> Val: 0.8321 | Test: 0.8357
#   NON-FUNCTIONAL MCC -> Val: 0.9431 | Test: 0.9456
#   anti-bacterial  : Val MCC=0.7826 | Test MCC=0.8227
#   anti-cancer     : Val MCC=0.5157 | Test MCC=0.5329
#   anti-fungal     : Val MCC=0.5353 | Test MCC=0.5824
#   anti-parasitic  : Val MCC=0.5304 | Test MCC=0.5482
#   anti-viral      : Val MCC=0.5257 | Test MCC=0.5810
#   cell-cell-communication: Val MCC=0.6431 | Test MCC=0.6340
#   drug-delivery   : Val MCC=0.5224 | Test MCC=0.5090
#   immunological   : Val MCC=0.5576 | Test MCC=0.6070
#   inhibitor       : Val MCC=0.4359 | Test MCC=0.4448
#   metabolic       : Val MCC=0.6449 | Test MCC=0.6298
#   other-functional: Val MCC=0.3898 | Test MCC=0.5120
#   signal-peptide  : Val MCC=0.8588 | Test MCC=0.8614
#   toxic           : Val MCC=0.7566 | Test MCC=0.7244
# ----------------------------------------------------------------------
# Ep 49/80 | LR: 3.5e-06 | Train: 0.4291 | Val: 0.0688 | Test: 0.0625 [SWA n=20]
#   MCC -> Func Avg (Val): 0.5937 | Func Avg (Test): 0.6140 | Pat: 0/20 >>> BEST <<<
#   Overall Total MCC -> Val: 0.8318 | Test: 0.8357
#   NON-FUNCTIONAL MCC -> Val: 0.9432 | Test: 0.9456
#   anti-bacterial  : Val MCC=0.7842 | Test MCC=0.8222
#   anti-cancer     : Val MCC=0.5137 | Test MCC=0.5344
#   anti-fungal     : Val MCC=0.5347 | Test MCC=0.5843
#   anti-parasitic  : Val MCC=0.5269 | Test MCC=0.5498
#   anti-viral      : Val MCC=0.5383 | Test MCC=0.5789
#   cell-cell-communication: Val MCC=0.6341 | Test MCC=0.6328
#   drug-delivery   : Val MCC=0.5254 | Test MCC=0.4937
#   immunological   : Val MCC=0.5590 | Test MCC=0.6077
#   inhibitor       : Val MCC=0.4365 | Test MCC=0.4375
#   metabolic       : Val MCC=0.6488 | Test MCC=0.6303
#   other-functional: Val MCC=0.4027 | Test MCC=0.5233
#   signal-peptide  : Val MCC=0.8578 | Test MCC=0.8637
#   toxic           : Val MCC=0.7561 | Test MCC=0.7238
# ----------------------------------------------------------------------
# Ep 50/80 | LR: 3.3e-06 | Train: 0.4277 | Val: 0.0690 | Test: 0.0627 [SWA n=21]
#   MCC -> Func Avg (Val): 0.5923 | Func Avg (Test): 0.6137 | Pat: 1/20
#   Overall Total MCC -> Val: 0.8357 | Test: 0.8398
#   NON-FUNCTIONAL MCC -> Val: 0.9430 | Test: 0.9454
#   anti-bacterial  : Val MCC=0.7838 | Test MCC=0.8213
#   anti-cancer     : Val MCC=0.5184 | Test MCC=0.5412
#   anti-fungal     : Val MCC=0.5309 | Test MCC=0.5804
#   anti-parasitic  : Val MCC=0.5270 | Test MCC=0.5498
#   anti-viral      : Val MCC=0.5337 | Test MCC=0.5770
#   cell-cell-communication: Val MCC=0.6436 | Test MCC=0.6365
#   drug-delivery   : Val MCC=0.5238 | Test MCC=0.4970
#   immunological   : Val MCC=0.5595 | Test MCC=0.6053
#   inhibitor       : Val MCC=0.4306 | Test MCC=0.4434
#   metabolic       : Val MCC=0.6388 | Test MCC=0.6184
#   other-functional: Val MCC=0.3963 | Test MCC=0.5215
#   signal-peptide  : Val MCC=0.8586 | Test MCC=0.8623
# ...
#   anti-fungal     : Val MCC=0.5322 | Test MCC=0.5859
#   anti-parasitic  : Val MCC=0.5312 | Test MCC=0.5518
#   anti-viral      : Val MCC=0.5398 | Test MCC=0.5752
#   cell-cell-communication: Val MCC=0.6440 | Test MCC=0.6480
#   drug-delivery   : Val MCC=0.5294 | Test MCC=0.5023
#   immunological   : Val MCC=0.5599 | Test MCC=0.6076
#   inhibitor       : Val MCC=0.4293 | Test MCC=0.4530
#   metabolic       : Val MCC=0.6437 | Test MCC=0.6315
#   other-functional: Val MCC=0.4006 | Test MCC=0.5234
#   signal-peptide  : Val MCC=0.8615 | Test MCC=0.8652
#   toxic           : Val MCC=0.7527 | Test MCC=0.7235
# ----------------------------------------------------------------------
# Ep 59/80 | LR: 1.7e-06 | Train: 0.4218 | Val: 0.0716 | Test: 0.0651 [SWA n=30]
#   MCC -> Func Avg (Val): 0.5898 | Func Avg (Test): 0.6146 | Pat: 3/20
#   Overall Total MCC -> Val: 0.8317 | Test: 0.8364
#   NON-FUNCTIONAL MCC -> Val: 0.9429 | Test: 0.9455
#   anti-bacterial  : Val MCC=0.7879 | Test MCC=0.8225
#   anti-cancer     : Val MCC=0.5168 | Test MCC=0.5380
#   anti-fungal     : Val MCC=0.5396 | Test MCC=0.5875
#   anti-parasitic  : Val MCC=0.5284 | Test MCC=0.5525
#   anti-viral      : Val MCC=0.5287 | Test MCC=0.5764
#   cell-cell-communication: Val MCC=0.6396 | Test MCC=0.6466
#   drug-delivery   : Val MCC=0.5113 | Test MCC=0.4860
#   immunological   : Val MCC=0.5542 | Test MCC=0.6089
#   inhibitor       : Val MCC=0.4372 | Test MCC=0.4494
#   metabolic       : Val MCC=0.6311 | Test MCC=0.6177
#   other-functional: Val MCC=0.4007 | Test MCC=0.5356
#   signal-peptide  : Val MCC=0.8462 | Test MCC=0.8524
#   toxic           : Val MCC=0.7454 | Test MCC=0.7162
# ----------------------------------------------------------------------
# Ep 60/80 | LR: 1.6e-06 | Train: 0.4211 | Val: 0.0717 | Test: 0.0654 [SWA n=31]
#   MCC -> Func Avg (Val): 0.5904 | Func Avg (Test): 0.6132 | Pat: 4/20
#   Overall Total MCC -> Val: 0.8317 | Test: 0.8359
#   NON-FUNCTIONAL MCC -> Val: 0.9432 | Test: 0.9453
#   anti-bacterial  : Val MCC=0.7875 | Test MCC=0.8230
#   anti-cancer     : Val MCC=0.5143 | Test MCC=0.5369
#   anti-fungal     : Val MCC=0.5380 | Test MCC=0.5867
#   anti-parasitic  : Val MCC=0.5282 | Test MCC=0.5515
#   anti-viral      : Val MCC=0.5381 | Test MCC=0.5793
#   cell-cell-communication: Val MCC=0.6013 | Test MCC=0.6116
#   drug-delivery   : Val MCC=0.5294 | Test MCC=0.5031
#   immunological   : Val MCC=0.5618 | Test MCC=0.6084
#   inhibitor       : Val MCC=0.4372 | Test MCC=0.4560
#   metabolic       : Val MCC=0.6453 | Test MCC=0.6239
#   other-functional: Val MCC=0.4027 | Test MCC=0.5236
#   signal-peptide  : Val MCC=0.8476 | Test MCC=0.8523
#   toxic           : Val MCC=0.7438 | Test MCC=0.7153
# ----------------------------------------------------------------------
# Ep 61/80 | LR: 1.4e-06 | Train: 0.4199 | Val: 0.0721 | Test: 0.0656 [SWA n=32]
#   MCC -> Func Avg (Val): 0.5926 | Func Avg (Test): 0.6170 | Pat: 5/20
#   Overall Total MCC -> Val: 0.8323 | Test: 0.8366
#   NON-FUNCTIONAL MCC -> Val: 0.9435 | Test: 0.9453
#   anti-bacterial  : Val MCC=0.7874 | Test MCC=0.8233
#   anti-cancer     : Val MCC=0.5186 | Test MCC=0.5364
#   anti-fungal     : Val MCC=0.5379 | Test MCC=0.5870
#   anti-parasitic  : Val MCC=0.5312 | Test MCC=0.5514
#   anti-viral      : Val MCC=0.5264 | Test MCC=0.5739
#   cell-cell-communication: Val MCC=0.6332 | Test MCC=0.6470
#   drug-delivery   : Val MCC=0.5207 | Test MCC=0.5030
#   immunological   : Val MCC=0.5590 | Test MCC=0.6108
#   inhibitor       : Val MCC=0.4392 | Test MCC=0.4551
#   metabolic       : Val MCC=0.6476 | Test MCC=0.6301
#   other-functional: Val MCC=0.4027 | Test MCC=0.5258
#   signal-peptide  : Val MCC=0.8462 | Test MCC=0.8534
#   toxic           : Val MCC=0.7535 | Test MCC=0.7241
# ----------------------------------------------------------------------
# Ep 62/80 | LR: 1.3e-06 | Train: 0.4201 | Val: 0.0722 | Test: 0.0658 [SWA n=33]
#   MCC -> Func Avg (Val): 0.5929 | Func Avg (Test): 0.6141 | Pat: 6/20
#   Overall Total MCC -> Val: 0.8302 | Test: 0.8333
#   NON-FUNCTIONAL MCC -> Val: 0.9432 | Test: 0.9450
#   anti-bacterial  : Val MCC=0.7871 | Test MCC=0.8217
#   anti-cancer     : Val MCC=0.5164 | Test MCC=0.5384
#   anti-fungal     : Val MCC=0.5364 | Test MCC=0.5862
#   anti-parasitic  : Val MCC=0.5382 | Test MCC=0.5353
#   anti-viral      : Val MCC=0.5342 | Test MCC=0.5725
#   cell-cell-communication: Val MCC=0.6376 | Test MCC=0.6552
#   drug-delivery   : Val MCC=0.5162 | Test MCC=0.4816
#   immunological   : Val MCC=0.5542 | Test MCC=0.6058
#   inhibitor       : Val MCC=0.4460 | Test MCC=0.4574
#   metabolic       : Val MCC=0.6472 | Test MCC=0.6324
#   other-functional: Val MCC=0.4027 | Test MCC=0.5247
#   signal-peptide  : Val MCC=0.8462 | Test MCC=0.8538
#   toxic           : Val MCC=0.7451 | Test MCC=0.7176
# ----------------------------------------------------------------------
# Ep 63/80 | LR: 1.2e-06 | Train: 0.4193 | Val: 0.0726 | Test: 0.0661 [SWA n=34]
#   MCC -> Func Avg (Val): 0.5902 | Func Avg (Test): 0.6130 | Pat: 7/20
#   Overall Total MCC -> Val: 0.8326 | Test: 0.8366
#   NON-FUNCTIONAL MCC -> Val: 0.9430 | Test: 0.9451
#   anti-bacterial  : Val MCC=0.7863 | Test MCC=0.8238
#   anti-cancer     : Val MCC=0.5189 | Test MCC=0.5389
#   anti-fungal     : Val MCC=0.5395 | Test MCC=0.5873
#   anti-parasitic  : Val MCC=0.5340 | Test MCC=0.5513
#   anti-viral      : Val MCC=0.5368 | Test MCC=0.5771
#   cell-cell-communication: Val MCC=0.6164 | Test MCC=0.6116
#   drug-delivery   : Val MCC=0.5153 | Test MCC=0.4825
#   immunological   : Val MCC=0.5599 | Test MCC=0.6052
#   inhibitor       : Val MCC=0.4400 | Test MCC=0.4531
#   metabolic       : Val MCC=0.6398 | Test MCC=0.6243
#   other-functional: Val MCC=0.3928 | Test MCC=0.5444
#   signal-peptide  : Val MCC=0.8459 | Test MCC=0.8538
#   toxic           : Val MCC=0.7464 | Test MCC=0.7160
# ----------------------------------------------------------------------
# Ep 64/80 | LR: 1.0e-06 | Train: 0.4194 | Val: 0.0728 | Test: 0.0663 [SWA n=35]
#   MCC -> Func Avg (Val): 0.5908 | Func Avg (Test): 0.6146 | Pat: 8/20
#   Overall Total MCC -> Val: 0.8336 | Test: 0.8379
#   NON-FUNCTIONAL MCC -> Val: 0.9432 | Test: 0.9451
#   anti-bacterial  : Val MCC=0.7864 | Test MCC=0.8243
#   anti-cancer     : Val MCC=0.5175 | Test MCC=0.5374
#   anti-fungal     : Val MCC=0.5379 | Test MCC=0.5894
#   anti-parasitic  : Val MCC=0.5343 | Test MCC=0.5531
#   anti-viral      : Val MCC=0.5367 | Test MCC=0.5762
#   cell-cell-communication: Val MCC=0.6121 | Test MCC=0.6160
#   drug-delivery   : Val MCC=0.5239 | Test MCC=0.5079
#   immunological   : Val MCC=0.5595 | Test MCC=0.6054
#   inhibitor       : Val MCC=0.4406 | Test MCC=0.4501
#   metabolic       : Val MCC=0.6427 | Test MCC=0.6234
#   other-functional: Val MCC=0.3923 | Test MCC=0.5356
#   signal-peptide  : Val MCC=0.8476 | Test MCC=0.8541
#   toxic           : Val MCC=0.7494 | Test MCC=0.7173
# ----------------------------------------------------------------------
# Ep 65/80 | LR: 9.1e-07 | Train: 0.4194 | Val: 0.0731 | Test: 0.0666 [SWA n=36]
#   MCC -> Func Avg (Val): 0.5950 | Func Avg (Test): 0.6177 | Pat: 0/20 >>> BEST <<<
#   Overall Total MCC -> Val: 0.8327 | Test: 0.8365
#   NON-FUNCTIONAL MCC -> Val: 0.9431 | Test: 0.9452
#   anti-bacterial  : Val MCC=0.7886 | Test MCC=0.8227
#   anti-cancer     : Val MCC=0.5216 | Test MCC=0.5393
#   anti-fungal     : Val MCC=0.5391 | Test MCC=0.5864
#   anti-parasitic  : Val MCC=0.5333 | Test MCC=0.5537
#   anti-viral      : Val MCC=0.5377 | Test MCC=0.5774
#   cell-cell-communication: Val MCC=0.6401 | Test MCC=0.6488
#   drug-delivery   : Val MCC=0.5170 | Test MCC=0.5090
#   immunological   : Val MCC=0.5547 | Test MCC=0.5952
#   inhibitor       : Val MCC=0.4474 | Test MCC=0.4605
#   metabolic       : Val MCC=0.6472 | Test MCC=0.6317
#   other-functional: Val MCC=0.4063 | Test MCC=0.5283
#   signal-peptide  : Val MCC=0.8482 | Test MCC=0.8540
#   toxic           : Val MCC=0.7541 | Test MCC=0.7231
# ----------------------------------------------------------------------
# Ep 66/80 | LR: 7.9e-07 | Train: 0.4183 | Val: 0.0733 | Test: 0.0667 [SWA n=37]
#   MCC -> Func Avg (Val): 0.5889 | Func Avg (Test): 0.6128 | Pat: 1/20
#   Overall Total MCC -> Val: 0.8312 | Test: 0.8355
#   NON-FUNCTIONAL MCC -> Val: 0.9430 | Test: 0.9453
#   anti-bacterial  : Val MCC=0.7673 | Test MCC=0.8053
#   anti-cancer     : Val MCC=0.5192 | Test MCC=0.5390
#   anti-fungal     : Val MCC=0.5348 | Test MCC=0.5879
#   anti-parasitic  : Val MCC=0.5289 | Test MCC=0.5517
#   anti-viral      : Val MCC=0.5385 | Test MCC=0.5796
#   cell-cell-communication: Val MCC=0.6194 | Test MCC=0.6119
#   drug-delivery   : Val MCC=0.5132 | Test MCC=0.5099
#   immunological   : Val MCC=0.5590 | Test MCC=0.6067
#   inhibitor       : Val MCC=0.4413 | Test MCC=0.4532
#   metabolic       : Val MCC=0.6392 | Test MCC=0.6249
#   other-functional: Val MCC=0.3997 | Test MCC=0.5265
#   signal-peptide  : Val MCC=0.8487 | Test MCC=0.8545
#   toxic           : Val MCC=0.7465 | Test MCC=0.7155
# ----------------------------------------------------------------------
# Ep 74/80 | LR: 1.5e-07 | Train: 0.4156 | Val: 0.0750 | Test: 0.0684 [SWA n=45]
#   MCC -> Func Avg (Val): 0.5920 | Func Avg (Test): 0.6149 | Pat: 9/20
#   Overall Total MCC -> Val: 0.8351 | Test: 0.8396
#   NON-FUNCTIONAL MCC -> Val: 0.9431 | Test: 0.9448
#   anti-bacterial  : Val MCC=0.7653 | Test MCC=0.8076
#   anti-cancer     : Val MCC=0.5156 | Test MCC=0.5404
#   anti-fungal     : Val MCC=0.5377 | Test MCC=0.5882
#   anti-parasitic  : Val MCC=0.5320 | Test MCC=0.5541
#   anti-viral      : Val MCC=0.5356 | Test MCC=0.5749
#   cell-cell-communication: Val MCC=0.6198 | Test MCC=0.6250
#   drug-delivery   : Val MCC=0.5316 | Test MCC=0.5034
#   immunological   : Val MCC=0.5533 | Test MCC=0.6075
#   inhibitor       : Val MCC=0.4491 | Test MCC=0.4641
#   metabolic       : Val MCC=0.6479 | Test MCC=0.6304
#   other-functional: Val MCC=0.4063 | Test MCC=0.5225
#   signal-peptide  : Val MCC=0.8519 | Test MCC=0.8568
#   toxic           : Val MCC=0.7502 | Test MCC=0.7181
# ----------------------------------------------------------------------
# Ep 75/80 | LR: 1.0e-07 | Train: 0.4157 | Val: 0.0752 | Test: 0.0686 [SWA n=46]
#   MCC -> Func Avg (Val): 0.5919 | Func Avg (Test): 0.6141 | Pat: 10/20
#   Overall Total MCC -> Val: 0.8321 | Test: 0.8359
#   NON-FUNCTIONAL MCC -> Val: 0.9429 | Test: 0.9450
#   anti-bacterial  : Val MCC=0.7709 | Test MCC=0.8084
#   anti-cancer     : Val MCC=0.5223 | Test MCC=0.5404
#   anti-fungal     : Val MCC=0.5377 | Test MCC=0.5906
#   anti-parasitic  : Val MCC=0.5286 | Test MCC=0.5520
#   anti-viral      : Val MCC=0.5301 | Test MCC=0.5752
#   cell-cell-communication: Val MCC=0.6245 | Test MCC=0.6267
#   drug-delivery   : Val MCC=0.5217 | Test MCC=0.4924
#   immunological   : Val MCC=0.5499 | Test MCC=0.6057
#   inhibitor       : Val MCC=0.4520 | Test MCC=0.4623
#   metabolic       : Val MCC=0.6504 | Test MCC=0.6306
#   other-functional: Val MCC=0.4063 | Test MCC=0.5261
#   signal-peptide  : Val MCC=0.8502 | Test MCC=0.8575
#   toxic           : Val MCC=0.7502 | Test MCC=0.7158
# ----------------------------------------------------------------------
# Ep 76/80 | LR: 6.6e-08 | Train: 0.4159 | Val: 0.0754 | Test: 0.0686 [SWA n=47]
#   MCC -> Func Avg (Val): 0.5915 | Func Avg (Test): 0.6166 | Pat: 11/20
#   Overall Total MCC -> Val: 0.8332 | Test: 0.8375
#   NON-FUNCTIONAL MCC -> Val: 0.9431 | Test: 0.9448
#   anti-bacterial  : Val MCC=0.7682 | Test MCC=0.8065
#   anti-cancer     : Val MCC=0.5163 | Test MCC=0.5417
#   anti-fungal     : Val MCC=0.5356 | Test MCC=0.5880
#   anti-parasitic  : Val MCC=0.5344 | Test MCC=0.5534
#   anti-viral      : Val MCC=0.5403 | Test MCC=0.5778
#   cell-cell-communication: Val MCC=0.6295 | Test MCC=0.6266
#   drug-delivery   : Val MCC=0.5238 | Test MCC=0.5070
#   immunological   : Val MCC=0.5575 | Test MCC=0.6039
#   inhibitor       : Val MCC=0.4450 | Test MCC=0.4713
#   metabolic       : Val MCC=0.6422 | Test MCC=0.6270
#   other-functional: Val MCC=0.3968 | Test MCC=0.5379
#   signal-peptide  : Val MCC=0.8510 | Test MCC=0.8576
#   toxic           : Val MCC=0.7492 | Test MCC=0.7173
# ----------------------------------------------------------------------
# Ep 77/80 | LR: 3.7e-08 | Train: 0.4156 | Val: 0.0756 | Test: 0.0688 [SWA n=48]
#   MCC -> Func Avg (Val): 0.5899 | Func Avg (Test): 0.6157 | Pat: 12/20
#   Overall Total MCC -> Val: 0.8324 | Test: 0.8370
#   NON-FUNCTIONAL MCC -> Val: 0.9430 | Test: 0.9448
#   anti-bacterial  : Val MCC=0.7654 | Test MCC=0.8080
#   anti-cancer     : Val MCC=0.5192 | Test MCC=0.5392
#   anti-fungal     : Val MCC=0.5399 | Test MCC=0.5870
#   anti-parasitic  : Val MCC=0.5310 | Test MCC=0.5533
#   anti-viral      : Val MCC=0.5370 | Test MCC=0.5762
#   cell-cell-communication: Val MCC=0.6202 | Test MCC=0.6324
#   drug-delivery   : Val MCC=0.5176 | Test MCC=0.4964
#   immunological   : Val MCC=0.5485 | Test MCC=0.6083
#   inhibitor       : Val MCC=0.4395 | Test MCC=0.4621
#   metabolic       : Val MCC=0.6393 | Test MCC=0.6252
#   other-functional: Val MCC=0.4106 | Test MCC=0.5427
#   signal-peptide  : Val MCC=0.8507 | Test MCC=0.8569
#   toxic           : Val MCC=0.7496 | Test MCC=0.7169
# ----------------------------------------------------------------------
# Ep 78/80 | LR: 1.7e-08 | Train: 0.4158 | Val: 0.0758 | Test: 0.0690 [SWA n=49]
#   MCC -> Func Avg (Val): 0.5911 | Func Avg (Test): 0.6139 | Pat: 13/20
#   Overall Total MCC -> Val: 0.8325 | Test: 0.8366
#   NON-FUNCTIONAL MCC -> Val: 0.9432 | Test: 0.9447
#   anti-bacterial  : Val MCC=0.7669 | Test MCC=0.8083
#   anti-cancer     : Val MCC=0.5218 | Test MCC=0.5421
#   anti-fungal     : Val MCC=0.5358 | Test MCC=0.5882
#   anti-parasitic  : Val MCC=0.5334 | Test MCC=0.5516
#   anti-viral      : Val MCC=0.5388 | Test MCC=0.5762
#   cell-cell-communication: Val MCC=0.6202 | Test MCC=0.6181
#   drug-delivery   : Val MCC=0.5156 | Test MCC=0.5024
#   immunological   : Val MCC=0.5537 | Test MCC=0.6052
#   inhibitor       : Val MCC=0.4457 | Test MCC=0.4627
#   metabolic       : Val MCC=0.6438 | Test MCC=0.6267
#   other-functional: Val MCC=0.4050 | Test MCC=0.5245
#   signal-peptide  : Val MCC=0.8527 | Test MCC=0.8584
#   toxic           : Val MCC=0.7502 | Test MCC=0.7165
# ----------------------------------------------------------------------
# Ep 79/80 | LR: 4.2e-09 | Train: 0.4155 | Val: 0.0758 | Test: 0.0691 [SWA n=50]
#   MCC -> Func Avg (Val): 0.5913 | Func Avg (Test): 0.6156 | Pat: 14/20
#   Overall Total MCC -> Val: 0.8335 | Test: 0.8374
#   NON-FUNCTIONAL MCC -> Val: 0.9431 | Test: 0.9451
#   anti-bacterial  : Val MCC=0.7686 | Test MCC=0.8086
#   anti-cancer     : Val MCC=0.5216 | Test MCC=0.5419
#   anti-fungal     : Val MCC=0.5408 | Test MCC=0.5877
#   anti-parasitic  : Val MCC=0.5334 | Test MCC=0.5527
#   anti-viral      : Val MCC=0.5374 | Test MCC=0.5757
#   cell-cell-communication: Val MCC=0.6177 | Test MCC=0.6242
#   drug-delivery   : Val MCC=0.5222 | Test MCC=0.5099
#   immunological   : Val MCC=0.5480 | Test MCC=0.6039
#   inhibitor       : Val MCC=0.4397 | Test MCC=0.4590
#   metabolic       : Val MCC=0.6446 | Test MCC=0.6284
#   other-functional: Val MCC=0.4097 | Test MCC=0.5365
#   signal-peptide  : Val MCC=0.8537 | Test MCC=0.8582
#   toxic           : Val MCC=0.7493 | Test MCC=0.7158
# ----------------------------------------------------------------------
# Ep 80/80 | LR: 0.0e+00 | Train: 0.4156 | Val: 0.0761 | Test: 0.0693 [SWA n=51]
#   MCC -> Func Avg (Val): 0.5915 | Func Avg (Test): 0.6131 | Pat: 15/20
#   Overall Total MCC -> Val: 0.8378 | Test: 0.8410
#   NON-FUNCTIONAL MCC -> Val: 0.9432 | Test: 0.9449
#   anti-bacterial  : Val MCC=0.7686 | Test MCC=0.8079
#   anti-cancer     : Val MCC=0.5183 | Test MCC=0.5399
#   anti-fungal     : Val MCC=0.5395 | Test MCC=0.5861
#   anti-parasitic  : Val MCC=0.5351 | Test MCC=0.5511
#   anti-viral      : Val MCC=0.5360 | Test MCC=0.5737
#   cell-cell-communication: Val MCC=0.6278 | Test MCC=0.6267
#   drug-delivery   : Val MCC=0.5200 | Test MCC=0.5109
#   immunological   : Val MCC=0.5464 | Test MCC=0.5726
#   inhibitor       : Val MCC=0.4426 | Test MCC=0.4648
#   metabolic       : Val MCC=0.6432 | Test MCC=0.6262
#   other-functional: Val MCC=0.4097 | Test MCC=0.5368
#   signal-peptide  : Val MCC=0.8532 | Test MCC=0.8573
#   toxic           : Val MCC=0.7486 | Test MCC=0.7165
# ----------------------------------------------------------------------
#
# Training Complete! Best Val MCC: 0.5950
