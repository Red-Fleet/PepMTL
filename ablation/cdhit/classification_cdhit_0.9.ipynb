# %%
# --------------------------------------------------
# 1. Imports (add these to the existing ones)
# --------------------------------------------------
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader, random_split
from sklearn.preprocessing import MultiLabelBinarizer
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt
import itertools
from torchvision.transforms import Resize
from ast import literal_eval
from sklearn.metrics import matthews_corrcoef
from torchvision import models
from transformers import AutoTokenizer, AutoModelForMaskedLM
import math
import json
from collections import defaultdict
import seaborn as sns
from matplotlib.colors import LogNorm
import random
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
# --------------------------------------------------
# Out:
# Skipping import of cpp extensions due to incompatible torch version 2.8.0+cu128 for torchao version 0.15.0             Please see https://github.com/pytorch/ao/issues/2919 for more info

# %%
DEVICE    = 'cuda:0' if torch.cuda.is_available() else 'cpu'

# %% [markdown]
# this is for all_endpoint + non_functional

# %%
with open('clustered_dataset_9.json') as f:
    clustered_dataset = json.load(f)

# %%
class_count = defaultdict(int)
for cluster in clustered_dataset:
    for s in cluster:
        for c in s['classes']:
            class_count[c] += 1

class_count
# Out:
# defaultdict(int,
#             {'toxic': 22440,
#              'anti-bacterial': 29969,
#              'anti-fungal': 12747,
#              'anti-cancer': 12390,
#              'anti-parasitic': 6586,
#              'anti-viral': 6894,
#              'inhibitor': 2046,
#              'signal-peptide': 22226,
#              'immunological': 4413,
#              'other-functional': 7040,
#              'metabolic': 11589,
#              'drug-delivery': 2202,
#              'non-functional': 163115,
#              'cell-cell-communication': 3249})

# %%
# cleaning clusters , removing clustures with empty sequences or empty classes
removes_seqs = 0

for i, cluster in enumerate(clustered_dataset):
    new_cluster = []
    for entry in cluster:
        if entry['sequence'] == '' or len(entry['classes']) == 0:
            removes_seqs += 1
        else:
            new_cluster.append(entry)

    clustered_dataset[i] = new_cluster

unfiltured_clusters_size = len(clustered_dataset)
clustered_dataset = [cluster for cluster in clustered_dataset if len(cluster) > 0]
print(f"Removed {unfiltured_clusters_size - len(clustered_dataset)} clusters")
print(f"Removed {removes_seqs} sequences")
print(len(clustered_dataset))
# Out:
# Removed 9863 clusters
# Removed 16400 sequences
# 164242

# %% [markdown]
# # dividing into train and test

# %%
train_val_test_ratio = [0.7, 0.1, 0.2]
random_state = 42

if len(train_val_test_ratio) != 3:
    raise ValueError("train_val_test_ratio must contain [train, val, test].")

ratio_sum = sum(train_val_test_ratio)
if ratio_sum <= 0:
    raise ValueError("Sum of train_val_test_ratio must be > 0.")

train_ratio, val_ratio, test_ratio = [r / ratio_sum for r in train_val_test_ratio]

all_seqs_count = sum(len(cluster) for cluster in clustered_dataset)
print('all_seqs_count', all_seqs_count)

train_size = int(all_seqs_count * train_ratio)
val_size = int(all_seqs_count * val_ratio)
test_size = all_seqs_count - train_size - val_size

train_seqs = []
val_seqs = []
test_seqs = []

train_cluster_count = 0
val_cluster_count = 0
test_cluster_count = 0

all_cluster_ids = [i for i in range(len(clustered_dataset))]
rng = random.Random(random_state)
rng.shuffle(all_cluster_ids)

for cluster_id in all_cluster_ids:
    cluster = clustered_dataset[cluster_id]
    if len(train_seqs) < train_size:
        train_seqs.extend(cluster)
        train_cluster_count += 1
    elif len(val_seqs) < val_size:
        val_seqs.extend(cluster)
        val_cluster_count += 1
    else:
        test_seqs.extend(cluster)
        test_cluster_count += 1

print('train_seqs', len(train_seqs))
print('val_seqs', len(val_seqs))
print('test_seqs', len(test_seqs))

print('train_cluster_count', train_cluster_count)
print('val_cluster_count', val_cluster_count)
print('test_cluster_count', test_cluster_count)
# Out:
# all_seqs_count 257812
# train_seqs 180468
# val_seqs 25784
# test_seqs 51560
# train_cluster_count 115309
# val_cluster_count 16241
# test_cluster_count 32692

# %% [markdown]
# # creating dataset

# %%
# other-functional is present with known functionl class then remove other-functional
for item in train_seqs:
    if 'other-functional' in item['classes'] and len(item['classes']) > 1:
        item['classes'].remove('other-functional')
        if len(item['classes']) == 0: raise Exception("no class left")

for item in test_seqs:
    if 'other-functional' in item['classes'] and len(item['classes']) > 1:
        item['classes'].remove('other-functional')
        if len(item['classes']) == 0: raise Exception("no class left")

for item in val_seqs:
    if 'other-functional' in item['classes'] and len(item['classes']) > 1:
        item['classes'].remove('other-functional')
        if len(item['classes']) == 0: raise Exception("no class left")

# %%
all_endpoints = set([c for e in train_seqs+test_seqs+val_seqs for c in e['classes']]) 

sorted(list(all_endpoints))
# Out:
# ['anti-bacterial',
#  'anti-cancer',
#  'anti-fungal',
#  'anti-parasitic',
#  'anti-viral',
#  'cell-cell-communication',
#  'drug-delivery',
#  'immunological',
#  'inhibitor',
#  'metabolic',
#  'non-functional',
#  'other-functional',
#  'signal-peptide',
#  'toxic']

# %%
# endpoints = [
#  'anti-cancer',
#  'anti-fungal',
#  'anti-parasitic',
#  'anti-viral',
#  'non-functional'
#  ]

endpoints = ['anti-bacterial',
 'anti-cancer',
 'anti-fungal',
 'anti-parasitic',
 'anti-viral',
 'cell-cell-communication',
 'drug-delivery',
 'immunological',
 'inhibitor',
 'metabolic',
 'non-functional',
 'other-functional',
 'signal-peptide',
 'toxic']

 
endpoints_set = set(endpoints)
endpoint_index = {endpoint: i for i, endpoint in enumerate(endpoints)}
index_endpoint = {i: endpoint for i, endpoint in enumerate(endpoints)}

# %%
endpoints_set
# Out:
# {'anti-bacterial',
#  'anti-cancer',
#  'anti-fungal',
#  'anti-parasitic',
#  'anti-viral',
#  'cell-cell-communication',
#  'drug-delivery',
#  'immunological',
#  'inhibitor',
#  'metabolic',
#  'non-functional',
#  'other-functional',
#  'signal-peptide',
#  'toxic'}

# %%
train_df_rows = []
for entry in train_seqs:
    row = [False]*len(endpoints)
    if len(set(entry['classes']).intersection(endpoints_set)) > 0: 
        
        for c in entry['classes']:
            if c in endpoints:
                row[endpoint_index[c]] = True

    
        row = [entry['sequence']] + row
        train_df_rows.append(row)
    
val_df_rows = []
for entry in val_seqs:
    row = [False]*len(endpoints)
    if len(set(entry['classes']).intersection(endpoints_set)) > 0: 

        for c in entry['classes']:
            if c in endpoints:
                row[endpoint_index[c]] = True

        row = [entry['sequence']] + row
        val_df_rows.append(row)

test_df_rows = []
for entry in test_seqs:
    row = [False]*len(endpoints)
    if len(set(entry['classes']).intersection(endpoints_set)) > 0: 

        for c in entry['classes']:
            if c in endpoints:
                row[endpoint_index[c]] = True

        row = [entry['sequence']] + row
        test_df_rows.append(row)

train_df = pd.DataFrame(train_df_rows, columns=['sequence'] + endpoints)
val_df = pd.DataFrame(val_df_rows, columns=['sequence'] + endpoints)
test_df = pd.DataFrame(test_df_rows, columns=['sequence'] + endpoints)

# %%
# # saving train, val, test dataset for classification
# train_df.to_csv('train_classification.csv')
# val_df.to_csv('validation_classification.csv')
# test_df.to_csv('test_classification.csv')

# %%
summary = train_df[endpoints].apply(pd.Series.value_counts)

# 2. Calculate True Percentage and add it as a new row
# We multiply by 100 to get a readable percentage (e.g., 75.0 instead of 0.75)
summary.loc['True %'] = train_df[endpoints].mean() * 100

# Print the final summary
print(summary)
# Out:
#         anti-bacterial    anti-cancer    anti-fungal  anti-parasitic  \
# False    159716.000000  171890.000000  171714.000000   175949.000000
# True      20752.000000    8578.000000    8754.000000     4519.000000
# True %       11.498992       4.753197       4.850721        2.504045
#
#          anti-viral  cell-cell-communication  drug-delivery  immunological  \
# False   175571.0000            178146.000000  178894.000000  177404.000000
# True      4897.0000              2322.000000    1574.000000    3064.000000
# True %       2.7135                 1.286655       0.872177       1.697808
#
#             inhibitor      metabolic  non-functional  other-functional  \
# False   179055.000000  172295.000000    66011.000000     178228.000000
# True      1413.000000    8173.000000   114457.000000       2240.000000
# True %       0.782964       4.528781       63.422324          1.241217
#
#         signal-peptide          toxic
# False    164880.000000  164928.000000
# True      15588.000000   15540.000000
# True %        8.637542       8.610945

# %%
summary = test_df[endpoints].apply(pd.Series.value_counts)

# 2. Calculate True Percentage and add it as a new row
# We multiply by 100 to get a readable percentage (e.g., 75.0 instead of 0.75)
summary.loc['True %'] = test_df[endpoints].mean() * 100

# Print the final summary
print(summary)
# Out:
#         anti-bacterial   anti-cancer   anti-fungal  anti-parasitic  \
# False     45250.000000  48913.000000  48860.000000    50103.000000
# True       6310.000000   2647.000000   2700.000000     1457.000000
# True %       12.238169      5.133825      5.236618        2.825834
#
#           anti-viral  cell-cell-communication  drug-delivery  immunological  \
# False   50185.000000              50974.00000   51102.000000   50679.000000
# True     1375.000000                586.00000     458.000000     881.000000
# True %      2.666796                  1.13654       0.888285       1.708689
#
#            inhibitor     metabolic  non-functional  other-functional  \
# False   51159.000000  49289.000000     19101.00000      50932.000000
# True      401.000000   2271.000000     32459.00000        628.000000
# True %      0.777735      4.404577        62.95384          1.217998
#
#         signal-peptide         toxic
# False       47108.0000  47050.000000
# True         4452.0000   4510.000000
# True %          8.6346      8.747091

# %%
random.random()
# Out:
# 0.43557378302891203

# %%
esm_tokenizer = AutoTokenizer.from_pretrained("facebook/esm2_t6_8M_UR50D")

# %%
class PeptideDataset(Dataset):

    def __init__(
        self,
        dataframe,
        tokenizer,
        label_columns,
        max_length: int = 128
    ):
        """
        Args:
            dataframe (pd.DataFrame): DataFrame containing the data.
                                      Must have a 'sequence' column.
            tokenizer (AutoTokenizer): A Hugging Face tokenizer (e.g., for ESM-2).
            label_columns (List[str]): A list of column names that represent the labels.
            max_length (int): Maximum sequence length for padding/truncation.
        """
        self.df = dataframe
        self.tokenizer = tokenizer
        self.sequences = self.df['sequence'].values
        self.labels = self.df[label_columns].values
        self.label_columns = label_columns
        self.max_length = max_length

        functional_idxs = []
        non_functional_idxs = []
        for i, label in enumerate(self.labels):
            if label[endpoint_index['non-functional']] == True:
                non_functional_idxs.append(i)
            else:
                functional_idxs.append(i)
        
        non_functional_idxs = [non_functional_idxs[i: i+1] for i in range(0, len(non_functional_idxs), 1)]
        non_functional_idxs = [i for i in non_functional_idxs]

        functional_idxs = [functional_idxs[i: i+1] for i in range(0, len(functional_idxs), 1)]
        self.all_idxs = non_functional_idxs + functional_idxs

        # Pre-tokenize ALL sequences once
        sequences = dataframe['sequence'].tolist()
        encodings = tokenizer(
            sequences,
            add_special_tokens=True,
            max_length=max_length,
            padding='max_length',
            truncation=True,
            return_attention_mask=True,
            return_tensors='pt'
        )
        self.input_ids = encodings['input_ids']
        self.attention_masks = encodings['attention_mask']


    def __len__(self) -> int:
        """Returns the total number of samples in the dataset."""
        return len(self.all_idxs)

    def __getitem__(self, index: int):
        """
        Retrieves a single sample from the dataset.

        Args:
            index (int): The index of the sample to retrieve.

        Returns:
            A dictionary containing:
            - 'input_ids': Token IDs of the sequence.
            - 'attention_mask': Mask to avoid performing attention on padding tokens.
            - 'labels': A multi-hot encoded tensor of labels.
            - 'img_input': A dummy tensor to match the MultiModelNetwork's forward signature.
        """
        idx = random.choice(self.all_idxs[index])

        return {
            'input_ids': self.input_ids[idx],
            'attention_mask': self.attention_masks[idx],
            'labels': torch.FloatTensor(self.labels[idx])
        }

# %%
LABEL_COLUMNS = endpoints

MAX_LEN = 100
train_dataset = PeptideDataset(train_df, esm_tokenizer, LABEL_COLUMNS, MAX_LEN)
val_dataset = PeptideDataset(val_df, esm_tokenizer, LABEL_COLUMNS, MAX_LEN)
test_dataset = PeptideDataset(test_df, esm_tokenizer, LABEL_COLUMNS, MAX_LEN)

# %%
len(train_dataset),  len(val_dataset), len(test_dataset)
# Out:
# (180468, 25784, 51560)

# %%
train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=64, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=True)

# %%
# Calculate weights
NON_FUNC_IDX = endpoint_index['non-functional']
FUNC_INDICES = [i for k, i in endpoint_index.items() if k != 'non-functional']

# %%
# =====================================================================
# Model v19 (Lite): Sequence-Level Cross-Attention + Task Query Decoder
# Parameter Count: ~19.6 Million
# =====================================================================

class ESM2_Encoder(nn.Module):
    def __init__(self, model_name, trainable=True, unfreeze_last_n=0):
        super().__init__()
        self.esm_mlm = AutoModelForMaskedLM.from_pretrained(model_name)
        self.hidden_size = self.esm_mlm.config.hidden_size
        if not trainable:
            for param in self.esm_mlm.parameters():
                param.requires_grad = False
            if unfreeze_last_n > 0:
                for layer in self.esm_mlm.esm.encoder.layer[-unfreeze_last_n:]:
                    for param in layer.parameters():
                        param.requires_grad = True

    def forward(self, input_ids, attention_mask):
        return self.esm_mlm.esm(input_ids=input_ids, attention_mask=attention_mask).last_hidden_state

class SEBlock(nn.Module):
    """
    Mask-aware Squeeze-and-Excitation block.

    Input:
        x        : [B, C, L]
        seq_mask : [B, L], 1 for valid tokens, 0 for PAD

    The channel descriptor is computed using only valid sequence positions.
    """

    def __init__(self, channels, reduction=4):
        super().__init__()

        hidden = max(channels // reduction, 1)

        self.fc = nn.Sequential(
            nn.Linear(channels, hidden),
            nn.ReLU(),
            nn.Linear(hidden, channels),
            nn.Sigmoid()
        )

    def forward(self, x, seq_mask):
        # [B, L] -> [B, 1, L]
        mask = seq_mask.unsqueeze(1).to(dtype=x.dtype)

        # Remove PAD contributions
        x_masked = x * mask

        # Number of valid positions per sequence
        lengths = seq_mask.sum(
            dim=1,
            keepdim=True
        ).clamp_min(1).to(dtype=x.dtype)

        # Masked global average pooling over sequence dimension
        # [B, C, L] -> [B, C]
        channel_descriptor = (
            x_masked.sum(dim=-1) / lengths
        )

        # Channel-wise gates
        gates = self.fc(channel_descriptor).unsqueeze(-1)

        # Apply channel recalibration
        return x * gates

class ConvBlock(nn.Module):
    """
    Mask-aware two-layer 1D convolution block.

    Uses LayerNorm instead of BatchNorm so that padded positions
    do not participate in batch/sequence normalization statistics.
    """

    def __init__(self, in_channels, out_channels, kernel_size):
        super().__init__()

        self.conv1 = nn.Conv1d(
            in_channels,
            out_channels,
            kernel_size=kernel_size,
            padding=kernel_size // 2,
            bias=False
        )

        self.norm1 = nn.LayerNorm(out_channels)

        self.conv2 = nn.Conv1d(
            out_channels,
            out_channels,
            kernel_size=kernel_size,
            padding=kernel_size // 2,
            bias=False
        )

        self.norm2 = nn.LayerNorm(out_channels)

    @staticmethod
    def apply_layernorm(x, norm):
        """
        Conv output: [B, C, L]
        LayerNorm expects normalized dimension at the end.
        """
        x = x.transpose(1, 2)      # [B, L, C]
        x = norm(x)
        x = x.transpose(1, 2)      # [B, C, L]
        return x

    def forward(self, x, mask):
        """
        x    : [B, C, L]
        mask : [B, 1, L]
        """
        # First convolution
        y = self.conv1(x)
        y = self.apply_layernorm(
            y,
            self.norm1
        )

        y = F.gelu(y)

        # Explicitly remove PAD activations
        y = y * mask

        # Second convolution
        y = self.conv2(y)

        y = self.apply_layernorm(
            y,
            self.norm2
        )

        y = F.gelu(y)

        # Explicitly remove PAD activations again
        y = y * mask

        return y

class EnhancedCNN1D(nn.Module):
    """
    Mask-aware multi-scale CNN for peptide/protein sequences.

    Branches:
        kernel 3 -> effective receptive field 5
        kernel 5 -> effective receptive field 9
        kernel 7 -> effective receptive field 13

    Each branch contains two convolutional layers.

    Output:
        [B, 2 * 3 * conv_dim]

    For conv_dim=128:
        output = [B, 768]
    """

    def __init__(
        self,
        vocab_size=33,
        embed_dim=128,
        conv_dim=128
    ):
        super().__init__()


        # Token embedding
        self.embed = nn.Embedding(
            num_embeddings=vocab_size,
            embedding_dim=embed_dim,
            padding_idx=1 # ESM TOKENIZER
        )

        # Multi-scale CNN branches
        self.branches = nn.ModuleList([
            ConvBlock(
                in_channels=embed_dim,
                out_channels=conv_dim,
                kernel_size=k
            )
            for k in [3, 5, 7]
        ])

        # Residual projection
        self.res_proj = nn.Conv1d(
            embed_dim,
            conv_dim,
            kernel_size=1,
            bias=False
        )

        # Squeeze-and-Excitation
        self.se = SEBlock(
            channels=conv_dim * 3,
            reduction=4
        )

        self.dropout = nn.Dropout(0.2)

        # Three branches × conv_dim channels
        # Max pooling + mean pooling
        self.hidden_size = conv_dim * 3 * 2

    def forward(self, x, seq_mask):
        """
        Args:
            x:
                [B, L] token IDs

            seq_mask:
                [B, L]
                1 = valid token
                0 = PAD
        Returns:
            CNN feature vector:
                [B, hidden_size]

        For conv_dim=128:
            [B, 768]
        """


        # Validate mask


        if seq_mask is None:
            raise ValueError(
                "seq_mask must be provided to EnhancedCNN1D. "
                "CNN padding masking must never be bypassed."
            )
        # Embedding
        # [B, L] -> [B, L, embed_dim]
        x = self.embed(x)

        # [B, L, embed_dim] -> [B, embed_dim, L]
        x = x.transpose(1, 2)

        # [B, L] -> [B, 1, L]
        mask = seq_mask.unsqueeze(1).to(dtype=x.dtype)

        # Explicitly zero PAD embeddings
        x = x * mask

        # Residual pathway
        res = self.res_proj(x)

        # Remove PAD activations
        res = res * mask

        # Multi-scale branches
        outs = []

        for branch in self.branches:
            y = branch(x, mask)
            # Residual connection
            y = y + res
            # Guarantee PAD = 0 after residual addition
            y = y * mask
            outs.append(y)

        # Concatenate branches
        # [B, 128*3, L]
        combined = torch.cat(
            outs,
            dim=1
        )

        # Guarantee no PAD signal
        combined = combined * mask

        # Mask-aware SE
        combined = self.se(
            combined,
            seq_mask
        )

        # SE can theoretically produce nonzero values
        # at PAD positions, so mask once more.
        combined = combined * mask

        # MASKED GLOBAL MAX POOLING
        # PAD cannot become the maximum.
        combined_for_max = combined.masked_fill(
            seq_mask.unsqueeze(1) == 0,
            torch.finfo(combined.dtype).min
        )

        max_pooled = combined_for_max.max(
            dim=-1
        ).values


        # MASKED GLOBAL MEAN POOLING
        combined_for_mean = combined * mask

        # Actual number of valid tokens
        lengths = seq_mask.sum(
            dim=1,
            keepdim=True
        ).clamp_min(1).to(
            dtype=combined.dtype
        )

        mean_pooled = (
            combined_for_mean.sum(dim=-1)
            / lengths
        )

        # FINAL REPRESENTATION
        pooled = torch.cat(
            [
                max_pooled,
                mean_pooled
            ],
            dim=1
        )

        return self.dropout(pooled)


class MultiHeadAttentionPool(nn.Module):
    def __init__(self, dim, num_heads=4):
        super().__init__()
        self.num_heads = num_heads
        self.attn = nn.Sequential(
            nn.Linear(dim, 128), 
            nn.Tanh(), 
            nn.Linear(128, num_heads)
        )
        self._last_weights = None

    def forward(self, x, mask):
        scores = self.attn(x)
        scores = scores.masked_fill(mask.unsqueeze(-1) == 0, -1e4)
        weights = torch.softmax(scores, dim=1)
        self._last_weights = weights
        pooled = (x.unsqueeze(2) * weights.unsqueeze(-1)).sum(dim=1)
        return pooled.view(x.size(0), -1)


    def orthogonality_loss(self):
        """Penalize overlap between head attention distributions."""
        if self._last_weights is None:
            return 0.0
            
        # weights: [B, L, num_heads] -> transpose to [B, num_heads, L]
        w = self._last_weights.transpose(1, 2)  
        
        # Gram matrix of head attention distributions: shape [B, num_heads, num_heads]
        gram = torch.bmm(w, w.transpose(1, 2))  
        
        # Create a boolean mask for the off-diagonal elements (~torch.eye inverts the identity matrix)
        mask = ~torch.eye(self.num_heads, dtype=torch.bool, device=gram.device)
        
        # Penalize only the off-diagonal overlap to encourage heads to focus on different tokens.
        # We want these dot products to be pushed towards 0.
        loss = (gram[:, mask] ** 2).mean()
        
        return loss
    
class GatedFusion(nn.Module):
    def __init__(self, input_dim):
        super().__init__()
        self.gate = nn.Sequential(nn.Linear(input_dim, input_dim), nn.Sigmoid())
    def forward(self, x):
        return x * self.gate(x)

class PeptideNetwork(nn.Module):
    def __init__(self, num_classes=21, mask_token_id=32):
        super().__init__()
        self.mask_token_id = mask_token_id
        self.num_classes = num_classes

        # BOTH encoders are now the 8M parameter t6 model
        self.esm_t6_a = ESM2_Encoder("facebook/esm2_t6_8M_UR50D", trainable=True)        
        self.esm_t6_b = ESM2_Encoder("facebook/esm2_t6_8M_UR50D", trainable=False, unfreeze_last_n=2)                                  
        self.cnn = EnhancedCNN1D()          # Bx768

        # REDUCED cross_dim to 128 to save parameters
        cross_dim = 128
        self.proj_t6_a = nn.Linear(320, cross_dim)
        self.proj_t6_b = nn.Linear(320, cross_dim) # Updated to 320 for t6

        self.cross_t6_a = nn.MultiheadAttention(cross_dim, num_heads=4, batch_first=True, dropout=0.1)
        self.ln_ca_t6_a = nn.LayerNorm(cross_dim)
        
        self.cross_t6_b = nn.MultiheadAttention(cross_dim, num_heads=4, batch_first=True, dropout=0.1)
        self.ln_ca_t6_b = nn.LayerNorm(cross_dim)
        
        self.pool_t6_a = MultiHeadAttentionPool(cross_dim, num_heads=4)
        self.pool_t6_b = MultiHeadAttentionPool(cross_dim, num_heads=4)

        # Bottleneck reduction layer before fusion
        # Concat size: 128*4*3 (pools) + 768 (CNN) = 1536 + 768 = 2304
        concat_size = cross_dim * 4 * 2 + self.cnn.hidden_size
        
        self.dim_reduce = nn.Sequential(
            nn.Linear(concat_size, 512),
            nn.GELU()
        )
        
        # Fusion now operates efficiently on 512 dimensions
        self.fusion = GatedFusion(512)
        self.ln = nn.LayerNorm(512)

        # binary head
        binary_features_dim = 64
        self.binary_features = nn.Sequential(
            nn.Linear(512, binary_features_dim),
            nn.GELU(),
            nn.Dropout(0.2)
        )
        self.binary_classifier = nn.Linear(64, 1) # Final logit

        # Task Query Decoder
        self.task_dim = 128
        self.n_memory_tokens = 16
        self.memory_proj = nn.Sequential(
            nn.Linear(512 + binary_features_dim, self.task_dim * self.n_memory_tokens),
            nn.GELU(),
        )
        self.task_queries = nn.Embedding(num_classes, self.task_dim)
        decoder_layer = nn.TransformerDecoderLayer(
            d_model=self.task_dim, nhead=4, dim_feedforward=256,
            batch_first=True, dropout=0.1
        )
        self.task_decoder = nn.TransformerDecoder(decoder_layer, num_layers=2)
        self.task_classifiers = nn.ModuleList([
            nn.Linear(self.task_dim, 1) for _ in range(num_classes)
        ])

    def _mask_tokens(self, input_ids, attention_mask, mask_prob=0.15):
        masked_ids = input_ids.clone()
        prob_matrix = torch.full_like(input_ids, mask_prob, dtype=torch.float)
        prob_matrix[attention_mask == 0] = 0
        prob_matrix[:, 0] = 0
        seq_lens = attention_mask.sum(dim=1)
        for i in range(len(seq_lens)):
            if seq_lens[i] > 1:
                prob_matrix[i, seq_lens[i] - 1] = 0
        mask = torch.bernoulli(prob_matrix).bool()
        masked_ids[mask] = self.mask_token_id
        return masked_ids

    def _extract_features(self, seq_input, seq_mask):
        esm6_a_seq = self.esm_t6_a(seq_input, seq_mask)       
        esm6_b_seq = self.esm_t6_b(seq_input, seq_mask)     
        cnn_feat = self.cnn(seq_input, seq_mask)                          

        t6_a = self.proj_t6_a(esm6_a_seq)       
        t6_b = self.proj_t6_b(esm6_b_seq)    


        kv_pad = seq_mask == 0  

        ca_t6_a, _ = self.cross_t6_a(t6_a, t6_b, t6_b, key_padding_mask=kv_pad)
        ca_t6_a = self.ln_ca_t6_a(t6_a + ca_t6_a)

        ca_t6_b, _ = self.cross_t6_b(t6_b, t6_a, t6_a, key_padding_mask=kv_pad)
        ca_t6_b = self.ln_ca_t6_b(t6_b + ca_t6_b)

        pooled_t6_a = self.pool_t6_a(ca_t6_a, seq_mask)
        pooled_t6_b = self.pool_t6_b(ca_t6_b, seq_mask)

        # Concat -> Reduce -> Fuse
        combined = torch.cat([pooled_t6_a, pooled_t6_b, cnn_feat], dim=1)  
        reduced = self.dim_reduce(combined)
        fusion = self.ln(reduced + self.fusion(reduced))

        binary_features = self.binary_features(fusion)
        
        return binary_features, torch.cat([fusion, binary_features], dim=1)
    
    def _binary_classify(self, binary_features):
        
        binary_logits = self.binary_classifier(binary_features)

        return binary_logits

    def _classify(self, final_fusion):
        B = final_fusion.size(0)
        memory = self.memory_proj(final_fusion).view(B, self.n_memory_tokens, self.task_dim)
        tgt = self.task_queries.weight.unsqueeze(0).expand(B, -1, -1)
        decoded = self.task_decoder(tgt, memory)
        logits = torch.cat([self.task_classifiers[i](decoded[:, i, :])
                           for i in range(self.num_classes)], dim=1)
        return logits

    def forward(self, seq_input, seq_mask, mask_tokens=False):
        if mask_tokens and self.training:
            seq_input = self._mask_tokens(seq_input, seq_mask)
        
        binary_features, combined_features = self._extract_features(seq_input, seq_mask)
        

        return self._binary_classify(binary_features), self._classify(combined_features)


    def ortho_loss(self):
        return (self.pool_t6_a.orthogonality_loss() +
                self.pool_t6_b.orthogonality_loss() 
                ) / 2
    
    def get_features(self, seq_input, seq_mask, mask_tokens=False):
        if mask_tokens and self.training:
            seq_input = self._mask_tokens(seq_input, seq_mask)
        return self._extract_features(seq_input, seq_mask)

    def multi_classify(self, combined):
        return self._classify(combined)
    
    def binary_classify(self, binary_features):
        return self._binary_classify(binary_features)

# %% [markdown]
# # training: function and non-functionl(whole sequence)

# %%
import copy
class EMA:
    def __init__(self, model, decay=0.999):
        self.decay = decay
        self.shadow = copy.deepcopy(model)
        self.shadow.eval()
        for p in self.shadow.parameters():
            p.requires_grad_(False)

    @torch.no_grad()
    def update(self, model):
        # Update parameters (weights & biases)
        for s_param, m_param in zip(self.shadow.parameters(), model.parameters()):
            s_param.data.mul_(self.decay).add_(m_param.data, alpha=1 - self.decay)
        
        # FIX: Update only floating point buffers (skip int buffers like num_batches_tracked)
        for s_buf, m_buf in zip(self.shadow.buffers(), model.buffers()):
            if s_buf.dtype.is_floating_point:
                s_buf.data.mul_(self.decay).add_(m_buf.data, alpha=1 - self.decay)
            else:
                # For integer buffers, just copy directly (no EMA smoothing needed)
                s_buf.data.copy_(m_buf.data)

    def forward(self, *args, **kwargs):
        return self.shadow(*args, **kwargs)

# %%
torch.cuda.empty_cache()

model = PeptideNetwork(num_classes=len(endpoints)-1, mask_token_id=32).to(DEVICE)
ema = EMA(model, decay=0.999)

# --- ASL: Asymmetric Loss for Multi-Label Classification ---
class AsymmetricLoss(nn.Module):
    def __init__(self, gamma_neg=4, gamma_pos=1, clip=0.05):
        super().__init__()
        self.gamma_neg = gamma_neg
        self.gamma_pos = gamma_pos
        self.clip = clip

    def forward(self, logits, targets):
        p = torch.sigmoid(logits)
        pos_part = targets * torch.log(p.clamp(min=1e-8))
        neg_p = (1 - p).clamp(min=1e-8)
        if self.clip > 0:
            neg_p = (neg_p + self.clip).clamp(max=1)
        neg_part = (1 - targets) * torch.log(neg_p)
        pos_weight = (1 - p) ** self.gamma_pos
        neg_weight = p ** self.gamma_neg
        loss = -(pos_weight * pos_part + neg_weight * neg_part)
        return loss.mean()

criterion = AsymmetricLoss(gamma_neg=4, gamma_pos=1, clip=0.05)
binary_criterion = nn.BCEWithLogitsLoss()

# Optimizer — 3 LR groups (Lowered LRs to prevent early overfitting)
esm_t6_ids = set(id(p) for p in model.esm_t6_a.esm_mlm.parameters())
esm_t6_b_ids = set(id(p) for p in model.esm_t6_b.esm_mlm.parameters())

esm_t6_params = [p for p in model.parameters() if id(p) in esm_t6_ids and p.requires_grad]
esm_t6_b_params = [p for p in model.parameters() if id(p) in esm_t6_b_ids and p.requires_grad]
other_params = [p for p in model.parameters() if id(p) not in esm_t6_ids and id(p) not in esm_t6_b_ids and p.requires_grad]

optimizer = optim.AdamW([
    {'params': esm_t6_params, 'lr': 1e-5},     # Reduced from 1e-5
    {'params': esm_t6_b_params, 'lr': 2e-6},   # Reduced from 2e-6
    {'params': other_params, 'lr': 1e-4},      # Reduced from 1e-4
], weight_decay=0.05)                          # Kept the stronger L2 regularization

total_params = sum(p.numel() for p in model.parameters())
trainable_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
print(f"Total: {total_params/1e6:.1f}M | Trainable: {trainable_params/1e6:.1f}M")
print(f"Loss: ASL(γ-=4, γ+=1, clip=0.05) | v19: Triple CrossAttn + Task Query Decoder")
# Out:
# Total: 18.7M | Trainable: 13.6M
# Loss: ASL(γ-=4, γ+=1, clip=0.05) | v19: Triple CrossAttn + Task Query Decoder

# %%
NON_FUNC_IDX = endpoint_index['non-functional']
FUNC_INDICES = [i for k, i in endpoint_index.items() if k != 'non-functional']

# %%
epochs = 80

# %%
# Warmup + Cosine Annealing
steps_per_epoch = len(train_loader)
warmup_epochs = 3
total_steps = epochs * steps_per_epoch

def lr_lambda(step):
    if step < warmup_epochs * steps_per_epoch:
        return step / (warmup_epochs * steps_per_epoch)
    progress = (step - warmup_epochs * steps_per_epoch) / (total_steps - warmup_epochs * steps_per_epoch)
    return 0.5 * (1 + math.cos(math.pi * progress))

scheduler = optim.lr_scheduler.LambdaLR(optimizer, lr_lambda)
print(f"Warmup ({warmup_epochs} ep) + CosineAnnealing, total {epochs} epochs, {total_steps} steps")
# Out:
# Warmup (3 ep) + CosineAnnealing, total 80 epochs, 225600 steps

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score

# %%
from sklearn.metrics import matthews_corrcoef, accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, confusion_matrix
import json

# %%
# --- HELPER FUNCTIONS ---
def calculate_complete_metrics(y_true, y_pred_probs, thresholds, class_names):
    results = {}
    for i in range(y_true.shape[1]):
        y_pred_cls = (y_pred_probs[:, i] >= thresholds[i]).astype(int)
        mcc = matthews_corrcoef(y_true[:, i], y_pred_cls)
        acc = accuracy_score(y_true[:, i], y_pred_cls)
        prec = precision_score(y_true[:, i], y_pred_cls, zero_division=0)
        rec = recall_score(y_true[:, i], y_pred_cls, zero_division=0)
        f1 = f1_score(y_true[:, i], y_pred_cls, zero_division=0)
        try:
            auc_val = roc_auc_score(y_true[:, i], y_pred_probs[:, i])
        except ValueError:
            auc_val = 0.5
        tn, fp, fn, tp = confusion_matrix(y_true[:, i], y_pred_cls, labels=[0, 1]).ravel()
        results[class_names[i]] = {
            "mcc": float(mcc),
            "threshold": float(thresholds[i]),
            "accuracy": float(acc),
            "precision": float(prec),
            "recall": float(rec),
            "f1_score": float(f1),
            "roc_auc": float(auc_val),
            "tp": int(tp),
            "tn": int(tn),
            "fp": int(fp),
            "fn": int(fn),
        }
    return results

def find_optimal_thresholds(y_true, y_pred_probs):
    optimal_thresholds = []
    for i in range(y_true.shape[1]):
        best_mcc = -1
        best_threshold = 0.5
        for threshold in np.arange(0.1, 0.95, 0.05):
            y_pred_class = (y_pred_probs[:, i] >= threshold).astype(int)
            mcc = matthews_corrcoef(y_true[:, i], y_pred_class)
            if mcc > best_mcc:
                best_mcc = mcc
                best_threshold = threshold
        optimal_thresholds.append(best_threshold)
    return optimal_thresholds

def calculate_mcc(tp, tn, fp, fn):
    num = (tp * tn) - (fp * fn)
    den_sq = (tp + fp) * (tp + fn) * (tn + fp) * (tn + fn)
    return num / math.sqrt(den_sq) if den_sq > 0 else 0.0

def aggregate_mcc(*metric_groups):
    tp, tn, fp, fn = 0, 0, 0, 0
    for metrics in metric_groups:
        for values in metrics.values():
            tp += values['tp']
            tn += values['tn']
            fp += values['fp']
            fn += values['fn']
    return calculate_mcc(tp, tn, fp, fn)

def feature_mixup(features, labels, alpha=0.4):
    batch_size = features.size(0)
    lam = np.random.beta(alpha, alpha) if alpha > 0 else 1.0
    index = torch.randperm(batch_size, device=features.device)
    mixed_features = lam * features + (1 - lam) * features[index]
    mixed_labels = lam * labels + (1 - lam) * labels[index]
    return mixed_features, mixed_labels

def rdrop_kl_loss(logits1, logits2):
    kl1 = F.binary_cross_entropy_with_logits(logits1, torch.sigmoid(logits2).detach(), reduction='mean')
    kl2 = F.binary_cross_entropy_with_logits(logits2, torch.sigmoid(logits1).detach(), reduction='mean')
    return (kl1 + kl2) / 2

def enable_dropout(model):
    """
    Specifically tailored for PeptideNetwork to activate all sources of dropout
    during Test-Time Augmentation (TTA), including functional dropouts hidden 
    inside complex PyTorch modules.
    """
    for module in model.modules():
        class_name = module.__class__.__name__
        
        # 1. Standard explicit dropout layers (Dropout, Dropout1d, Dropout2d)
        if class_name.startswith('Dropout'):
            module.train()
            
        # 2. Cross-Attention functional dropout
        elif class_name == 'MultiheadAttention':
            module.train()
            
        # 3. Task Query Decoder functional dropout
        elif class_name in ['TransformerDecoder', 'TransformerDecoderLayer']:
            module.train()
            
        # 4. GRU functional dropout (applied between internal layers)
        elif class_name == 'GRU':
            module.train()


# --- SWA ---
swa_start_epoch = 30
swa_model = None
swa_n = 0

def update_swa(model_state, swa_state, n):
    if swa_state is None:
        return {k: v.clone() for k, v in model_state.items()}, 1
    for k in swa_state:
        swa_state[k] = (swa_state[k] * n + model_state[k]) / (n + 1)
    return swa_state, n + 1

# --- MAIN TRAINING LOOP ---
history_log = []
history_log_path = "cd_hit_0.9.json"
best_model_path = "cd_hit_0.9.pt"
best_val_mcc = -1.0
scaler = torch.amp.GradScaler('cuda')
patience_counter = 0
early_stop_patience = 20
mixup_alpha = 0.4
rdrop_alpha = 1.0
tta_passes = 5

func_names = [index_endpoint[i] for i in FUNC_INDICES]
bin_names = ["NON-FUNCTIONAL"]
bin_thresh = [0.5]
spec_thresh = [0.5] * len(func_names)

print("Training v19: Triple CrossAttn + Task Query Decoder + ASL")
print(f"  ASL(γ-=4, γ+=1, clip=0.05)")
print(f"  R-Drop α={rdrop_alpha} | Mixup α={mixup_alpha} | SWA from ep {swa_start_epoch}")
print(f"  Validation eval: TTA={tta_passes} | Test eval: simple (no TTA)")
print("=" * 70)
for epoch in range(1, epochs + 1):
    model.train()
    total_train_loss = 0.0

    for data in train_loader:
        input_ids = data['input_ids'].to(DEVICE)
        attention_mask = data['attention_mask'].to(DEVICE)
        labels = data['labels'].to(DEVICE)

        optimizer.zero_grad()

        # Binary label: 1 if NON-FUNCTIONAL, 0 if FUNCTIONAL
        target_bin = labels[:, NON_FUNC_IDX].unsqueeze(1).float()
        target_spec = labels[:, FUNC_INDICES]

        with torch.amp.autocast('cuda'):
            # Two augmented passes for R-Drop
            bin_features1, features1 = model.get_features(input_ids, attention_mask, mask_tokens=True)
            bin_features2, features2 = model.get_features(input_ids, attention_mask, mask_tokens=True)

            # 1. Clean predictions
            logits1_clean = model.multi_classify(features1)
            logits2_clean = model.multi_classify(features2)

            # 2. Binary classification (Always on the whole batch)
            binary_logits = model.binary_classify(bin_features2)
            binary_loss = binary_criterion(binary_logits, target_bin)
            ortho = model.ortho_loss()

            # --- THE FIX: Boolean Masking ---
            is_functional_mask = (target_bin == 0).view(-1).bool()
            
            if is_functional_mask.sum() > 0:
                # Slice out ONLY the functional peptides
                func_f1 = features1[is_functional_mask]
                func_targets = target_spec[is_functional_mask]
                func_logits1 = logits1_clean[is_functional_mask]
                func_logits2 = logits2_clean[is_functional_mask]

                # R-Drop only on functional
                rdrop_loss = rdrop_kl_loss(func_logits1, func_logits2)
                
                # Mixup only on functional
                mixed_f, mixed_y = feature_mixup(func_f1, func_targets, alpha=mixup_alpha)
                logits_mix = model.multi_classify(mixed_f)
                
                # ASL evaluates ONLY the functional slice
                asl_loss_mix = criterion(logits_mix, mixed_y)
                asl_loss_clean = criterion(func_logits2, func_targets)
                
                spec_loss = (asl_loss_mix + asl_loss_clean) / 2 + (rdrop_alpha * rdrop_loss) + (0.1 * ortho)
                loss = 0.3 * binary_loss + 0.7 * spec_loss
            else:
                # If batch is 100% non-functional
                loss = binary_loss + (0.1 * ortho)

        scaler.scale(loss).backward()
        scaler.unscale_(optimizer)
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
        scaler.step(optimizer)
        scaler.update()
        scheduler.step()
        ema.update(model)

        total_train_loss += loss.item() * input_ids.size(0)

    # --- SWA Update ---
    if epoch >= swa_start_epoch:
        swa_model, swa_n = update_swa(ema.shadow.state_dict(), swa_model, swa_n)

    if swa_model is not None and epoch >= swa_start_epoch:
        eval_model = copy.deepcopy(ema.shadow)
        eval_model.load_state_dict(swa_model)
        eval_model.eval()
    else:
        eval_model = ema.shadow
        eval_model.eval()

    # --- VALIDATION (TTA) ---
    total_val_loss = 0.0
    val_bin_y = []
    val_spec_y = []
    val_tta_bin_preds = [[] for _ in range(tta_passes)]
    val_tta_spec_preds = [[] for _ in range(tta_passes)]

    with torch.no_grad():
        for data in val_loader:
            input_ids = data['input_ids'].to(DEVICE)
            attention_mask = data['attention_mask'].to(DEVICE)
            labels = data['labels'].to(DEVICE)

            target_bin = labels[:, NON_FUNC_IDX].unsqueeze(1).float()
            target_spec = labels[:, FUNC_INDICES]

            with torch.amp.autocast('cuda'):
                pred_bin, pred_spec = eval_model(input_ids, attention_mask)
                loss_bin = binary_criterion(pred_bin, target_bin)

                is_functional_mask = (target_bin == 0).view(-1).bool()
                if is_functional_mask.sum() > 0:
                    loss_spec = criterion(pred_spec[is_functional_mask], target_spec[is_functional_mask])
                    loss_val = 0.3 * loss_bin + 0.7 * loss_spec
                else:
                    loss_val = loss_bin  # fallback if batch has no functional peptides

            total_val_loss += loss_val.item() * input_ids.size(0)
            
            # Append entire batch for both binary and specific targets
            val_bin_y.append(target_bin.cpu().numpy())
            val_spec_y.append(target_spec.cpu().numpy()) 
            
            val_tta_bin_preds[0].append(torch.sigmoid(pred_bin).detach().cpu().numpy())
            val_tta_spec_preds[0].append(torch.sigmoid(pred_spec).detach().cpu().numpy())

            if tta_passes > 1:
                enable_dropout(eval_model)
                for t in range(1, tta_passes):
                    with torch.amp.autocast('cuda'):
                        pred_bin_t, pred_spec_t = eval_model(input_ids, attention_mask)
                    val_tta_bin_preds[t].append(torch.sigmoid(pred_bin_t).detach().cpu().numpy())
                    val_tta_spec_preds[t].append(torch.sigmoid(pred_spec_t).detach().cpu().numpy())
                eval_model.eval()

    y_true_bin_val = np.concatenate(val_bin_y)
    y_pred_bin_val = np.mean([np.concatenate(pred_list) for pred_list in val_tta_bin_preds], axis=0)
    
    y_true_spec_val = np.concatenate(val_spec_y)
    raw_pred_spec_val = np.mean([np.concatenate(pred_list) for pred_list in val_tta_spec_preds], axis=0)

    # SOFT GATING: Scale specific predictions by functionality probability
    # y_pred_bin_val is probability of NON-FUNCTIONAL, so 1 - y_pred_bin_val is prob of FUNCTIONAL
    y_pred_spec_val = raw_pred_spec_val * (1 - y_pred_bin_val)

    # Compute optimal thresholds on Validation set
    opt_bin_thresh = find_optimal_thresholds(y_true_bin_val.reshape(-1, 1), y_pred_bin_val.reshape(-1, 1))
    opt_spec_thresh = find_optimal_thresholds(y_true_spec_val, raw_pred_spec_val)


    val_bin_metrics = calculate_complete_metrics(y_true_bin_val, y_pred_bin_val, opt_bin_thresh, bin_names)
    val_spec_metrics = calculate_complete_metrics(y_true_spec_val, y_pred_spec_val, opt_spec_thresh, func_names)
    val_total_mcc = aggregate_mcc(val_bin_metrics, val_spec_metrics)
    
    val_func_mccs = [metrics['mcc'] for metrics in val_spec_metrics.values() if not np.isnan(metrics['mcc'])]
    val_avg_func_mcc = sum(val_func_mccs) / len(val_func_mccs) if val_func_mccs else 0.0


    # --- TEST (TTA) ---
    total_test_loss = 0.0
    test_bin_y = []
    test_spec_y = []
    test_tta_bin_preds = [[] for _ in range(tta_passes)]
    test_tta_spec_preds = [[] for _ in range(tta_passes)]

    with torch.no_grad():
        for data in test_loader:
            input_ids = data['input_ids'].to(DEVICE)
            attention_mask = data['attention_mask'].to(DEVICE)
            labels = data['labels'].to(DEVICE)

            target_bin = labels[:, NON_FUNC_IDX].unsqueeze(1).float()
            target_spec = labels[:, FUNC_INDICES]

            with torch.amp.autocast('cuda'):
                pred_bin, pred_spec = eval_model(input_ids, attention_mask)
                loss_bin = binary_criterion(pred_bin, target_bin)
                
                is_functional_mask = (target_bin == 0).view(-1).bool()
                if is_functional_mask.sum() > 0:
                    loss_spec = criterion(pred_spec[is_functional_mask], target_spec[is_functional_mask])
                    loss_test = 0.3 * loss_bin + 0.7 * loss_spec
                else:
                    loss_test = loss_bin

            total_test_loss += loss_test.item() * input_ids.size(0)
            
            test_bin_y.append(target_bin.cpu().numpy())
            test_spec_y.append(target_spec.cpu().numpy())
            
            # First pass predictions
            test_tta_bin_preds[0].append(torch.sigmoid(pred_bin).detach().cpu().numpy())
            test_tta_spec_preds[0].append(torch.sigmoid(pred_spec).detach().cpu().numpy())

            # Additional TTA passes
            if tta_passes > 1:
                enable_dropout(eval_model)
                for t in range(1, tta_passes):
                    with torch.amp.autocast('cuda'):
                        pred_bin_t, pred_spec_t = eval_model(input_ids, attention_mask)
                    test_tta_bin_preds[t].append(torch.sigmoid(pred_bin_t).detach().cpu().numpy())
                    test_tta_spec_preds[t].append(torch.sigmoid(pred_spec_t).detach().cpu().numpy())
                eval_model.eval()

    y_true_bin_test = np.concatenate(test_bin_y)
    y_pred_bin_test = np.mean([np.concatenate(pred_list) for pred_list in test_tta_bin_preds], axis=0)
    
    y_true_spec_test = np.concatenate(test_spec_y)
    raw_pred_spec_test = np.mean([np.concatenate(pred_list) for pred_list in test_tta_spec_preds], axis=0)

    # SOFT GATING for Test
    y_pred_spec_test = raw_pred_spec_test * (1 - y_pred_bin_test)

    test_bin_metrics = calculate_complete_metrics(y_true_bin_test, y_pred_bin_test, opt_bin_thresh, bin_names)
    test_spec_metrics = calculate_complete_metrics(y_true_spec_test, y_pred_spec_test, opt_spec_thresh, func_names)
    test_total_mcc = aggregate_mcc(test_bin_metrics, test_spec_metrics)

    test_func_mccs = [metrics['mcc'] for metrics in test_spec_metrics.values() if not np.isnan(metrics['mcc'])]
    test_avg_func_mcc = sum(test_func_mccs) / len(test_func_mccs) if test_func_mccs else 0.0

    avg_train_loss = total_train_loss / len(train_loader.dataset)
    avg_val_loss = total_val_loss / len(val_loader.dataset)
    avg_test_loss = total_test_loss / len(test_loader.dataset)

    if val_avg_func_mcc > best_val_mcc:
        best_val_mcc = val_avg_func_mcc
        patience_counter = 0
        torch.save(eval_model.state_dict(), best_model_path)
        marker = " >>> BEST <<<"
    else:
        patience_counter += 1
        marker = ""

    lr_now = optimizer.param_groups[0]['lr']
    swa_tag = f" [SWA n={swa_n}]" if epoch >= swa_start_epoch else ""
    print(f"Ep {epoch:02d}/{epochs} | LR: {lr_now:.1e} | Train: {avg_train_loss:.4f} | Val: {avg_val_loss:.4f} | Test: {avg_test_loss:.4f}{swa_tag}")
    print(f"  MCC -> Func Avg (Val): {val_avg_func_mcc:.4f} | Func Avg (Test): {test_avg_func_mcc:.4f} | Pat: {patience_counter}/{early_stop_patience}{marker}")
    print(f"  Overall Total MCC -> Val: {val_total_mcc:.4f} | Test: {test_total_mcc:.4f}")
    print(f"  NON-FUNCTIONAL MCC -> Val: {val_bin_metrics['NON-FUNCTIONAL']['mcc']:.4f} | Test: {test_bin_metrics['NON-FUNCTIONAL']['mcc']:.4f}")
    
    for name in func_names:
        val_mcc = val_spec_metrics[name]['mcc'] if name in val_spec_metrics else float('nan')
        test_mcc = test_spec_metrics[name]['mcc'] if name in test_spec_metrics else float('nan')
        print(f"  {name:16s}: Val MCC={val_mcc:.4f} | Test MCC={test_mcc:.4f}")
    print("-" * 70)

    epoch_data = {
        "epoch": epoch,
        "train_loss": avg_train_loss,
        "val_loss": avg_val_loss,
        "test_loss": avg_test_loss,
        "val_total_mcc": float(val_total_mcc),
        "val_func_mcc": float(val_avg_func_mcc),
        "test_total_mcc": float(test_total_mcc),
        "test_func_mcc": float(test_avg_func_mcc),
        "thresholds": {
            "binary": opt_bin_thresh,
            "functional": opt_spec_thresh,
        },
        "val_metrics": {**val_bin_metrics, **val_spec_metrics},
        "test_metrics": {**test_bin_metrics, **test_spec_metrics},
    }
    history_log.append(epoch_data)
    with open(history_log_path, "w") as f:
        json.dump(history_log, f, indent=2)

    if patience_counter >= early_stop_patience:
        print(f"\nEarly stopping at epoch {epoch}!")
        break

    if swa_model is not None and epoch >= swa_start_epoch:
        del eval_model

print(f"\nTraining Complete! Best Val MCC: {best_val_mcc:.4f}")
# Out:
# Training v19: Triple CrossAttn + Task Query Decoder + ASL
#   ASL(γ-=4, γ+=1, clip=0.05)
#   R-Drop α=1.0 | Mixup α=0.4 | SWA from ep 30
#   Validation eval: TTA=5 | Test eval: simple (no TTA)
# ======================================================================
# Ep 01/80 | LR: 3.3e-06 | Train: 0.5634 | Val: 0.0718 | Test: 0.0718
#   MCC -> Func Avg (Val): 0.3010 | Func Avg (Test): 0.3126 | Pat: 0/20 >>> BEST <<<
#   Overall Total MCC -> Val: 0.6032 | Test: 0.6093
#   NON-FUNCTIONAL MCC -> Val: 0.9158 | Test: 0.9127
#   anti-bacterial  : Val MCC=0.6589 | Test MCC=0.6632
#   anti-cancer     : Val MCC=0.2833 | Test MCC=0.3558
#   anti-fungal     : Val MCC=0.3222 | Test MCC=0.3554
#   anti-parasitic  : Val MCC=0.2401 | Test MCC=0.2994
#   anti-viral      : Val MCC=0.2294 | Test MCC=0.2364
#   cell-cell-communication: Val MCC=0.0000 | Test MCC=0.0000
#   drug-delivery   : Val MCC=0.1359 | Test MCC=0.1687
#   immunological   : Val MCC=0.2871 | Test MCC=0.2757
#   inhibitor       : Val MCC=0.2365 | Test MCC=0.1819
#   metabolic       : Val MCC=0.3244 | Test MCC=0.3233
#   other-functional: Val MCC=-0.0007 | Test MCC=-0.0005
#   signal-peptide  : Val MCC=0.6463 | Test MCC=0.6623
#   toxic           : Val MCC=0.5502 | Test MCC=0.5424
# ----------------------------------------------------------------------
# Ep 02/80 | LR: 6.7e-06 | Train: 0.5193 | Val: 0.0584 | Test: 0.0594
#   MCC -> Func Avg (Val): 0.3955 | Func Avg (Test): 0.3880 | Pat: 0/20 >>> BEST <<<
#   Overall Total MCC -> Val: 0.7220 | Test: 0.7191
#   NON-FUNCTIONAL MCC -> Val: 0.9290 | Test: 0.9282
#   anti-bacterial  : Val MCC=0.7113 | Test MCC=0.6979
#   anti-cancer     : Val MCC=0.3535 | Test MCC=0.3900
#   anti-fungal     : Val MCC=0.4286 | Test MCC=0.4287
#   anti-parasitic  : Val MCC=0.2904 | Test MCC=0.2481
#   anti-viral      : Val MCC=0.3297 | Test MCC=0.3891
#   cell-cell-communication: Val MCC=0.1880 | Test MCC=0.0885
#   drug-delivery   : Val MCC=0.1760 | Test MCC=0.2139
#   immunological   : Val MCC=0.3894 | Test MCC=0.4000
#   inhibitor       : Val MCC=0.3478 | Test MCC=0.2995
#   metabolic       : Val MCC=0.3614 | Test MCC=0.3731
#   other-functional: Val MCC=0.1855 | Test MCC=0.1463
#   signal-peptide  : Val MCC=0.7774 | Test MCC=0.7812
#   toxic           : Val MCC=0.6019 | Test MCC=0.5879
# ----------------------------------------------------------------------
# Ep 03/80 | LR: 1.0e-05 | Train: 0.5082 | Val: 0.0534 | Test: 0.0543
#   MCC -> Func Avg (Val): 0.4474 | Func Avg (Test): 0.4502 | Pat: 0/20 >>> BEST <<<
#   Overall Total MCC -> Val: 0.7602 | Test: 0.7597
#   NON-FUNCTIONAL MCC -> Val: 0.9364 | Test: 0.9347
#   anti-bacterial  : Val MCC=0.7233 | Test MCC=0.7234
#   anti-cancer     : Val MCC=0.3837 | Test MCC=0.4281
#   anti-fungal     : Val MCC=0.4611 | Test MCC=0.4529
#   anti-parasitic  : Val MCC=0.3165 | Test MCC=0.3609
#   anti-viral      : Val MCC=0.3722 | Test MCC=0.4209
#   cell-cell-communication: Val MCC=0.3670 | Test MCC=0.3654
#   drug-delivery   : Val MCC=0.2225 | Test MCC=0.2453
#   immunological   : Val MCC=0.4504 | Test MCC=0.4380
#   inhibitor       : Val MCC=0.4009 | Test MCC=0.3143
#   metabolic       : Val MCC=0.4101 | Test MCC=0.4392
#   other-functional: Val MCC=0.2608 | Test MCC=0.2339
#   signal-peptide  : Val MCC=0.7964 | Test MCC=0.7984
#   toxic           : Val MCC=0.6512 | Test MCC=0.6315
# ----------------------------------------------------------------------
# Ep 04/80 | LR: 1.0e-05 | Train: 0.5013 | Val: 0.0511 | Test: 0.0514
#   MCC -> Func Avg (Val): 0.4783 | Func Avg (Test): 0.4796 | Pat: 0/20 >>> BEST <<<
#   Overall Total MCC -> Val: 0.7807 | Test: 0.7822
#   NON-FUNCTIONAL MCC -> Val: 0.9399 | Test: 0.9390
#   anti-bacterial  : Val MCC=0.7345 | Test MCC=0.7393
#   anti-cancer     : Val MCC=0.4093 | Test MCC=0.4496
#   anti-fungal     : Val MCC=0.4936 | Test MCC=0.4784
#   anti-parasitic  : Val MCC=0.3425 | Test MCC=0.4068
#   anti-viral      : Val MCC=0.4192 | Test MCC=0.4519
#   cell-cell-communication: Val MCC=0.4517 | Test MCC=0.4119
#   drug-delivery   : Val MCC=0.2421 | Test MCC=0.2776
#   immunological   : Val MCC=0.5047 | Test MCC=0.4926
#   inhibitor       : Val MCC=0.4248 | Test MCC=0.3231
#   metabolic       : Val MCC=0.4482 | Test MCC=0.4750
#   other-functional: Val MCC=0.2709 | Test MCC=0.2477
#   signal-peptide  : Val MCC=0.8117 | Test MCC=0.8188
#   toxic           : Val MCC=0.6649 | Test MCC=0.6619
# ----------------------------------------------------------------------
# Ep 05/80 | LR: 1.0e-05 | Train: 0.4955 | Val: 0.0493 | Test: 0.0497
#   MCC -> Func Avg (Val): 0.5026 | Func Avg (Test): 0.5049 | Pat: 0/20 >>> BEST <<<
#   Overall Total MCC -> Val: 0.7894 | Test: 0.7920
#   NON-FUNCTIONAL MCC -> Val: 0.9416 | Test: 0.9406
#   anti-bacterial  : Val MCC=0.7427 | Test MCC=0.7528
#   anti-cancer     : Val MCC=0.4242 | Test MCC=0.4732
#   anti-fungal     : Val MCC=0.5060 | Test MCC=0.4962
#   anti-parasitic  : Val MCC=0.3960 | Test MCC=0.4496
#   anti-viral      : Val MCC=0.4474 | Test MCC=0.4669
#   cell-cell-communication: Val MCC=0.5065 | Test MCC=0.4889
#   drug-delivery   : Val MCC=0.2518 | Test MCC=0.2994
#   immunological   : Val MCC=0.5195 | Test MCC=0.5163
#   inhibitor       : Val MCC=0.4229 | Test MCC=0.3199
#   metabolic       : Val MCC=0.5035 | Test MCC=0.5194
#   other-functional: Val MCC=0.3095 | Test MCC=0.2735
#   signal-peptide  : Val MCC=0.8258 | Test MCC=0.8304
#   toxic           : Val MCC=0.6778 | Test MCC=0.6779
# ----------------------------------------------------------------------
# Ep 26/80 | LR: 8.0e-06 | Train: 0.4521 | Val: 0.0554 | Test: 0.0558
#   MCC -> Func Avg (Val): 0.6182 | Func Avg (Test): 0.6164 | Pat: 0/20 >>> BEST <<<
#   Overall Total MCC -> Val: 0.8436 | Test: 0.8439
#   NON-FUNCTIONAL MCC -> Val: 0.9452 | Test: 0.9463
#   anti-bacterial  : Val MCC=0.8046 | Test MCC=0.8127
#   anti-cancer     : Val MCC=0.5363 | Test MCC=0.5716
#   anti-fungal     : Val MCC=0.6151 | Test MCC=0.5998
#   anti-parasitic  : Val MCC=0.4998 | Test MCC=0.5651
#   anti-viral      : Val MCC=0.5686 | Test MCC=0.5866
#   cell-cell-communication: Val MCC=0.6489 | Test MCC=0.6550
#   drug-delivery   : Val MCC=0.5055 | Test MCC=0.5143
#   immunological   : Val MCC=0.5989 | Test MCC=0.5477
#   inhibitor       : Val MCC=0.4959 | Test MCC=0.4214
#   metabolic       : Val MCC=0.6681 | Test MCC=0.6729
#   other-functional: Val MCC=0.4724 | Test MCC=0.4591
#   signal-peptide  : Val MCC=0.8741 | Test MCC=0.8743
#   toxic           : Val MCC=0.7480 | Test MCC=0.7320
# ----------------------------------------------------------------------
# Ep 27/80 | LR: 7.8e-06 | Train: 0.4511 | Val: 0.0553 | Test: 0.0555
#   MCC -> Func Avg (Val): 0.6194 | Func Avg (Test): 0.6223 | Pat: 0/20 >>> BEST <<<
#   Overall Total MCC -> Val: 0.8403 | Test: 0.8426
#   NON-FUNCTIONAL MCC -> Val: 0.9454 | Test: 0.9476
#   anti-bacterial  : Val MCC=0.8083 | Test MCC=0.8135
#   anti-cancer     : Val MCC=0.5368 | Test MCC=0.5760
#   anti-fungal     : Val MCC=0.6183 | Test MCC=0.6083
#   anti-parasitic  : Val MCC=0.5058 | Test MCC=0.5665
#   anti-viral      : Val MCC=0.5722 | Test MCC=0.6033
#   cell-cell-communication: Val MCC=0.6910 | Test MCC=0.6833
#   drug-delivery   : Val MCC=0.4942 | Test MCC=0.5356
#   immunological   : Val MCC=0.6145 | Test MCC=0.5900
#   inhibitor       : Val MCC=0.4843 | Test MCC=0.4370
#   metabolic       : Val MCC=0.6452 | Test MCC=0.6507
#   other-functional: Val MCC=0.4568 | Test MCC=0.4118
#   signal-peptide  : Val MCC=0.8654 | Test MCC=0.8629
#   toxic           : Val MCC=0.7589 | Test MCC=0.7508
# ----------------------------------------------------------------------
# Ep 28/80 | LR: 7.6e-06 | Train: 0.4499 | Val: 0.0557 | Test: 0.0562
#   MCC -> Func Avg (Val): 0.6189 | Func Avg (Test): 0.6207 | Pat: 1/20
#   Overall Total MCC -> Val: 0.8456 | Test: 0.8472
#   NON-FUNCTIONAL MCC -> Val: 0.9452 | Test: 0.9457
#   anti-bacterial  : Val MCC=0.8087 | Test MCC=0.8162
#   anti-cancer     : Val MCC=0.5401 | Test MCC=0.5771
#   anti-fungal     : Val MCC=0.6077 | Test MCC=0.5890
#   anti-parasitic  : Val MCC=0.5163 | Test MCC=0.5710
#   anti-viral      : Val MCC=0.5726 | Test MCC=0.6078
#   cell-cell-communication: Val MCC=0.6581 | Test MCC=0.6621
#   drug-delivery   : Val MCC=0.4852 | Test MCC=0.5366
#   immunological   : Val MCC=0.5976 | Test MCC=0.5770
#   inhibitor       : Val MCC=0.4930 | Test MCC=0.4113
#   metabolic       : Val MCC=0.6480 | Test MCC=0.6532
#   other-functional: Val MCC=0.4867 | Test MCC=0.4573
#   signal-peptide  : Val MCC=0.8683 | Test MCC=0.8609
#   toxic           : Val MCC=0.7639 | Test MCC=0.7493
# ----------------------------------------------------------------------
# Ep 29/80 | LR: 7.4e-06 | Train: 0.4489 | Val: 0.0555 | Test: 0.0562
#   MCC -> Func Avg (Val): 0.6204 | Func Avg (Test): 0.6281 | Pat: 0/20 >>> BEST <<<
#   Overall Total MCC -> Val: 0.8415 | Test: 0.8443
#   NON-FUNCTIONAL MCC -> Val: 0.9454 | Test: 0.9468
#   anti-bacterial  : Val MCC=0.8083 | Test MCC=0.8183
#   anti-cancer     : Val MCC=0.5440 | Test MCC=0.5849
#   anti-fungal     : Val MCC=0.6195 | Test MCC=0.6101
#   anti-parasitic  : Val MCC=0.5127 | Test MCC=0.5778
#   anti-viral      : Val MCC=0.5769 | Test MCC=0.5917
#   cell-cell-communication: Val MCC=0.6431 | Test MCC=0.6607
#   drug-delivery   : Val MCC=0.4844 | Test MCC=0.5368
#   immunological   : Val MCC=0.6037 | Test MCC=0.5808
#   inhibitor       : Val MCC=0.5058 | Test MCC=0.4394
#   metabolic       : Val MCC=0.6679 | Test MCC=0.6764
#   other-functional: Val MCC=0.4701 | Test MCC=0.4730
#   signal-peptide  : Val MCC=0.8682 | Test MCC=0.8623
#   toxic           : Val MCC=0.7610 | Test MCC=0.7531
# ----------------------------------------------------------------------
# Ep 30/80 | LR: 7.3e-06 | Train: 0.4477 | Val: 0.0566 | Test: 0.0575 [SWA n=1]
#   MCC -> Func Avg (Val): 0.6231 | Func Avg (Test): 0.6267 | Pat: 0/20 >>> BEST <<<
#   Overall Total MCC -> Val: 0.8419 | Test: 0.8430
#   NON-FUNCTIONAL MCC -> Val: 0.9463 | Test: 0.9467
#   anti-bacterial  : Val MCC=0.7854 | Test MCC=0.7885
#   anti-cancer     : Val MCC=0.5393 | Test MCC=0.5807
#   anti-fungal     : Val MCC=0.6319 | Test MCC=0.6082
#   anti-parasitic  : Val MCC=0.5037 | Test MCC=0.5783
#   anti-viral      : Val MCC=0.5857 | Test MCC=0.6078
#   cell-cell-communication: Val MCC=0.6846 | Test MCC=0.6745
#   drug-delivery   : Val MCC=0.4744 | Test MCC=0.5441
#   immunological   : Val MCC=0.6050 | Test MCC=0.5883
#   inhibitor       : Val MCC=0.5118 | Test MCC=0.4402
#   metabolic       : Val MCC=0.6676 | Test MCC=0.6721
#   other-functional: Val MCC=0.4668 | Test MCC=0.4346
#   signal-peptide  : Val MCC=0.8795 | Test MCC=0.8764
#   toxic           : Val MCC=0.7647 | Test MCC=0.7534
# ----------------------------------------------------------------------
# Ep 31/80 | LR: 7.1e-06 | Train: 0.4469 | Val: 0.0566 | Test: 0.0577 [SWA n=2]
#   MCC -> Func Avg (Val): 0.6226 | Func Avg (Test): 0.6247 | Pat: 1/20
#   Overall Total MCC -> Val: 0.8439 | Test: 0.8435
#   NON-FUNCTIONAL MCC -> Val: 0.9467 | Test: 0.9479
#   anti-bacterial  : Val MCC=0.7360 | Test MCC=0.7368
#   anti-cancer     : Val MCC=0.5524 | Test MCC=0.5836
#   anti-fungal     : Val MCC=0.6380 | Test MCC=0.6079
#   anti-parasitic  : Val MCC=0.5127 | Test MCC=0.5795
#   anti-viral      : Val MCC=0.5897 | Test MCC=0.6091
#   cell-cell-communication: Val MCC=0.6631 | Test MCC=0.6731
#   drug-delivery   : Val MCC=0.4805 | Test MCC=0.5283
#   immunological   : Val MCC=0.6117 | Test MCC=0.5851
#   inhibitor       : Val MCC=0.5106 | Test MCC=0.4423
#   metabolic       : Val MCC=0.6629 | Test MCC=0.6766
#   other-functional: Val MCC=0.4925 | Test MCC=0.4685
#   signal-peptide  : Val MCC=0.8801 | Test MCC=0.8789
#   toxic           : Val MCC=0.7637 | Test MCC=0.7517
# ----------------------------------------------------------------------
# Ep 32/80 | LR: 6.9e-06 | Train: 0.4455 | Val: 0.0570 | Test: 0.0579 [SWA n=3]
#   MCC -> Func Avg (Val): 0.6263 | Func Avg (Test): 0.6255 | Pat: 0/20 >>> BEST <<<
#   Overall Total MCC -> Val: 0.8393 | Test: 0.8390
#   NON-FUNCTIONAL MCC -> Val: 0.9465 | Test: 0.9475
#   anti-bacterial  : Val MCC=0.7357 | Test MCC=0.7415
#   anti-cancer     : Val MCC=0.5460 | Test MCC=0.5852
#   anti-fungal     : Val MCC=0.6281 | Test MCC=0.6097
#   anti-parasitic  : Val MCC=0.5181 | Test MCC=0.5811
#   anti-viral      : Val MCC=0.5861 | Test MCC=0.5989
#   cell-cell-communication: Val MCC=0.6710 | Test MCC=0.6765
#   drug-delivery   : Val MCC=0.5137 | Test MCC=0.5451
#   immunological   : Val MCC=0.6219 | Test MCC=0.5673
#   inhibitor       : Val MCC=0.5029 | Test MCC=0.4410
#   metabolic       : Val MCC=0.6776 | Test MCC=0.6827
#   other-functional: Val MCC=0.4949 | Test MCC=0.4697
#   signal-peptide  : Val MCC=0.8808 | Test MCC=0.8786
#   toxic           : Val MCC=0.7646 | Test MCC=0.7540
# ----------------------------------------------------------------------
# Ep 33/80 | LR: 6.7e-06 | Train: 0.4445 | Val: 0.0571 | Test: 0.0583 [SWA n=4]
#   MCC -> Func Avg (Val): 0.6289 | Func Avg (Test): 0.6320 | Pat: 0/20 >>> BEST <<<
#   Overall Total MCC -> Val: 0.8439 | Test: 0.8441
#   NON-FUNCTIONAL MCC -> Val: 0.9461 | Test: 0.9475
#   anti-bacterial  : Val MCC=0.7887 | Test MCC=0.7944
#   anti-cancer     : Val MCC=0.5483 | Test MCC=0.5835
#   anti-fungal     : Val MCC=0.6307 | Test MCC=0.6140
#   anti-parasitic  : Val MCC=0.5117 | Test MCC=0.5832
#   anti-viral      : Val MCC=0.5867 | Test MCC=0.6154
#   cell-cell-communication: Val MCC=0.6753 | Test MCC=0.6724
#   drug-delivery   : Val MCC=0.5030 | Test MCC=0.5506
#   immunological   : Val MCC=0.6115 | Test MCC=0.5725
#   inhibitor       : Val MCC=0.5055 | Test MCC=0.4463
#   metabolic       : Val MCC=0.6802 | Test MCC=0.6872
#   other-functional: Val MCC=0.4902 | Test MCC=0.4787
#   signal-peptide  : Val MCC=0.8832 | Test MCC=0.8778
#   toxic           : Val MCC=0.7607 | Test MCC=0.7397
# ----------------------------------------------------------------------
# Ep 34/80 | LR: 6.5e-06 | Train: 0.4440 | Val: 0.0574 | Test: 0.0586 [SWA n=5]
#   MCC -> Func Avg (Val): 0.6299 | Func Avg (Test): 0.6336 | Pat: 0/20 >>> BEST <<<
#   Overall Total MCC -> Val: 0.8438 | Test: 0.8457
#   NON-FUNCTIONAL MCC -> Val: 0.9459 | Test: 0.9478
#   anti-bacterial  : Val MCC=0.7900 | Test MCC=0.7941
#   anti-cancer     : Val MCC=0.5461 | Test MCC=0.5837
#   anti-fungal     : Val MCC=0.6286 | Test MCC=0.6181
#   anti-parasitic  : Val MCC=0.5123 | Test MCC=0.5842
#   anti-viral      : Val MCC=0.5868 | Test MCC=0.6083
#   cell-cell-communication: Val MCC=0.6826 | Test MCC=0.6787
#   drug-delivery   : Val MCC=0.5030 | Test MCC=0.5447
#   immunological   : Val MCC=0.6190 | Test MCC=0.6009
#   inhibitor       : Val MCC=0.5114 | Test MCC=0.4419
#   metabolic       : Val MCC=0.6794 | Test MCC=0.6939
#   other-functional: Val MCC=0.4802 | Test MCC=0.4490
#   signal-peptide  : Val MCC=0.8821 | Test MCC=0.8803
#   toxic           : Val MCC=0.7668 | Test MCC=0.7583
# ----------------------------------------------------------------------
# Ep 35/80 | LR: 6.3e-06 | Train: 0.4427 | Val: 0.0577 | Test: 0.0589 [SWA n=6]
#   MCC -> Func Avg (Val): 0.6306 | Func Avg (Test): 0.6330 | Pat: 0/20 >>> BEST <<<
#   Overall Total MCC -> Val: 0.8508 | Test: 0.8502
#   NON-FUNCTIONAL MCC -> Val: 0.9465 | Test: 0.9479
#   anti-bacterial  : Val MCC=0.7919 | Test MCC=0.7971
#   anti-cancer     : Val MCC=0.5573 | Test MCC=0.5885
#   anti-fungal     : Val MCC=0.6320 | Test MCC=0.6187
#   anti-parasitic  : Val MCC=0.5134 | Test MCC=0.5805
#   anti-viral      : Val MCC=0.5806 | Test MCC=0.5911
#   cell-cell-communication: Val MCC=0.6743 | Test MCC=0.6718
#   drug-delivery   : Val MCC=0.4969 | Test MCC=0.5568
#   immunological   : Val MCC=0.6171 | Test MCC=0.5821
#   inhibitor       : Val MCC=0.5146 | Test MCC=0.4450
#   metabolic       : Val MCC=0.6823 | Test MCC=0.6836
#   other-functional: Val MCC=0.4902 | Test MCC=0.4923
#   signal-peptide  : Val MCC=0.8854 | Test MCC=0.8791
#   toxic           : Val MCC=0.7622 | Test MCC=0.7422
# ----------------------------------------------------------------------
# Ep 36/80 | LR: 6.1e-06 | Train: 0.4410 | Val: 0.0580 | Test: 0.0592 [SWA n=7]
#   MCC -> Func Avg (Val): 0.6321 | Func Avg (Test): 0.6356 | Pat: 0/20 >>> BEST <<<
#   Overall Total MCC -> Val: 0.8507 | Test: 0.8510
#   NON-FUNCTIONAL MCC -> Val: 0.9460 | Test: 0.9479
#   anti-bacterial  : Val MCC=0.7930 | Test MCC=0.7972
#   anti-cancer     : Val MCC=0.5643 | Test MCC=0.5921
#   anti-fungal     : Val MCC=0.6319 | Test MCC=0.6189
#   anti-parasitic  : Val MCC=0.5169 | Test MCC=0.5871
#   anti-viral      : Val MCC=0.5870 | Test MCC=0.6159
#   cell-cell-communication: Val MCC=0.6740 | Test MCC=0.6733
#   drug-delivery   : Val MCC=0.4988 | Test MCC=0.5542
#   immunological   : Val MCC=0.6213 | Test MCC=0.5872
#   inhibitor       : Val MCC=0.5172 | Test MCC=0.4404
#   metabolic       : Val MCC=0.6789 | Test MCC=0.6835
#   other-functional: Val MCC=0.4875 | Test MCC=0.4869
#   signal-peptide  : Val MCC=0.8861 | Test MCC=0.8819
#   toxic           : Val MCC=0.7597 | Test MCC=0.7444
# ----------------------------------------------------------------------
# Ep 37/80 | LR: 5.9e-06 | Train: 0.4402 | Val: 0.0581 | Test: 0.0593 [SWA n=8]
#   MCC -> Func Avg (Val): 0.6353 | Func Avg (Test): 0.6354 | Pat: 0/20 >>> BEST <<<
#   Overall Total MCC -> Val: 0.8477 | Test: 0.8479
#   NON-FUNCTIONAL MCC -> Val: 0.9454 | Test: 0.9480
#   anti-bacterial  : Val MCC=0.7957 | Test MCC=0.7987
#   anti-cancer     : Val MCC=0.5542 | Test MCC=0.5862
#   anti-fungal     : Val MCC=0.6317 | Test MCC=0.6196
#   anti-parasitic  : Val MCC=0.5160 | Test MCC=0.5826
#   anti-viral      : Val MCC=0.5895 | Test MCC=0.6157
#   cell-cell-communication: Val MCC=0.6850 | Test MCC=0.6776
#   drug-delivery   : Val MCC=0.5272 | Test MCC=0.5623
#   immunological   : Val MCC=0.6257 | Test MCC=0.5856
#   inhibitor       : Val MCC=0.5115 | Test MCC=0.4373
#   metabolic       : Val MCC=0.6809 | Test MCC=0.6892
#   other-functional: Val MCC=0.4939 | Test MCC=0.4790
#   signal-peptide  : Val MCC=0.8853 | Test MCC=0.8805
#   toxic           : Val MCC=0.7625 | Test MCC=0.7454
# ----------------------------------------------------------------------
# Ep 38/80 | LR: 5.7e-06 | Train: 0.4394 | Val: 0.0584 | Test: 0.0595 [SWA n=9]
#   MCC -> Func Avg (Val): 0.6349 | Func Avg (Test): 0.6367 | Pat: 1/20
#   Overall Total MCC -> Val: 0.8507 | Test: 0.8501
#   NON-FUNCTIONAL MCC -> Val: 0.9451 | Test: 0.9479
#   anti-bacterial  : Val MCC=0.7973 | Test MCC=0.7976
#   anti-cancer     : Val MCC=0.5640 | Test MCC=0.5900
#   anti-fungal     : Val MCC=0.6321 | Test MCC=0.6194
#   anti-parasitic  : Val MCC=0.5211 | Test MCC=0.5891
#   anti-viral      : Val MCC=0.5890 | Test MCC=0.6119
#   cell-cell-communication: Val MCC=0.6743 | Test MCC=0.6758
#   drug-delivery   : Val MCC=0.5211 | Test MCC=0.5601
#   immunological   : Val MCC=0.6293 | Test MCC=0.5877
#   inhibitor       : Val MCC=0.5095 | Test MCC=0.4457
#   metabolic       : Val MCC=0.6856 | Test MCC=0.6891
#   other-functional: Val MCC=0.4916 | Test MCC=0.4946
#   signal-peptide  : Val MCC=0.8767 | Test MCC=0.8691
#   toxic           : Val MCC=0.7620 | Test MCC=0.7475
# ----------------------------------------------------------------------
# Ep 39/80 | LR: 5.5e-06 | Train: 0.4390 | Val: 0.0585 | Test: 0.0597 [SWA n=10]
#   MCC -> Func Avg (Val): 0.6357 | Func Avg (Test): 0.6349 | Pat: 0/20 >>> BEST <<<
#   Overall Total MCC -> Val: 0.8523 | Test: 0.8516
#   NON-FUNCTIONAL MCC -> Val: 0.9454 | Test: 0.9479
#   anti-bacterial  : Val MCC=0.7962 | Test MCC=0.7993
#   anti-cancer     : Val MCC=0.5662 | Test MCC=0.5896
#   anti-fungal     : Val MCC=0.6307 | Test MCC=0.6197
#   anti-parasitic  : Val MCC=0.5195 | Test MCC=0.5844
#   anti-viral      : Val MCC=0.5886 | Test MCC=0.6116
#   cell-cell-communication: Val MCC=0.6810 | Test MCC=0.6733
#   drug-delivery   : Val MCC=0.5324 | Test MCC=0.5637
#   immunological   : Val MCC=0.6219 | Test MCC=0.5882
#   inhibitor       : Val MCC=0.5114 | Test MCC=0.4441
#   metabolic       : Val MCC=0.6841 | Test MCC=0.6907
#   other-functional: Val MCC=0.4792 | Test MCC=0.4605
#   signal-peptide  : Val MCC=0.8864 | Test MCC=0.8815
#   toxic           : Val MCC=0.7669 | Test MCC=0.7467
# ----------------------------------------------------------------------
# Ep 40/80 | LR: 5.3e-06 | Train: 0.4371 | Val: 0.0588 | Test: 0.0600 [SWA n=11]
#   MCC -> Func Avg (Val): 0.6365 | Func Avg (Test): 0.6384 | Pat: 0/20 >>> BEST <<<
#   Overall Total MCC -> Val: 0.8478 | Test: 0.8487
#   NON-FUNCTIONAL MCC -> Val: 0.9447 | Test: 0.9478
#   anti-bacterial  : Val MCC=0.8000 | Test MCC=0.8008
#   anti-cancer     : Val MCC=0.5562 | Test MCC=0.5875
#   anti-fungal     : Val MCC=0.6306 | Test MCC=0.6185
#   anti-parasitic  : Val MCC=0.5201 | Test MCC=0.5919
#   anti-viral      : Val MCC=0.5899 | Test MCC=0.6179
#   cell-cell-communication: Val MCC=0.6814 | Test MCC=0.6735
#   drug-delivery   : Val MCC=0.5293 | Test MCC=0.5569
#   immunological   : Val MCC=0.6202 | Test MCC=0.6078
#   inhibitor       : Val MCC=0.5198 | Test MCC=0.4423
#   metabolic       : Val MCC=0.6850 | Test MCC=0.6918
#   other-functional: Val MCC=0.4872 | Test MCC=0.4719
#   signal-peptide  : Val MCC=0.8859 | Test MCC=0.8802
#   toxic           : Val MCC=0.7693 | Test MCC=0.7581
# ----------------------------------------------------------------------
# Ep 41/80 | LR: 5.1e-06 | Train: 0.4366 | Val: 0.0591 | Test: 0.0603 [SWA n=12]
#   MCC -> Func Avg (Val): 0.6361 | Func Avg (Test): 0.6340 | Pat: 1/20
#   Overall Total MCC -> Val: 0.8533 | Test: 0.8510
#   NON-FUNCTIONAL MCC -> Val: 0.9447 | Test: 0.9444
#   anti-bacterial  : Val MCC=0.7989 | Test MCC=0.8002
#   anti-cancer     : Val MCC=0.5654 | Test MCC=0.5910
#   anti-fungal     : Val MCC=0.6331 | Test MCC=0.6207
#   anti-parasitic  : Val MCC=0.5367 | Test MCC=0.5831
#   anti-viral      : Val MCC=0.5837 | Test MCC=0.6021
#   cell-cell-communication: Val MCC=0.6817 | Test MCC=0.6750
#   drug-delivery   : Val MCC=0.5315 | Test MCC=0.5670
#   immunological   : Val MCC=0.6172 | Test MCC=0.5902
#   inhibitor       : Val MCC=0.5093 | Test MCC=0.4360
#   metabolic       : Val MCC=0.6846 | Test MCC=0.6923
#   other-functional: Val MCC=0.4842 | Test MCC=0.4641
#   signal-peptide  : Val MCC=0.8765 | Test MCC=0.8726
#   toxic           : Val MCC=0.7668 | Test MCC=0.7476
# ----------------------------------------------------------------------
# Ep 42/80 | LR: 4.9e-06 | Train: 0.4357 | Val: 0.0593 | Test: 0.0605 [SWA n=13]
#   MCC -> Func Avg (Val): 0.6377 | Func Avg (Test): 0.6327 | Pat: 0/20 >>> BEST <<<
#   Overall Total MCC -> Val: 0.8511 | Test: 0.8499
#   NON-FUNCTIONAL MCC -> Val: 0.9458 | Test: 0.9478
#   anti-bacterial  : Val MCC=0.8011 | Test MCC=0.8038
#   anti-cancer     : Val MCC=0.5541 | Test MCC=0.5884
#   anti-fungal     : Val MCC=0.6346 | Test MCC=0.6228
#   anti-parasitic  : Val MCC=0.5320 | Test MCC=0.5866
#   anti-viral      : Val MCC=0.5892 | Test MCC=0.6196
#   cell-cell-communication: Val MCC=0.6895 | Test MCC=0.6808
#   drug-delivery   : Val MCC=0.5307 | Test MCC=0.5576
#   immunological   : Val MCC=0.6252 | Test MCC=0.5491
#   inhibitor       : Val MCC=0.5257 | Test MCC=0.4382
#   metabolic       : Val MCC=0.6853 | Test MCC=0.6897
#   other-functional: Val MCC=0.4822 | Test MCC=0.4692
#   signal-peptide  : Val MCC=0.8755 | Test MCC=0.8725
#   toxic           : Val MCC=0.7650 | Test MCC=0.7473
# ----------------------------------------------------------------------
# Ep 43/80 | LR: 4.7e-06 | Train: 0.4348 | Val: 0.0596 | Test: 0.0606 [SWA n=14]
#   MCC -> Func Avg (Val): 0.6402 | Func Avg (Test): 0.6414 | Pat: 0/20 >>> BEST <<<
#   Overall Total MCC -> Val: 0.8513 | Test: 0.8520
#   NON-FUNCTIONAL MCC -> Val: 0.9451 | Test: 0.9478
#   anti-bacterial  : Val MCC=0.8219 | Test MCC=0.8265
#   anti-cancer     : Val MCC=0.5570 | Test MCC=0.5881
#   anti-fungal     : Val MCC=0.6352 | Test MCC=0.6230
#   anti-parasitic  : Val MCC=0.5247 | Test MCC=0.5895
#   anti-viral      : Val MCC=0.5939 | Test MCC=0.6222
#   cell-cell-communication: Val MCC=0.6895 | Test MCC=0.6857
#   drug-delivery   : Val MCC=0.5437 | Test MCC=0.5617
#   immunological   : Val MCC=0.6238 | Test MCC=0.6051
#   inhibitor       : Val MCC=0.5099 | Test MCC=0.4404
#   metabolic       : Val MCC=0.6863 | Test MCC=0.6858
#   other-functional: Val MCC=0.4837 | Test MCC=0.4804
#   signal-peptide  : Val MCC=0.8861 | Test MCC=0.8814
#   toxic           : Val MCC=0.7667 | Test MCC=0.7481
# ----------------------------------------------------------------------
# Ep 44/80 | LR: 4.5e-06 | Train: 0.4340 | Val: 0.0599 | Test: 0.0609 [SWA n=15]
#   MCC -> Func Avg (Val): 0.6435 | Func Avg (Test): 0.6383 | Pat: 0/20 >>> BEST <<<
#   Overall Total MCC -> Val: 0.8574 | Test: 0.8560
#   NON-FUNCTIONAL MCC -> Val: 0.9455 | Test: 0.9484
#   anti-bacterial  : Val MCC=0.8226 | Test MCC=0.8282
#   anti-cancer     : Val MCC=0.5673 | Test MCC=0.5929
#   anti-fungal     : Val MCC=0.6362 | Test MCC=0.6249
#   anti-parasitic  : Val MCC=0.5388 | Test MCC=0.5840
#   anti-viral      : Val MCC=0.5917 | Test MCC=0.6197
#   cell-cell-communication: Val MCC=0.6997 | Test MCC=0.6867
#   drug-delivery   : Val MCC=0.5416 | Test MCC=0.5602
#   immunological   : Val MCC=0.6274 | Test MCC=0.5490
#   inhibitor       : Val MCC=0.5145 | Test MCC=0.4429
#   metabolic       : Val MCC=0.6848 | Test MCC=0.6954
#   other-functional: Val MCC=0.4964 | Test MCC=0.4886
#   signal-peptide  : Val MCC=0.8771 | Test MCC=0.8747
#   toxic           : Val MCC=0.7674 | Test MCC=0.7510
# ----------------------------------------------------------------------
# Ep 45/80 | LR: 4.3e-06 | Train: 0.4327 | Val: 0.0600 | Test: 0.0612 [SWA n=16]
#   MCC -> Func Avg (Val): 0.6400 | Func Avg (Test): 0.6413 | Pat: 1/20
#   Overall Total MCC -> Val: 0.8517 | Test: 0.8521
#   NON-FUNCTIONAL MCC -> Val: 0.9453 | Test: 0.9481
#   anti-bacterial  : Val MCC=0.8236 | Test MCC=0.8280
#   anti-cancer     : Val MCC=0.5605 | Test MCC=0.5894
#   anti-fungal     : Val MCC=0.6364 | Test MCC=0.6243
#   anti-parasitic  : Val MCC=0.5257 | Test MCC=0.5854
#   anti-viral      : Val MCC=0.5881 | Test MCC=0.6279
#   cell-cell-communication: Val MCC=0.6965 | Test MCC=0.6827
#   drug-delivery   : Val MCC=0.5301 | Test MCC=0.5568
#   immunological   : Val MCC=0.6222 | Test MCC=0.5966
#   inhibitor       : Val MCC=0.5191 | Test MCC=0.4410
#   metabolic       : Val MCC=0.6834 | Test MCC=0.6889
#   other-functional: Val MCC=0.4915 | Test MCC=0.4943
#   signal-peptide  : Val MCC=0.8768 | Test MCC=0.8730
#   toxic           : Val MCC=0.7660 | Test MCC=0.7488
# ----------------------------------------------------------------------
# Ep 46/80 | LR: 4.1e-06 | Train: 0.4321 | Val: 0.0601 | Test: 0.0614 [SWA n=17]
#   MCC -> Func Avg (Val): 0.6397 | Func Avg (Test): 0.6404 | Pat: 2/20
#   Overall Total MCC -> Val: 0.8522 | Test: 0.8526
#   NON-FUNCTIONAL MCC -> Val: 0.9452 | Test: 0.9482
#   anti-bacterial  : Val MCC=0.8240 | Test MCC=0.8267
#   anti-cancer     : Val MCC=0.5554 | Test MCC=0.5913
#   anti-fungal     : Val MCC=0.6354 | Test MCC=0.6249
#   anti-parasitic  : Val MCC=0.5232 | Test MCC=0.5926
#   anti-viral      : Val MCC=0.5907 | Test MCC=0.6240
#   cell-cell-communication: Val MCC=0.6979 | Test MCC=0.6835
#   drug-delivery   : Val MCC=0.5329 | Test MCC=0.5692
#   immunological   : Val MCC=0.6200 | Test MCC=0.5540
#   inhibitor       : Val MCC=0.5079 | Test MCC=0.4481
#   metabolic       : Val MCC=0.6901 | Test MCC=0.6925
#   other-functional: Val MCC=0.4935 | Test MCC=0.4917
#   signal-peptide  : Val MCC=0.8779 | Test MCC=0.8733
#   toxic           : Val MCC=0.7676 | Test MCC=0.7532
# ----------------------------------------------------------------------
# Ep 51/80 | LR: 3.1e-06 | Train: 0.4276 | Val: 0.0610 | Test: 0.0626 [SWA n=22]
#   MCC -> Func Avg (Val): 0.6451 | Func Avg (Test): 0.6421 | Pat: 0/20 >>> BEST <<<
#   Overall Total MCC -> Val: 0.8559 | Test: 0.8546
#   NON-FUNCTIONAL MCC -> Val: 0.9453 | Test: 0.9481
#   anti-bacterial  : Val MCC=0.8274 | Test MCC=0.8299
#   anti-cancer     : Val MCC=0.5632 | Test MCC=0.5922
#   anti-fungal     : Val MCC=0.6412 | Test MCC=0.6240
#   anti-parasitic  : Val MCC=0.5428 | Test MCC=0.5917
#   anti-viral      : Val MCC=0.5894 | Test MCC=0.6277
#   cell-cell-communication: Val MCC=0.7055 | Test MCC=0.6836
#   drug-delivery   : Val MCC=0.5401 | Test MCC=0.5665
#   immunological   : Val MCC=0.6205 | Test MCC=0.5681
#   inhibitor       : Val MCC=0.5178 | Test MCC=0.4420
#   metabolic       : Val MCC=0.6897 | Test MCC=0.6951
#   other-functional: Val MCC=0.5000 | Test MCC=0.4993
#   signal-peptide  : Val MCC=0.8796 | Test MCC=0.8750
#   toxic           : Val MCC=0.7689 | Test MCC=0.7528
# ----------------------------------------------------------------------
# Ep 52/80 | LR: 2.9e-06 | Train: 0.4271 | Val: 0.0612 | Test: 0.0628 [SWA n=23]
#   MCC -> Func Avg (Val): 0.6449 | Func Avg (Test): 0.6460 | Pat: 1/20
#   Overall Total MCC -> Val: 0.8553 | Test: 0.8550
#   NON-FUNCTIONAL MCC -> Val: 0.9452 | Test: 0.9467
#   anti-bacterial  : Val MCC=0.8277 | Test MCC=0.8308
#   anti-cancer     : Val MCC=0.5636 | Test MCC=0.5932
#   anti-fungal     : Val MCC=0.6394 | Test MCC=0.6244
#   anti-parasitic  : Val MCC=0.5449 | Test MCC=0.5945
#   anti-viral      : Val MCC=0.5977 | Test MCC=0.6281
#   cell-cell-communication: Val MCC=0.6989 | Test MCC=0.6864
#   drug-delivery   : Val MCC=0.5299 | Test MCC=0.5626
#   immunological   : Val MCC=0.6224 | Test MCC=0.6126
#   inhibitor       : Val MCC=0.5232 | Test MCC=0.4467
#   metabolic       : Val MCC=0.6916 | Test MCC=0.6956
#   other-functional: Val MCC=0.4909 | Test MCC=0.4857
#   signal-peptide  : Val MCC=0.8793 | Test MCC=0.8739
#   toxic           : Val MCC=0.7741 | Test MCC=0.7630
# ----------------------------------------------------------------------
# Ep 53/80 | LR: 2.7e-06 | Train: 0.4263 | Val: 0.0613 | Test: 0.0631 [SWA n=24]
#   MCC -> Func Avg (Val): 0.6462 | Func Avg (Test): 0.6413 | Pat: 0/20 >>> BEST <<<
#   Overall Total MCC -> Val: 0.8558 | Test: 0.8546
#   NON-FUNCTIONAL MCC -> Val: 0.9452 | Test: 0.9481
#   anti-bacterial  : Val MCC=0.8268 | Test MCC=0.8291
#   anti-cancer     : Val MCC=0.5664 | Test MCC=0.5940
#   anti-fungal     : Val MCC=0.6386 | Test MCC=0.6251
#   anti-parasitic  : Val MCC=0.5438 | Test MCC=0.5932
#   anti-viral      : Val MCC=0.6006 | Test MCC=0.6260
#   cell-cell-communication: Val MCC=0.7055 | Test MCC=0.6829
#   drug-delivery   : Val MCC=0.5451 | Test MCC=0.5711
#   immunological   : Val MCC=0.6162 | Test MCC=0.5674
#   inhibitor       : Val MCC=0.5211 | Test MCC=0.4401
#   metabolic       : Val MCC=0.6918 | Test MCC=0.6980
#   other-functional: Val MCC=0.4961 | Test MCC=0.4827
#   signal-peptide  : Val MCC=0.8789 | Test MCC=0.8748
#   toxic           : Val MCC=0.7700 | Test MCC=0.7530
# ----------------------------------------------------------------------
# Ep 55/80 | LR: 2.4e-06 | Train: 0.4241 | Val: 0.0617 | Test: 0.0636 [SWA n=26]
#   MCC -> Func Avg (Val): 0.6471 | Func Avg (Test): 0.6422 | Pat: 1/20
#   Overall Total MCC -> Val: 0.8538 | Test: 0.8524
#   NON-FUNCTIONAL MCC -> Val: 0.9451 | Test: 0.9447
#   anti-bacterial  : Val MCC=0.8278 | Test MCC=0.8304
#   anti-cancer     : Val MCC=0.5651 | Test MCC=0.5955
#   anti-fungal     : Val MCC=0.6383 | Test MCC=0.6284
#   anti-parasitic  : Val MCC=0.5254 | Test MCC=0.5852
#   anti-viral      : Val MCC=0.6007 | Test MCC=0.6282
#   cell-cell-communication: Val MCC=0.7042 | Test MCC=0.6842
#   drug-delivery   : Val MCC=0.5582 | Test MCC=0.5622
#   immunological   : Val MCC=0.6200 | Test MCC=0.5701
#   inhibitor       : Val MCC=0.5286 | Test MCC=0.4370
#   metabolic       : Val MCC=0.6948 | Test MCC=0.6985
#   other-functional: Val MCC=0.5000 | Test MCC=0.4994
#   signal-peptide  : Val MCC=0.8797 | Test MCC=0.8761
#   toxic           : Val MCC=0.7694 | Test MCC=0.7536
# ----------------------------------------------------------------------
# Ep 56/80 | LR: 2.2e-06 | Train: 0.4247 | Val: 0.0621 | Test: 0.0638 [SWA n=27]
#   MCC -> Func Avg (Val): 0.6482 | Func Avg (Test): 0.6480 | Pat: 0/20 >>> BEST <<<
#   Overall Total MCC -> Val: 0.8556 | Test: 0.8549
#   NON-FUNCTIONAL MCC -> Val: 0.9452 | Test: 0.9477
#   anti-bacterial  : Val MCC=0.8290 | Test MCC=0.8304
#   anti-cancer     : Val MCC=0.5644 | Test MCC=0.5969
#   anti-fungal     : Val MCC=0.6449 | Test MCC=0.6265
#   anti-parasitic  : Val MCC=0.5421 | Test MCC=0.5974
#   anti-viral      : Val MCC=0.5979 | Test MCC=0.6313
#   cell-cell-communication: Val MCC=0.7042 | Test MCC=0.6864
#   drug-delivery   : Val MCC=0.5500 | Test MCC=0.5743
#   immunological   : Val MCC=0.6235 | Test MCC=0.6001
#   inhibitor       : Val MCC=0.5238 | Test MCC=0.4496
#   metabolic       : Val MCC=0.6934 | Test MCC=0.6974
#   other-functional: Val MCC=0.4991 | Test MCC=0.5034
#   signal-peptide  : Val MCC=0.8824 | Test MCC=0.8741
#   toxic           : Val MCC=0.7725 | Test MCC=0.7559
# ----------------------------------------------------------------------
# Ep 57/80 | LR: 2.0e-06 | Train: 0.4234 | Val: 0.0624 | Test: 0.0641 [SWA n=28]
#   MCC -> Func Avg (Val): 0.6467 | Func Avg (Test): 0.6466 | Pat: 1/20
#   Overall Total MCC -> Val: 0.8544 | Test: 0.8539
#   NON-FUNCTIONAL MCC -> Val: 0.9453 | Test: 0.9482
#   anti-bacterial  : Val MCC=0.8276 | Test MCC=0.8318
#   anti-cancer     : Val MCC=0.5676 | Test MCC=0.5925
#   anti-fungal     : Val MCC=0.6417 | Test MCC=0.6255
#   anti-parasitic  : Val MCC=0.5362 | Test MCC=0.5937
#   anti-viral      : Val MCC=0.5974 | Test MCC=0.6131
#   cell-cell-communication: Val MCC=0.7075 | Test MCC=0.6908
#   drug-delivery   : Val MCC=0.5445 | Test MCC=0.5739
#   immunological   : Val MCC=0.6197 | Test MCC=0.6064
#   inhibitor       : Val MCC=0.5232 | Test MCC=0.4505
#   metabolic       : Val MCC=0.6928 | Test MCC=0.6970
#   other-functional: Val MCC=0.4933 | Test MCC=0.5009
#   signal-peptide  : Val MCC=0.8829 | Test MCC=0.8748
#   toxic           : Val MCC=0.7729 | Test MCC=0.7556
# ----------------------------------------------------------------------
# Ep 58/80 | LR: 1.9e-06 | Train: 0.4229 | Val: 0.0624 | Test: 0.0643 [SWA n=29]
#   MCC -> Func Avg (Val): 0.6477 | Func Avg (Test): 0.6452 | Pat: 2/20
#   Overall Total MCC -> Val: 0.8584 | Test: 0.8567
#   NON-FUNCTIONAL MCC -> Val: 0.9453 | Test: 0.9488
#   anti-bacterial  : Val MCC=0.8327 | Test MCC=0.8302
#   anti-cancer     : Val MCC=0.5756 | Test MCC=0.5968
#   anti-fungal     : Val MCC=0.6406 | Test MCC=0.6279
#   anti-parasitic  : Val MCC=0.5373 | Test MCC=0.5932
#   anti-viral      : Val MCC=0.5975 | Test MCC=0.6170
#   cell-cell-communication: Val MCC=0.7058 | Test MCC=0.6864
#   drug-delivery   : Val MCC=0.5498 | Test MCC=0.5664
#   immunological   : Val MCC=0.6196 | Test MCC=0.5983
#   inhibitor       : Val MCC=0.5260 | Test MCC=0.4430
#   metabolic       : Val MCC=0.6889 | Test MCC=0.6975
#   other-functional: Val MCC=0.4896 | Test MCC=0.4999
#   signal-peptide  : Val MCC=0.8822 | Test MCC=0.8751
#   toxic           : Val MCC=0.7745 | Test MCC=0.7563
# ----------------------------------------------------------------------
# Ep 59/80 | LR: 1.7e-06 | Train: 0.4221 | Val: 0.0627 | Test: 0.0645 [SWA n=30]
#   MCC -> Func Avg (Val): 0.6489 | Func Avg (Test): 0.6468 | Pat: 0/20 >>> BEST <<<
#   Overall Total MCC -> Val: 0.8553 | Test: 0.8545
#   NON-FUNCTIONAL MCC -> Val: 0.9454 | Test: 0.9482
#   anti-bacterial  : Val MCC=0.8278 | Test MCC=0.8307
#   anti-cancer     : Val MCC=0.5748 | Test MCC=0.5970
#   anti-fungal     : Val MCC=0.6401 | Test MCC=0.6258
#   anti-parasitic  : Val MCC=0.5399 | Test MCC=0.5949
#   anti-viral      : Val MCC=0.5993 | Test MCC=0.6276
#   cell-cell-communication: Val MCC=0.7161 | Test MCC=0.6866
#   drug-delivery   : Val MCC=0.5494 | Test MCC=0.5639
#   immunological   : Val MCC=0.6211 | Test MCC=0.6069
#   inhibitor       : Val MCC=0.5206 | Test MCC=0.4507
#   metabolic       : Val MCC=0.6946 | Test MCC=0.6971
#   other-functional: Val MCC=0.4975 | Test MCC=0.4958
#   signal-peptide  : Val MCC=0.8827 | Test MCC=0.8753
#   toxic           : Val MCC=0.7724 | Test MCC=0.7562
# ----------------------------------------------------------------------
# Ep 63/80 | LR: 1.2e-06 | Train: 0.4201 | Val: 0.0635 | Test: 0.0655 [SWA n=34]
#   MCC -> Func Avg (Val): 0.6457 | Func Avg (Test): 0.6433 | Pat: 4/20
#   Overall Total MCC -> Val: 0.8562 | Test: 0.8547
#   NON-FUNCTIONAL MCC -> Val: 0.9454 | Test: 0.9483
#   anti-bacterial  : Val MCC=0.8310 | Test MCC=0.8309
#   anti-cancer     : Val MCC=0.5696 | Test MCC=0.5954
#   anti-fungal     : Val MCC=0.6441 | Test MCC=0.6280
#   anti-parasitic  : Val MCC=0.5361 | Test MCC=0.5969
#   anti-viral      : Val MCC=0.6030 | Test MCC=0.6237
#   cell-cell-communication: Val MCC=0.6826 | Test MCC=0.6795
#   drug-delivery   : Val MCC=0.5406 | Test MCC=0.5697
#   immunological   : Val MCC=0.6206 | Test MCC=0.5663
#   inhibitor       : Val MCC=0.5276 | Test MCC=0.4498
#   metabolic       : Val MCC=0.6892 | Test MCC=0.6892
#   other-functional: Val MCC=0.4931 | Test MCC=0.5020
#   signal-peptide  : Val MCC=0.8851 | Test MCC=0.8751
#   toxic           : Val MCC=0.7715 | Test MCC=0.7564
# ----------------------------------------------------------------------
# Ep 64/80 | LR: 1.0e-06 | Train: 0.4194 | Val: 0.0637 | Test: 0.0656 [SWA n=35]
#   MCC -> Func Avg (Val): 0.6461 | Func Avg (Test): 0.6476 | Pat: 5/20
#   Overall Total MCC -> Val: 0.8555 | Test: 0.8551
#   NON-FUNCTIONAL MCC -> Val: 0.9453 | Test: 0.9458
#   anti-bacterial  : Val MCC=0.8308 | Test MCC=0.8335
#   anti-cancer     : Val MCC=0.5641 | Test MCC=0.5954
#   anti-fungal     : Val MCC=0.6441 | Test MCC=0.6283
#   anti-parasitic  : Val MCC=0.5354 | Test MCC=0.5970
#   anti-viral      : Val MCC=0.6005 | Test MCC=0.6277
#   cell-cell-communication: Val MCC=0.6832 | Test MCC=0.6864
#   drug-delivery   : Val MCC=0.5500 | Test MCC=0.5686
#   immunological   : Val MCC=0.6254 | Test MCC=0.6097
#   inhibitor       : Val MCC=0.5253 | Test MCC=0.4542
#   metabolic       : Val MCC=0.6934 | Test MCC=0.6971
#   other-functional: Val MCC=0.4916 | Test MCC=0.4859
#   signal-peptide  : Val MCC=0.8841 | Test MCC=0.8776
#   toxic           : Val MCC=0.7720 | Test MCC=0.7570
# ----------------------------------------------------------------------
# Ep 65/80 | LR: 9.1e-07 | Train: 0.4187 | Val: 0.0639 | Test: 0.0659 [SWA n=36]
#   MCC -> Func Avg (Val): 0.6471 | Func Avg (Test): 0.6440 | Pat: 6/20
#   Overall Total MCC -> Val: 0.8556 | Test: 0.8544
#   NON-FUNCTIONAL MCC -> Val: 0.9455 | Test: 0.9489
#   anti-bacterial  : Val MCC=0.8298 | Test MCC=0.8308
#   anti-cancer     : Val MCC=0.5713 | Test MCC=0.5956
#   anti-fungal     : Val MCC=0.6425 | Test MCC=0.6304
#   anti-parasitic  : Val MCC=0.5409 | Test MCC=0.5987
#   anti-viral      : Val MCC=0.6051 | Test MCC=0.6145
#   cell-cell-communication: Val MCC=0.6871 | Test MCC=0.6770
#   drug-delivery   : Val MCC=0.5577 | Test MCC=0.5658
#   immunological   : Val MCC=0.6245 | Test MCC=0.5783
#   inhibitor       : Val MCC=0.5208 | Test MCC=0.4566
#   metabolic       : Val MCC=0.6926 | Test MCC=0.7010
#   other-functional: Val MCC=0.4975 | Test MCC=0.5039
#   signal-peptide  : Val MCC=0.8718 | Test MCC=0.8629
#   toxic           : Val MCC=0.7712 | Test MCC=0.7559
# ----------------------------------------------------------------------
# Ep 66/80 | LR: 7.9e-07 | Train: 0.4187 | Val: 0.0641 | Test: 0.0661 [SWA n=37]
#   MCC -> Func Avg (Val): 0.6443 | Func Avg (Test): 0.6430 | Pat: 7/20
#   Overall Total MCC -> Val: 0.8543 | Test: 0.8533
#   NON-FUNCTIONAL MCC -> Val: 0.9456 | Test: 0.9487
#   anti-bacterial  : Val MCC=0.8156 | Test MCC=0.8158
#   anti-cancer     : Val MCC=0.5704 | Test MCC=0.5974
#   anti-fungal     : Val MCC=0.6419 | Test MCC=0.6284
#   anti-parasitic  : Val MCC=0.5387 | Test MCC=0.5965
#   anti-viral      : Val MCC=0.6087 | Test MCC=0.6267
#   cell-cell-communication: Val MCC=0.6955 | Test MCC=0.6772
#   drug-delivery   : Val MCC=0.5406 | Test MCC=0.5544
#   immunological   : Val MCC=0.6182 | Test MCC=0.5800
#   inhibitor       : Val MCC=0.5132 | Test MCC=0.4556
#   metabolic       : Val MCC=0.6938 | Test MCC=0.6987
#   other-functional: Val MCC=0.4953 | Test MCC=0.5078
#   signal-peptide  : Val MCC=0.8716 | Test MCC=0.8634
#   toxic           : Val MCC=0.7725 | Test MCC=0.7567
# ----------------------------------------------------------------------
# Ep 67/80 | LR: 6.9e-07 | Train: 0.4186 | Val: 0.0642 | Test: 0.0663 [SWA n=38]
#   MCC -> Func Avg (Val): 0.6459 | Func Avg (Test): 0.6433 | Pat: 8/20
#   Overall Total MCC -> Val: 0.8555 | Test: 0.8545
#   NON-FUNCTIONAL MCC -> Val: 0.9459 | Test: 0.9482
#   anti-bacterial  : Val MCC=0.8297 | Test MCC=0.8308
#   anti-cancer     : Val MCC=0.5698 | Test MCC=0.5982
#   anti-fungal     : Val MCC=0.6396 | Test MCC=0.6332
#   anti-parasitic  : Val MCC=0.5409 | Test MCC=0.5935
#   anti-viral      : Val MCC=0.6011 | Test MCC=0.6253
#   cell-cell-communication: Val MCC=0.6832 | Test MCC=0.6789
#   drug-delivery   : Val MCC=0.5585 | Test MCC=0.5613
#   immunological   : Val MCC=0.6244 | Test MCC=0.5796
#   inhibitor       : Val MCC=0.5126 | Test MCC=0.4516
#   metabolic       : Val MCC=0.6996 | Test MCC=0.6978
#   other-functional: Val MCC=0.4939 | Test MCC=0.4938
#   signal-peptide  : Val MCC=0.8705 | Test MCC=0.8626
#   toxic           : Val MCC=0.7730 | Test MCC=0.7568
# ----------------------------------------------------------------------
# Ep 68/80 | LR: 5.9e-07 | Train: 0.4174 | Val: 0.0645 | Test: 0.0666 [SWA n=39]
#   MCC -> Func Avg (Val): 0.6469 | Func Avg (Test): 0.6433 | Pat: 9/20
#   Overall Total MCC -> Val: 0.8558 | Test: 0.8548
#   NON-FUNCTIONAL MCC -> Val: 0.9453 | Test: 0.9486
#   anti-bacterial  : Val MCC=0.8314 | Test MCC=0.8325
#   anti-cancer     : Val MCC=0.5682 | Test MCC=0.5966
#   anti-fungal     : Val MCC=0.6399 | Test MCC=0.6290
#   anti-parasitic  : Val MCC=0.5394 | Test MCC=0.5922
#   anti-viral      : Val MCC=0.6039 | Test MCC=0.6245
#   cell-cell-communication: Val MCC=0.6989 | Test MCC=0.6810
#   drug-delivery   : Val MCC=0.5498 | Test MCC=0.5524
#   immunological   : Val MCC=0.6229 | Test MCC=0.5813
#   inhibitor       : Val MCC=0.5174 | Test MCC=0.4509
#   metabolic       : Val MCC=0.6995 | Test MCC=0.7009
#   other-functional: Val MCC=0.4931 | Test MCC=0.4969
#   signal-peptide  : Val MCC=0.8734 | Test MCC=0.8650
#   toxic           : Val MCC=0.7716 | Test MCC=0.7596
# ----------------------------------------------------------------------
# Ep 69/80 | LR: 5.0e-07 | Train: 0.4172 | Val: 0.0647 | Test: 0.0667 [SWA n=40]
#   MCC -> Func Avg (Val): 0.6482 | Func Avg (Test): 0.6436 | Pat: 10/20
#   Overall Total MCC -> Val: 0.8577 | Test: 0.8552
#   NON-FUNCTIONAL MCC -> Val: 0.9455 | Test: 0.9454
#   anti-bacterial  : Val MCC=0.8318 | Test MCC=0.8318
#   anti-cancer     : Val MCC=0.5719 | Test MCC=0.5982
#   anti-fungal     : Val MCC=0.6409 | Test MCC=0.6282
#   anti-parasitic  : Val MCC=0.5420 | Test MCC=0.5979
#   anti-viral      : Val MCC=0.6039 | Test MCC=0.6280
#   cell-cell-communication: Val MCC=0.6917 | Test MCC=0.6776
#   drug-delivery   : Val MCC=0.5561 | Test MCC=0.5580
#   immunological   : Val MCC=0.6298 | Test MCC=0.5742
#   inhibitor       : Val MCC=0.5152 | Test MCC=0.4534
#   metabolic       : Val MCC=0.6902 | Test MCC=0.6888
#   other-functional: Val MCC=0.4953 | Test MCC=0.4970
#   signal-peptide  : Val MCC=0.8856 | Test MCC=0.8765
#   toxic           : Val MCC=0.7724 | Test MCC=0.7574
# ----------------------------------------------------------------------
# Ep 70/80 | LR: 4.1e-07 | Train: 0.4174 | Val: 0.0648 | Test: 0.0669 [SWA n=41]
#   MCC -> Func Avg (Val): 0.6463 | Func Avg (Test): 0.6453 | Pat: 11/20
#   Overall Total MCC -> Val: 0.8574 | Test: 0.8560
#   NON-FUNCTIONAL MCC -> Val: 0.9454 | Test: 0.9462
#   anti-bacterial  : Val MCC=0.8333 | Test MCC=0.8321
#   anti-cancer     : Val MCC=0.5733 | Test MCC=0.5993
#   anti-fungal     : Val MCC=0.6422 | Test MCC=0.6289
#   anti-parasitic  : Val MCC=0.5368 | Test MCC=0.6006
#   anti-viral      : Val MCC=0.6042 | Test MCC=0.6303
#   cell-cell-communication: Val MCC=0.6917 | Test MCC=0.6859
#   drug-delivery   : Val MCC=0.5487 | Test MCC=0.5681
#   immunological   : Val MCC=0.6198 | Test MCC=0.5729
#   inhibitor       : Val MCC=0.5106 | Test MCC=0.4545
#   metabolic       : Val MCC=0.6942 | Test MCC=0.7019
#   other-functional: Val MCC=0.5019 | Test MCC=0.4930
#   signal-peptide  : Val MCC=0.8721 | Test MCC=0.8639
#   toxic           : Val MCC=0.7734 | Test MCC=0.7571
# ----------------------------------------------------------------------
